# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from tensorflow import keras as ks

import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from skimage.transform import resize
from sklearn.metrics import confusion_matrix

import cv2

#Per data visualization
import seaborn as sns

from matplotlib import pyplot as plt

import glob
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import os, os.path

#Per modello NN
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Softmax

import time
import math

import operator

print(tf.__version__)
# Out:
# 1.15.2
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Extract the full file name
def extract_name(from_string):
  to_pos = from_string.index('.')
  substring = from_string[0:to_pos]
  return substring

#Extract the class from the file name, if the class is the string before che -
def extract_label(from_string):
  position = from_string.index('-') # gets position of the - in the filename
  substring = from_string[0:position]
  return substring

#Extract the list of obfuscations applied to label
def extract_obf(from_string):
  start_pos = from_string.index('-')
  end_pos = from_string.index('.')
  substring = from_string[(start_pos + 1):end_pos]
  return substring

def mapping_labels_encoded(label_encoder):
  for index in range(len(list(label_encoder.classes_))):
    #print(index, end = ": ")
    print(index, end = "-> ")
    print(list(label_encoder.inverse_transform([index]))) 

class TimeHistory(ks.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

print("Done")
# Out:
# Done

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

downloaded = drive.CreateFile({'id':"18ESID3MpwG-SzZPE1EENzsGPh8vl8ti9"})   # replace the id with id of file you want to access
downloaded.GetContentFile('data_18k.zip')        # replace the file name with your file

# %%
# !unzip -q data_18k.zip -d DB_Repo/

print("Done")
# Out:
# replace DB_Repo/data/alien_language-EncodeArithmetic-EncodeLiterals-Flatten.npy? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# Done

# %%
path, dirs, files = next(os.walk("/content/DB_Repo/data"))
file_count = len(files)
#Should be 36000
print(file_count)
# Out:
# 18800

# %%
# %cd /content/DB_Repo/data
# !pwd
# Out:
# /content/DB_Repo/data
# /content/DB_Repo/data

# %%
#COSTANTI E DICHIARAZIONI

database_list = list()
filename_list = list()
labels_list = list()
obf_list = list()
class_names = set()

#LETTURA E RESIZE IMMAGINI

#Aggiungo i valori alle liste leggendo i vari files
for filename in glob.glob('*.npy'):
  temp_img = np.load(filename)
  database_list.append(temp_img)
  #Salvo il file name
  filename_list.append(extract_name(filename))
  #Salvo la label, ossia la classe
  labels_list.append(extract_label(filename))
  #Creo un set di tutte le classi così trovate
  class_names.add(extract_label(filename))
  #Salvo la lista di offuscatori di ogni file
  obf_list.append(extract_obf(filename))

# %%
'''

#SHUFFLE

#Ho i valori e le etichette in due liste (+ obf); 
#le mescolo mantenendo l'ordine tra valore-label
temp = list(zip(database_list, labels_list, obf_list))
np.random.shuffle(temp)
database_list, labels_list, obf_list = zip(*temp)


'''
# Out:
# "\n\n#SHUFFLE\n\n#Ho i valori e le etichette in due liste (+ obf); \n#le mescolo mantenendo l'ordine tra valore-label\ntemp = list(zip(database_list, labels_list, obf_list))\nnp.random.shuffle(temp)\ndatabase_list, labels_list, obf_list = zip(*temp)\n\n\n"

# %%
assert len(database_list) == len(labels_list) == len(obf_list)

#Trasformo i valori in numpy.ndarray
images = np.array(database_list)

labels = np.array(labels_list)

obf = np.array(obf_list)

numero_file = images.size

# %% [markdown]
# #ANALISI DATABASE

# %%
print("Numero immagini:", images.size)
print("Numero labels:", labels.size)
print("Numero obf:", obf.size)
# Out:
# Numero immagini: 18800
# Numero labels: 18800
# Numero obf: 18800

# %%
dim1, dim2 = images[0].shape
print(dim1, dim2)
# Out:
# 21 64

# %%
np.amax(images[0])
# Out:
# 65535

# %%
dim1_min = 999999
dim2_min = 999999
dim1_max = 0
dim2_max = 0
max_val = 0
min_val = 999999

index_of_maxlen = -1

dim2diff = 999999

count_0_1024 = 0
count_1024_2048 = 0
count_2048_4096 = 0
count_over_4096 = 0
count_err = 0

valore_medio_sotto_1024 = 0
#NB se non è esattamente 65535, qualche immagine non ha tale valore come massimo
valore_max_medio = 0

lista_obf_dim = list()
dizionario_dim_obf = dict()

for index in range(images.size):
  dim1_t, dim2_t = images[index].shape

  valore_max_medio += np.amax(images[index])

  dizionario_dim_obf[index] = dim1_t

  if max_val < np.amax(images[index]):
    max_val = np.amax(images[index])
  if min_val > np.amax(images[index]):
    min_val = np.amin(images[index])
  if dim1_t > dim1_max:
    dim1_max = dim1_t
    index_of_maxlen = index
  if dim2_t > dim2_max:
    dim2_max = dim2_t
  if dim1_t < dim1_min:
    dim1_min = dim1_t
  if dim2_t < dim2_min:
    dim2_min = dim2_t
  if dim2_t != 64:
    dim2diff = dim2_t

  if dim1_t <= 1024:
    count_0_1024+=1
    valore_medio_sotto_1024 += dim1_t
  elif dim1_t > 1024 and dim1_t <= 2048:
    count_1024_2048+=1
  elif dim1_t > 2048 and dim1_t <= 4096:
    count_2048_4096+=1
  elif dim1_t > 4096:
    count_over_4096+=1
  else:
    count_err+=1

# %%
valore_medio_sotto_1024 /= count_0_1024
valore_max_medio /= numero_file

sorted_diz = dict(sorted(dizionario_dim_obf.items(), key=operator.itemgetter(1),reverse=True))

# %%
print("Valore più alto:", max_val)
print("Valore più basso:", min_val)
print("Dim1_min:", dim1_min)
print("Dim1_max:", dim1_max)
print("File più lungo:", labels[index_of_maxlen], ",", obf[index_of_maxlen])
print("Dim2_min:", dim2_min)
print("Dim2_max:", dim2_max)
print("Se esiste un valore di dim2 diverso da 64:", dim2diff)
print()
print("Numero dimensioni1 tra 0 e 1024:", count_0_1024)
print("Valore medio dimensioni1 sotto 1024:", valore_medio_sotto_1024)
print("Numero dimensioni1 tra 1024 e 2048:", count_1024_2048)
print("Numero dimensioni1 tra 2048 e 4096:", count_2048_4096)
print("Numero dimensioni1 oltre il 4096:", count_over_4096)
print("Errori nel contare:", count_err)
print()
print("Controllo che il massimo di ogni immagine sia uguale per tutte (ossia 65535):", valore_max_medio)
# Out:
# Valore più alto: 65535
# Valore più basso: 0
# Dim1_min: 7
# Dim1_max: 7928
# File più lungo: fair_warning , InitOpaque-EncodeArithmetic-RandomFuns
# Dim2_min: 64
# Dim2_max: 64
# Se esiste un valore di dim2 diverso da 64: 999999
#
# Numero dimensioni1 tra 0 e 1024: 17479
# Valore medio dimensioni1 sotto 1024: 79.50369014245666
# Numero dimensioni1 tra 1024 e 2048: 124
# Numero dimensioni1 tra 2048 e 4096: 399
# Numero dimensioni1 oltre il 4096: 798
# Errori nel contare: 0
#
# Controllo che il massimo di ogni immagine sia uguale per tutte (ossia 65535): 65535.0

# %%
counter = 25
for key in sorted_diz:
  print("Lunghezza:", sorted_diz[key], end=", ")
  print(obf[key], end="\t ---> \t\t")
  print(labels[key])
  counter-=1
  if counter == 0:
    break
# Out:
# Lunghezza: 7928, InitOpaque-EncodeArithmetic-RandomFuns	 ---> 		fair_warning
# Lunghezza: 7928, EncodeArithmetic-RandomFuns-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7928, EncodeArithmetic-InitOpaque-RandomFuns	 ---> 		fair_warning
# Lunghezza: 7912, InitOpaque-EncodeLiterals-RandomFuns	 ---> 		fair_warning
# Lunghezza: 7911, Flatten-InitOpaque-RandomFuns	 ---> 		fair_warning
# Lunghezza: 7911, InitOpaque-Flatten-RandomFuns	 ---> 		fair_warning
# Lunghezza: 7911, Flatten-RandomFuns-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7899, InitOpaque-EncodeArithmetic-EncodeLiterals	 ---> 		fair_warning
# Lunghezza: 7899, EncodeArithmetic-InitOpaque-EncodeLiterals	 ---> 		fair_warning
# Lunghezza: 7898, InitOpaque-EncodeLiterals-EncodeArithmetic	 ---> 		fair_warning
# Lunghezza: 7894, Flatten-InitOpaque-EncodeLiterals	 ---> 		fair_warning
# Lunghezza: 7894, RandomFuns-InitOpaque-EncodeLiterals	 ---> 		fair_warning
# Lunghezza: 7894, InitOpaque-Flatten-EncodeLiterals	 ---> 		fair_warning
# Lunghezza: 7894, InitOpaque-RandomFuns-EncodeLiterals	 ---> 		fair_warning
# Lunghezza: 7891, RandomFuns-EncodeLiterals-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7891, EncodeLiterals-InitOpaque-RandomFuns	 ---> 		fair_warning
# Lunghezza: 7891, EncodeLiterals-RandomFuns-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7890, InitOpaque-EncodeLiterals-Flatten	 ---> 		fair_warning
# Lunghezza: 7889, InitOpaque-RandomFuns-EncodeArithmetic	 ---> 		fair_warning
# Lunghezza: 7889, RandomFuns-EncodeArithmetic-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7889, InitOpaque-EncodeLiterals-Split	 ---> 		fair_warning
# Lunghezza: 7889, RandomFuns-InitOpaque-EncodeArithmetic	 ---> 		fair_warning
# Lunghezza: 7887, RandomFuns-InitOpaque-Flatten	 ---> 		fair_warning
# Lunghezza: 7887, RandomFuns-Flatten-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7887, InitOpaque-RandomFuns-Flatten	 ---> 		fair_warning

# %%
classi_e_val = list()

for indice in range(images.size):
  dimensione_classe = images[indice].shape[0]
  classe = labels[indice]
  classi_e_val.append((classe, dimensione_classe))

# %%
from itertools import groupby
from operator import itemgetter
from statistics import mean


#s = [('A', 1), ('B', 2), ('C', 3), ('A', 9), ('B', 8)]
s = classi_e_val
s2 = sorted(s, key=itemgetter(0))   # sorting the tuple based on 0th index

dimension_list = [(k, int(mean(list(zip(*g))[1]))) for k, g in groupby(s2, itemgetter(0))]

# %%
sorted_by_second = sorted(dimension_list, key=lambda tup: tup[1])

# %%
for elem in sorted_by_second:
  print(elem)
# Out:
# ('hello_world', 45)
# ('pyramid', 49)
# ('sum', 49)
# ('times_table', 49)
# ('count_digits', 50)
# ('factorial_rec', 50)
# ('factors', 50)
# ('fib_1', 50)
# ('reverse_integer', 50)
# ('strcpy', 50)
# ('strlen', 50)
# ('fib_2', 51)
# ('gcd_rec', 51)
# ('power_n', 51)
# ('gcd', 52)
# ('lcm', 52)
# ('n_is_palindrome', 52)
# ('n_is_prime', 52)
# ('positive_or_negative', 52)
# ('quotient_remainder', 52)
# ('factorial', 53)
# ('prime_n_between_intervals', 53)
# ('remove_char', 53)
# ('armstrong_n', 54)
# ('char_frequency', 54)
# ('leap_year', 54)
# ('strcat', 54)
# ('minimum_scalar_product', 55)
# ('n_is_sum_of_primes', 55)
# ('stringsort', 56)
# ('candy_splitting', 57)
# ('snapper_chain', 58)
# ('store_struct', 59)
# ('calculator', 60)
# ('count_vowels', 63)
# ('fly_swatter', 63)
# ('saving_the_universe', 66)
# ('train_time_table', 74)
# ('bot_trust', 91)
# ('rotate', 93)
# ('welcome_to_codejam', 129)
# ('multibase_happiness', 159)
# ('theme_park', 263)
# ('watersheds', 1005)
# ('magicka', 3585)
# ('alien_language', 4556)
# ('fair_warning', 7792)

# %%
obf_set = set()

for index in range(obf.size):
  for elem in obf[index].split('-'):
    obf_set.add(elem)

print("Trasformazioni applicate:")
print(sorted(obf_set))

sorted_obf_set = sorted(obf_set)
counter = 1
for elem in (sorted_obf_set):
  print("{}: {}".format(counter, elem))
  counter += 1
# Out:
# Trasformazioni applicate:
# ['EncodeArithmetic', 'EncodeLiterals', 'Flatten', 'InitEntropy', 'InitImplicitFlow', 'InitOpaque', 'RandomFuns', 'Split', 'base']
# 1: EncodeArithmetic
# 2: EncodeLiterals
# 3: Flatten
# 4: InitEntropy
# 5: InitImplicitFlow
# 6: InitOpaque
# 7: RandomFuns
# 8: Split
# 9: base

# %%
labels_set = set()

for index in range(obf.size):
  for elem in labels[index].split('-'):
    labels_set.add(elem)

print("Programmi (labels) analizzati:")

sorted_labels_set = sorted(labels_set)
counter = 1
for elem in (sorted_labels_set):
  print("{}: {}".format(counter, elem))
  counter += 1
# Out:
# Programmi (labels) analizzati:
# 1: alien_language
# 2: armstrong_n
# 3: bot_trust
# 4: calculator
# 5: candy_splitting
# 6: char_frequency
# 7: count_digits
# 8: count_vowels
# 9: factorial
# 10: factorial_rec
# 11: factors
# 12: fair_warning
# 13: fib_1
# 14: fib_2
# 15: fly_swatter
# 16: gcd
# 17: gcd_rec
# 18: hello_world
# 19: lcm
# 20: leap_year
# 21: magicka
# 22: minimum_scalar_product
# 23: multibase_happiness
# 24: n_is_palindrome
# 25: n_is_prime
# 26: n_is_sum_of_primes
# 27: positive_or_negative
# 28: power_n
# 29: prime_n_between_intervals
# 30: pyramid
# 31: quotient_remainder
# 32: remove_char
# 33: reverse_integer
# 34: rotate
# 35: saving_the_universe
# 36: snapper_chain
# 37: store_struct
# 38: strcat
# 39: strcpy
# 40: stringsort
# 41: strlen
# 42: sum
# 43: theme_park
# 44: times_table
# 45: train_time_table
# 46: watersheds
# 47: welcome_to_codejam

# %%
set_transformations = set()

for elem in obf:
  set_transformations.add(elem)

number_of_unique_trans = len(set_transformations)
print(number_of_unique_trans)

set_transformations_sorted = sorted(set_transformations)
# Out:
# 400

# %%
print("Trasformazioni applicate: ")
counter = 1
for elem in set_transformations_sorted:
  print("{}: {}".format(counter, elem))
  counter += 1
# Out:
# Trasformazioni applicate:
# 1: EncodeArithmetic
# 2: EncodeArithmetic-EncodeLiterals
# 3: EncodeArithmetic-EncodeLiterals-Flatten
# 4: EncodeArithmetic-EncodeLiterals-InitEntropy
# 5: EncodeArithmetic-EncodeLiterals-InitImplicitFlow
# 6: EncodeArithmetic-EncodeLiterals-InitOpaque
# 7: EncodeArithmetic-EncodeLiterals-RandomFuns
# 8: EncodeArithmetic-EncodeLiterals-Split
# 9: EncodeArithmetic-Flatten
# 10: EncodeArithmetic-Flatten-EncodeLiterals
# 11: EncodeArithmetic-Flatten-InitEntropy
# 12: EncodeArithmetic-Flatten-InitImplicitFlow
# 13: EncodeArithmetic-Flatten-InitOpaque
# 14: EncodeArithmetic-Flatten-RandomFuns
# 15: EncodeArithmetic-Flatten-Split
# 16: EncodeArithmetic-InitEntropy
# 17: EncodeArithmetic-InitEntropy-EncodeLiterals
# 18: EncodeArithmetic-InitEntropy-Flatten
# 19: EncodeArithmetic-InitEntropy-InitImplicitFlow
# 20: EncodeArithmetic-InitEntropy-InitOpaque
# 21: EncodeArithmetic-InitEntropy-RandomFuns
# 22: EncodeArithmetic-InitEntropy-Split
# 23: EncodeArithmetic-InitImplicitFlow
# 24: EncodeArithmetic-InitImplicitFlow-EncodeLiterals
# 25: EncodeArithmetic-InitImplicitFlow-Flatten
# 26: EncodeArithmetic-InitImplicitFlow-InitEntropy
# 27: EncodeArithmetic-InitImplicitFlow-InitOpaque
# 28: EncodeArithmetic-InitImplicitFlow-RandomFuns
# 29: EncodeArithmetic-InitImplicitFlow-Split
# 30: EncodeArithmetic-InitOpaque
# 31: EncodeArithmetic-InitOpaque-EncodeLiterals
# 32: EncodeArithmetic-InitOpaque-Flatten
# 33: EncodeArithmetic-InitOpaque-InitEntropy
# 34: EncodeArithmetic-InitOpaque-InitImplicitFlow
# 35: EncodeArithmetic-InitOpaque-RandomFuns
# 36: EncodeArithmetic-InitOpaque-Split
# 37: EncodeArithmetic-RandomFuns
# 38: EncodeArithmetic-RandomFuns-EncodeLiterals
# 39: EncodeArithmetic-RandomFuns-Flatten
# 40: EncodeArithmetic-RandomFuns-InitEntropy
# 41: EncodeArithmetic-RandomFuns-InitImplicitFlow
# 42: EncodeArithmetic-RandomFuns-InitOpaque
# 43: EncodeArithmetic-RandomFuns-Split
# 44: EncodeArithmetic-Split
# 45: EncodeArithmetic-Split-EncodeLiterals
# 46: EncodeArithmetic-Split-Flatten
# 47: EncodeArithmetic-Split-InitEntropy
# 48: EncodeArithmetic-Split-InitImplicitFlow
# 49: EncodeArithmetic-Split-InitOpaque
# 50: EncodeArithmetic-Split-RandomFuns
# 51: EncodeLiterals
# 52: EncodeLiterals-EncodeArithmetic
# 53: EncodeLiterals-EncodeArithmetic-Flatten
# 54: EncodeLiterals-EncodeArithmetic-InitEntropy
# 55: EncodeLiterals-EncodeArithmetic-InitImplicitFlow
# 56: EncodeLiterals-EncodeArithmetic-InitOpaque
# 57: EncodeLiterals-EncodeArithmetic-RandomFuns
# 58: EncodeLiterals-EncodeArithmetic-Split
# 59: EncodeLiterals-Flatten
# 60: EncodeLiterals-Flatten-EncodeArithmetic
# 61: EncodeLiterals-Flatten-InitEntropy
# 62: EncodeLiterals-Flatten-InitImplicitFlow
# 63: EncodeLiterals-Flatten-InitOpaque
# 64: EncodeLiterals-Flatten-RandomFuns
# 65: EncodeLiterals-Flatten-Split
# 66: EncodeLiterals-InitEntropy
# 67: EncodeLiterals-InitEntropy-EncodeArithmetic
# 68: EncodeLiterals-InitEntropy-Flatten
# 69: EncodeLiterals-InitEntropy-InitImplicitFlow
# 70: EncodeLiterals-InitEntropy-InitOpaque
# 71: EncodeLiterals-InitEntropy-RandomFuns
# 72: EncodeLiterals-InitEntropy-Split
# 73: EncodeLiterals-InitImplicitFlow
# 74: EncodeLiterals-InitImplicitFlow-EncodeArithmetic
# 75: EncodeLiterals-InitImplicitFlow-Flatten
# 76: EncodeLiterals-InitImplicitFlow-InitEntropy
# 77: EncodeLiterals-InitImplicitFlow-InitOpaque
# 78: EncodeLiterals-InitImplicitFlow-RandomFuns
# 79: EncodeLiterals-InitImplicitFlow-Split
# 80: EncodeLiterals-InitOpaque
# 81: EncodeLiterals-InitOpaque-EncodeArithmetic
# 82: EncodeLiterals-InitOpaque-Flatten
# 83: EncodeLiterals-InitOpaque-InitEntropy
# 84: EncodeLiterals-InitOpaque-InitImplicitFlow
# 85: EncodeLiterals-InitOpaque-RandomFuns
# 86: EncodeLiterals-InitOpaque-Split
# 87: EncodeLiterals-RandomFuns
# 88: EncodeLiterals-RandomFuns-EncodeArithmetic
# 89: EncodeLiterals-RandomFuns-Flatten
# 90: EncodeLiterals-RandomFuns-InitEntropy
# 91: EncodeLiterals-RandomFuns-InitImplicitFlow
# 92: EncodeLiterals-RandomFuns-InitOpaque
# 93: EncodeLiterals-RandomFuns-Split
# 94: EncodeLiterals-Split
# 95: EncodeLiterals-Split-EncodeArithmetic
# 96: EncodeLiterals-Split-Flatten
# 97: EncodeLiterals-Split-InitEntropy
# 98: EncodeLiterals-Split-InitImplicitFlow
# 99: EncodeLiterals-Split-InitOpaque
# 100: EncodeLiterals-Split-RandomFuns
# 101: Flatten
# 102: Flatten-EncodeArithmetic
# 103: Flatten-EncodeArithmetic-EncodeLiterals
# 104: Flatten-EncodeArithmetic-InitEntropy
# 105: Flatten-EncodeArithmetic-InitImplicitFlow
# 106: Flatten-EncodeArithmetic-InitOpaque
# 107: Flatten-EncodeArithmetic-RandomFuns
# 108: Flatten-EncodeArithmetic-Split
# 109: Flatten-EncodeLiterals
# 110: Flatten-EncodeLiterals-EncodeArithmetic
# 111: Flatten-EncodeLiterals-InitEntropy
# 112: Flatten-EncodeLiterals-InitImplicitFlow
# 113: Flatten-EncodeLiterals-InitOpaque
# 114: Flatten-EncodeLiterals-RandomFuns
# 115: Flatten-EncodeLiterals-Split
# 116: Flatten-InitEntropy
# 117: Flatten-InitEntropy-EncodeArithmetic
# 118: Flatten-InitEntropy-EncodeLiterals
# 119: Flatten-InitEntropy-InitImplicitFlow
# 120: Flatten-InitEntropy-InitOpaque
# 121: Flatten-InitEntropy-RandomFuns
# 122: Flatten-InitEntropy-Split
# 123: Flatten-InitImplicitFlow
# 124: Flatten-InitImplicitFlow-EncodeArithmetic
# 125: Flatten-InitImplicitFlow-EncodeLiterals
# 126: Flatten-InitImplicitFlow-InitEntropy
# 127: Flatten-InitImplicitFlow-InitOpaque
# 128: Flatten-InitImplicitFlow-RandomFuns
# 129: Flatten-InitImplicitFlow-Split
# 130: Flatten-InitOpaque
# 131: Flatten-InitOpaque-EncodeArithmetic
# 132: Flatten-InitOpaque-EncodeLiterals
# 133: Flatten-InitOpaque-InitEntropy
# 134: Flatten-InitOpaque-InitImplicitFlow
# 135: Flatten-InitOpaque-RandomFuns
# 136: Flatten-InitOpaque-Split
# 137: Flatten-RandomFuns
# 138: Flatten-RandomFuns-EncodeArithmetic
# 139: Flatten-RandomFuns-EncodeLiterals
# 140: Flatten-RandomFuns-InitEntropy
# 141: Flatten-RandomFuns-InitImplicitFlow
# 142: Flatten-RandomFuns-InitOpaque
# 143: Flatten-RandomFuns-Split
# 144: Flatten-Split
# 145: Flatten-Split-EncodeArithmetic
# 146: Flatten-Split-EncodeLiterals
# 147: Flatten-Split-InitEntropy
# 148: Flatten-Split-InitImplicitFlow
# 149: Flatten-Split-InitOpaque
# 150: Flatten-Split-RandomFuns
# 151: InitEntropy
# 152: InitEntropy-EncodeArithmetic
# 153: InitEntropy-EncodeArithmetic-EncodeLiterals
# 154: InitEntropy-EncodeArithmetic-Flatten
# 155: InitEntropy-EncodeArithmetic-InitImplicitFlow
# 156: InitEntropy-EncodeArithmetic-InitOpaque
# 157: InitEntropy-EncodeArithmetic-RandomFuns
# 158: InitEntropy-EncodeArithmetic-Split
# 159: InitEntropy-EncodeLiterals
# 160: InitEntropy-EncodeLiterals-EncodeArithmetic
# 161: InitEntropy-EncodeLiterals-Flatten
# 162: InitEntropy-EncodeLiterals-InitImplicitFlow
# 163: InitEntropy-EncodeLiterals-InitOpaque
# 164: InitEntropy-EncodeLiterals-RandomFuns
# 165: InitEntropy-EncodeLiterals-Split
# 166: InitEntropy-Flatten
# 167: InitEntropy-Flatten-EncodeArithmetic
# 168: InitEntropy-Flatten-EncodeLiterals
# 169: InitEntropy-Flatten-InitImplicitFlow
# 170: InitEntropy-Flatten-InitOpaque
# 171: InitEntropy-Flatten-RandomFuns
# 172: InitEntropy-Flatten-Split
# 173: InitEntropy-InitImplicitFlow
# 174: InitEntropy-InitImplicitFlow-EncodeArithmetic
# 175: InitEntropy-InitImplicitFlow-EncodeLiterals
# 176: InitEntropy-InitImplicitFlow-Flatten
# 177: InitEntropy-InitImplicitFlow-InitOpaque
# 178: InitEntropy-InitImplicitFlow-RandomFuns
# 179: InitEntropy-InitImplicitFlow-Split
# 180: InitEntropy-InitOpaque
# 181: InitEntropy-InitOpaque-EncodeArithmetic
# 182: InitEntropy-InitOpaque-EncodeLiterals
# 183: InitEntropy-InitOpaque-Flatten
# 184: InitEntropy-InitOpaque-InitImplicitFlow
# 185: InitEntropy-InitOpaque-RandomFuns
# 186: InitEntropy-InitOpaque-Split
# 187: InitEntropy-RandomFuns
# 188: InitEntropy-RandomFuns-EncodeArithmetic
# 189: InitEntropy-RandomFuns-EncodeLiterals
# 190: InitEntropy-RandomFuns-Flatten
# 191: InitEntropy-RandomFuns-InitImplicitFlow
# 192: InitEntropy-RandomFuns-InitOpaque
# 193: InitEntropy-RandomFuns-Split
# 194: InitEntropy-Split
# 195: InitEntropy-Split-EncodeArithmetic
# 196: InitEntropy-Split-EncodeLiterals
# 197: InitEntropy-Split-Flatten
# 198: InitEntropy-Split-InitImplicitFlow
# 199: InitEntropy-Split-InitOpaque
# 200: InitEntropy-Split-RandomFuns
# 201: InitImplicitFlow
# 202: InitImplicitFlow-EncodeArithmetic
# 203: InitImplicitFlow-EncodeArithmetic-EncodeLiterals
# 204: InitImplicitFlow-EncodeArithmetic-Flatten
# 205: InitImplicitFlow-EncodeArithmetic-InitEntropy
# 206: InitImplicitFlow-EncodeArithmetic-InitOpaque
# 207: InitImplicitFlow-EncodeArithmetic-RandomFuns
# 208: InitImplicitFlow-EncodeArithmetic-Split
# 209: InitImplicitFlow-EncodeLiterals
# 210: InitImplicitFlow-EncodeLiterals-EncodeArithmetic
# 211: InitImplicitFlow-EncodeLiterals-Flatten
# 212: InitImplicitFlow-EncodeLiterals-InitEntropy
# 213: InitImplicitFlow-EncodeLiterals-InitOpaque
# 214: InitImplicitFlow-EncodeLiterals-RandomFuns
# 215: InitImplicitFlow-EncodeLiterals-Split
# 216: InitImplicitFlow-Flatten
# 217: InitImplicitFlow-Flatten-EncodeArithmetic
# 218: InitImplicitFlow-Flatten-EncodeLiterals
# 219: InitImplicitFlow-Flatten-InitEntropy
# 220: InitImplicitFlow-Flatten-InitOpaque
# 221: InitImplicitFlow-Flatten-RandomFuns
# 222: InitImplicitFlow-Flatten-Split
# 223: InitImplicitFlow-InitEntropy
# 224: InitImplicitFlow-InitEntropy-EncodeArithmetic
# 225: InitImplicitFlow-InitEntropy-EncodeLiterals
# 226: InitImplicitFlow-InitEntropy-Flatten
# 227: InitImplicitFlow-InitEntropy-InitOpaque
# 228: InitImplicitFlow-InitEntropy-RandomFuns
# 229: InitImplicitFlow-InitEntropy-Split
# 230: InitImplicitFlow-InitOpaque
# 231: InitImplicitFlow-InitOpaque-EncodeArithmetic
# 232: InitImplicitFlow-InitOpaque-EncodeLiterals
# 233: InitImplicitFlow-InitOpaque-Flatten
# 234: InitImplicitFlow-InitOpaque-InitEntropy
# 235: InitImplicitFlow-InitOpaque-RandomFuns
# 236: InitImplicitFlow-InitOpaque-Split
# 237: InitImplicitFlow-RandomFuns
# 238: InitImplicitFlow-RandomFuns-EncodeArithmetic
# 239: InitImplicitFlow-RandomFuns-EncodeLiterals
# 240: InitImplicitFlow-RandomFuns-Flatten
# 241: InitImplicitFlow-RandomFuns-InitEntropy
# 242: InitImplicitFlow-RandomFuns-InitOpaque
# 243: InitImplicitFlow-RandomFuns-Split
# 244: InitImplicitFlow-Split
# 245: InitImplicitFlow-Split-EncodeArithmetic
# 246: InitImplicitFlow-Split-EncodeLiterals
# 247: InitImplicitFlow-Split-Flatten
# 248: InitImplicitFlow-Split-InitEntropy
# 249: InitImplicitFlow-Split-InitOpaque
# 250: InitImplicitFlow-Split-RandomFuns
# 251: InitOpaque
# 252: InitOpaque-EncodeArithmetic
# 253: InitOpaque-EncodeArithmetic-EncodeLiterals
# 254: InitOpaque-EncodeArithmetic-Flatten
# 255: InitOpaque-EncodeArithmetic-InitEntropy
# 256: InitOpaque-EncodeArithmetic-InitImplicitFlow
# 257: InitOpaque-EncodeArithmetic-RandomFuns
# 258: InitOpaque-EncodeArithmetic-Split
# 259: InitOpaque-EncodeLiterals
# 260: InitOpaque-EncodeLiterals-EncodeArithmetic
# 261: InitOpaque-EncodeLiterals-Flatten
# 262: InitOpaque-EncodeLiterals-InitEntropy
# 263: InitOpaque-EncodeLiterals-InitImplicitFlow
# 264: InitOpaque-EncodeLiterals-RandomFuns
# 265: InitOpaque-EncodeLiterals-Split
# 266: InitOpaque-Flatten
# 267: InitOpaque-Flatten-EncodeArithmetic
# 268: InitOpaque-Flatten-EncodeLiterals
# 269: InitOpaque-Flatten-InitEntropy
# 270: InitOpaque-Flatten-RandomFuns
# 271: InitOpaque-Flatten-Split
# 272: InitOpaque-InitEntropy
# 273: InitOpaque-InitEntropy-EncodeArithmetic
# 274: InitOpaque-InitEntropy-EncodeLiterals
# 275: InitOpaque-InitEntropy-Flatten
# 276: InitOpaque-InitEntropy-InitImplicitFlow
# 277: InitOpaque-InitEntropy-RandomFuns
# 278: InitOpaque-InitEntropy-Split
# 279: InitOpaque-InitImplicitFlow
# 280: InitOpaque-InitImplicitFlow-EncodeArithmetic
# 281: InitOpaque-InitImplicitFlow-EncodeLiterals
# 282: InitOpaque-InitImplicitFlow-Flatten
# 283: InitOpaque-InitImplicitFlow-InitEntropy
# 284: InitOpaque-InitImplicitFlow-RandomFuns
# 285: InitOpaque-InitImplicitFlow-Split
# 286: InitOpaque-RandomFuns
# 287: InitOpaque-RandomFuns-EncodeArithmetic
# 288: InitOpaque-RandomFuns-EncodeLiterals
# 289: InitOpaque-RandomFuns-Flatten
# 290: InitOpaque-RandomFuns-InitEntropy
# 291: InitOpaque-RandomFuns-InitImplicitFlow
# 292: InitOpaque-RandomFuns-Split
# 293: InitOpaque-Split
# 294: InitOpaque-Split-EncodeArithmetic
# 295: InitOpaque-Split-EncodeLiterals
# 296: InitOpaque-Split-Flatten
# 297: InitOpaque-Split-InitEntropy
# 298: InitOpaque-Split-InitImplicitFlow
# 299: InitOpaque-Split-RandomFuns
# 300: RandomFuns
# 301: RandomFuns-EncodeArithmetic
# 302: RandomFuns-EncodeArithmetic-EncodeLiterals
# 303: RandomFuns-EncodeArithmetic-Flatten
# 304: RandomFuns-EncodeArithmetic-InitEntropy
# 305: RandomFuns-EncodeArithmetic-InitImplicitFlow
# 306: RandomFuns-EncodeArithmetic-InitOpaque
# 307: RandomFuns-EncodeArithmetic-Split
# 308: RandomFuns-EncodeLiterals
# 309: RandomFuns-EncodeLiterals-EncodeArithmetic
# 310: RandomFuns-EncodeLiterals-Flatten
# 311: RandomFuns-EncodeLiterals-InitEntropy
# 312: RandomFuns-EncodeLiterals-InitImplicitFlow
# 313: RandomFuns-EncodeLiterals-InitOpaque
# 314: RandomFuns-EncodeLiterals-Split
# 315: RandomFuns-Flatten
# 316: RandomFuns-Flatten-EncodeArithmetic
# 317: RandomFuns-Flatten-EncodeLiterals
# 318: RandomFuns-Flatten-InitEntropy
# 319: RandomFuns-Flatten-InitImplicitFlow
# 320: RandomFuns-Flatten-InitOpaque
# 321: RandomFuns-Flatten-Split
# 322: RandomFuns-InitEntropy
# 323: RandomFuns-InitEntropy-EncodeArithmetic
# 324: RandomFuns-InitEntropy-EncodeLiterals
# 325: RandomFuns-InitEntropy-Flatten
# 326: RandomFuns-InitEntropy-InitImplicitFlow
# 327: RandomFuns-InitEntropy-InitOpaque
# 328: RandomFuns-InitEntropy-Split
# 329: RandomFuns-InitImplicitFlow
# 330: RandomFuns-InitImplicitFlow-EncodeArithmetic
# 331: RandomFuns-InitImplicitFlow-EncodeLiterals
# 332: RandomFuns-InitImplicitFlow-Flatten
# 333: RandomFuns-InitImplicitFlow-InitEntropy
# 334: RandomFuns-InitImplicitFlow-InitOpaque
# 335: RandomFuns-InitImplicitFlow-Split
# 336: RandomFuns-InitOpaque
# 337: RandomFuns-InitOpaque-EncodeArithmetic
# 338: RandomFuns-InitOpaque-EncodeLiterals
# 339: RandomFuns-InitOpaque-Flatten
# 340: RandomFuns-InitOpaque-InitEntropy
# 341: RandomFuns-InitOpaque-InitImplicitFlow
# 342: RandomFuns-InitOpaque-Split
# 343: RandomFuns-Split
# 344: RandomFuns-Split-EncodeArithmetic
# 345: RandomFuns-Split-EncodeLiterals
# 346: RandomFuns-Split-Flatten
# 347: RandomFuns-Split-InitEntropy
# 348: RandomFuns-Split-InitImplicitFlow
# 349: RandomFuns-Split-InitOpaque
# 350: Split
# 351: Split-EncodeArithmetic
# 352: Split-EncodeArithmetic-EncodeLiterals
# 353: Split-EncodeArithmetic-Flatten
# 354: Split-EncodeArithmetic-InitEntropy
# 355: Split-EncodeArithmetic-InitImplicitFlow
# 356: Split-EncodeArithmetic-InitOpaque
# 357: Split-EncodeArithmetic-RandomFuns
# 358: Split-EncodeLiterals
# 359: Split-EncodeLiterals-EncodeArithmetic
# 360: Split-EncodeLiterals-Flatten
# 361: Split-EncodeLiterals-InitEntropy
# 362: Split-EncodeLiterals-InitImplicitFlow
# 363: Split-EncodeLiterals-InitOpaque
# 364: Split-EncodeLiterals-RandomFuns
# 365: Split-Flatten
# 366: Split-Flatten-EncodeArithmetic
# 367: Split-Flatten-EncodeLiterals
# 368: Split-Flatten-InitEntropy
# 369: Split-Flatten-InitImplicitFlow
# 370: Split-Flatten-InitOpaque
# 371: Split-Flatten-RandomFuns
# 372: Split-InitEntropy
# 373: Split-InitEntropy-EncodeArithmetic
# 374: Split-InitEntropy-EncodeLiterals
# 375: Split-InitEntropy-Flatten
# 376: Split-InitEntropy-InitImplicitFlow
# 377: Split-InitEntropy-InitOpaque
# 378: Split-InitEntropy-RandomFuns
# 379: Split-InitImplicitFlow
# 380: Split-InitImplicitFlow-EncodeArithmetic
# 381: Split-InitImplicitFlow-EncodeLiterals
# 382: Split-InitImplicitFlow-Flatten
# 383: Split-InitImplicitFlow-InitEntropy
# 384: Split-InitImplicitFlow-InitOpaque
# 385: Split-InitImplicitFlow-RandomFuns
# 386: Split-InitOpaque
# 387: Split-InitOpaque-EncodeArithmetic
# 388: Split-InitOpaque-EncodeLiterals
# 389: Split-InitOpaque-Flatten
# 390: Split-InitOpaque-InitEntropy
# 391: Split-InitOpaque-InitImplicitFlow
# 392: Split-InitOpaque-RandomFuns
# 393: Split-RandomFuns
# 394: Split-RandomFuns-EncodeArithmetic
# 395: Split-RandomFuns-EncodeLiterals
# 396: Split-RandomFuns-Flatten
# 397: Split-RandomFuns-InitEntropy
# 398: Split-RandomFuns-InitImplicitFlow
# 399: Split-RandomFuns-InitOpaque
# 400: base

# %%
def indices(lst, element):
    result = []
    offset = -1
    while True:
        try:
            offset = lst.index(element, offset+1)
        except ValueError:
            return result
        result.append(offset)

# %%
print("Programmi che non hanno tutte le trasformazioni, e trasformazioni da loro saltate:")

counterOk = 0
counterWrong = 0

for class_name in class_names:
  print("Analizzo la classe: " + class_name)

  set_of_obf_per_class = set()
  #setDiff = set()

  indici = indices(labels_list, class_name)

  for elem in indici:
    set_of_obf_per_class.add(obf_list[elem])


  setDiff = set_transformations - set_of_obf_per_class

  if len(setDiff) == 0:
    print("APPOSTO")
    counterOk += 1
  else:
    counterWrong += 1
    counterDiff = 1
    for elem in setDiff:
      print("{}: {}".format(counterDiff, elem))
      counterDiff += 1

print("{}: {}".format("Numero di classi senza problemi", counterOk))
print("{}: {}".format("Numero di classi CON problemi", counterWrong))
# Out:
# Programmi che non hanno tutte le trasformazioni, e trasformazioni da loro saltate:
# Analizzo la classe: candy_splitting
# APPOSTO
# Analizzo la classe: minimum_scalar_product
# APPOSTO
# Analizzo la classe: count_digits
# APPOSTO
# Analizzo la classe: store_struct
# APPOSTO
# Analizzo la classe: fib_2
# APPOSTO
# Analizzo la classe: prime_n_between_intervals
# APPOSTO
# Analizzo la classe: stringsort
# APPOSTO
# Analizzo la classe: reverse_integer
# APPOSTO
# Analizzo la classe: armstrong_n
# APPOSTO
# Analizzo la classe: fair_warning
# APPOSTO
# Analizzo la classe: lcm
# APPOSTO
# Analizzo la classe: saving_the_universe
# APPOSTO
# Analizzo la classe: n_is_prime
# APPOSTO
# Analizzo la classe: char_frequency
# APPOSTO
# Analizzo la classe: factorial
# APPOSTO
# Analizzo la classe: n_is_sum_of_primes
# APPOSTO
# Analizzo la classe: calculator
# APPOSTO
# Analizzo la classe: rotate
# APPOSTO
# Analizzo la classe: power_n
# APPOSTO
# Analizzo la classe: magicka
# APPOSTO
# Analizzo la classe: quotient_remainder
# APPOSTO
# Analizzo la classe: theme_park
# APPOSTO
# Analizzo la classe: bot_trust
# APPOSTO
# Analizzo la classe: gcd
# APPOSTO
# Analizzo la classe: times_table
# APPOSTO
# Analizzo la classe: welcome_to_codejam
# APPOSTO
# Analizzo la classe: n_is_palindrome
# APPOSTO
# Analizzo la classe: train_time_table
# APPOSTO
# Analizzo la classe: leap_year
# APPOSTO
# Analizzo la classe: hello_world
# APPOSTO
# Analizzo la classe: strlen
# APPOSTO
# Analizzo la classe: factors
# APPOSTO
# Analizzo la classe: fly_swatter
# APPOSTO
# Analizzo la classe: snapper_chain
# APPOSTO
# Analizzo la classe: remove_char
# APPOSTO
# Analizzo la classe: strcpy
# APPOSTO
# Analizzo la classe: count_vowels
# APPOSTO
# Analizzo la classe: pyramid
# APPOSTO
# Analizzo la classe: watersheds
# APPOSTO
# Analizzo la classe: factorial_rec
# APPOSTO
# Analizzo la classe: multibase_happiness
# APPOSTO
# Analizzo la classe: gcd_rec
# APPOSTO
# Analizzo la classe: positive_or_negative
# APPOSTO
# Analizzo la classe: alien_language
# APPOSTO
# Analizzo la classe: fib_1
# APPOSTO
# Analizzo la classe: sum
# APPOSTO
# Analizzo la classe: strcat
# APPOSTO
# Numero di classi senza problemi: 47
# Numero di classi CON problemi: 0

# %%
def isinteger(x):
  return np.equal(np.mod(x, 1), 0)

# %%
#COSTANTI E DICHIARAZIONI

database_list = list()
filename_list = list()

#LETTURA E RESIZE IMMAGINI

#Aggiungo i valori alle liste leggendo i vari files
for filename in glob.glob('*.npy'):
  temp_img = np.load(filename)
  temp_img = temp_img.flatten()
  database_list.append(temp_img)
  #Salvo il file name
  filename_list.append(extract_name(filename))

# %%
lista = list()
conto_immagini = 0
for img in database_list:
  arrayres = isinteger(img)
  for elem in arrayres:
    if elem != True:
      print("Found an element not integer.")
  if (conto_immagini%100 == 0):
    print(conto_immagini)
  conto_immagini += 1

print("Fine.")
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# Fine.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from tensorflow import keras as ks

import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from skimage.transform import resize
from sklearn.metrics import confusion_matrix

import cv2

#Per data visualization
import seaborn as sns

from matplotlib import pyplot as plt

import glob
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import os, os.path

#Per modello NN
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Softmax

import time
import math

import operator

print(tf.__version__)
# Out:
# 1.15.2
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Extract the full file name
def extract_name(from_string):
  to_pos = from_string.index('.')
  substring = from_string[0:to_pos]
  return substring

#Extract the class from the file name, if the class is the string before che -
def extract_label(from_string):
  position = from_string.index('-') # gets position of the - in the filename
  substring = from_string[0:position]
  return substring

#Extract the list of obfuscations applied to label
def extract_obf(from_string):
  start_pos = from_string.index('-')
  end_pos = from_string.index('.')
  substring = from_string[(start_pos + 1):end_pos]
  return substring

def mapping_labels_encoded(label_encoder):
  for index in range(len(list(label_encoder.classes_))):
    #print(index, end = ": ")
    print(index, end = "-> ")
    print(list(label_encoder.inverse_transform([index]))) 

class TimeHistory(ks.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

print("Done")
# Out:
# Done

# %% [markdown]
# #Import database

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

downloaded = drive.CreateFile({'id':"1iDz4FJROi7aW45Y0ZQjkNRsE9NLxIXmG"})   # replace the id with id of file you want to access
downloaded.GetContentFile('data_36k.zip')        # replace the file name with your file

# %%
# !unzip -qq data_36k.zip -d DB_Repo/

print("Done")
# Out:
# replace DB_Repo/data/alien_language-EncodeArithmetic-EncodeLiterals-Flatten.npy? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# Done

# %%
path, dirs, files = next(os.walk("/content/DB_Repo/data"))
file_count = len(files)
#Should be 36000
print(file_count)
# Out:
# 36000

# %%
# %cd /content/DB_Repo/data
# !pwd
# Out:
# /content/DB_Repo/data
# /content/DB_Repo/data

# %%
#COSTANTI E DICHIARAZIONI

database_list = list()
filename_list = list()
labels_list = list()
obf_list = list()
class_names = set()

#LETTURA E RESIZE IMMAGINI

#Aggiungo i valori alle liste leggendo i vari files
for filename in glob.glob('*.npy'):
  temp_img = np.load(filename)
  database_list.append(temp_img)
  #Salvo il file name
  filename_list.append(extract_name(filename))
  #Salvo la label, ossia la classe
  labels_list.append(extract_label(filename))
  #Creo un set di tutte le classi così trovate
  class_names.add(extract_label(filename))
  #Salvo la lista di offuscatori di ogni file
  obf_list.append(extract_obf(filename))

# %%
'''

#SHUFFLE

#Ho i valori e le etichette in due liste (+ obf); 
#le mescolo mantenendo l'ordine tra valore-label
temp = list(zip(database_list, labels_list, obf_list))
np.random.shuffle(temp)
database_list, labels_list, obf_list = zip(*temp)


'''
# Out:
# "\n\n#SHUFFLE\n\n#Ho i valori e le etichette in due liste (+ obf); \n#le mescolo mantenendo l'ordine tra valore-label\ntemp = list(zip(database_list, labels_list, obf_list))\nnp.random.shuffle(temp)\ndatabase_list, labels_list, obf_list = zip(*temp)\n\n\n"

# %%
assert len(database_list) == len(labels_list) == len(obf_list)

#Trasformo i valori in numpy.ndarray
images = np.array(database_list)

labels = np.array(labels_list)

obf = np.array(obf_list)

numero_file = images.size

# %% [markdown]
# #ANALISI DATABASE

# %%
print("Numero immagini:", images.size)
print("Numero labels:", labels.size)
print("Numero obf:", obf.size)
# Out:
# Numero immagini: 36000
# Numero labels: 36000
# Numero obf: 36000

# %%
dim1, dim2 = images[0].shape
print(dim1, dim2)
# Out:
# 24 64

# %%
np.amax(images[0])
# Out:
# 65535

# %%
dim1_min = 999999
dim2_min = 999999
dim1_max = 0
dim2_max = 0
max_val = 0
min_val = 999999

index_of_maxlen = -1

dim2diff = 999999

count_0_1024 = 0
count_1024_2048 = 0
count_2048_4096 = 0
count_over_4096 = 0
count_err = 0

valore_medio_sotto_1024 = 0
#NB se non è esattamente 65535, qualche immagine non ha tale valore come massimo
valore_max_medio = 0

lista_obf_dim = list()
dizionario_dim_obf = dict()

for index in range(images.size):
  dim1_t, dim2_t = images[index].shape

  valore_max_medio += np.amax(images[index])

  dizionario_dim_obf[index] = dim1_t

  if max_val < np.amax(images[index]):
    max_val = np.amax(images[index])
  if min_val > np.amax(images[index]):
    min_val = np.amin(images[index])
  if dim1_t > dim1_max:
    dim1_max = dim1_t
    index_of_maxlen = index
  if dim2_t > dim2_max:
    dim2_max = dim2_t
  if dim1_t < dim1_min:
    dim1_min = dim1_t
  if dim2_t < dim2_min:
    dim2_min = dim2_t
  if dim2_t != 64:
    dim2diff = dim2_t

  if dim1_t <= 1024:
    count_0_1024+=1
    valore_medio_sotto_1024 += dim1_t
  elif dim1_t > 1024 and dim1_t <= 2048:
    count_1024_2048+=1
  elif dim1_t > 2048 and dim1_t <= 4096:
    count_2048_4096+=1
  elif dim1_t > 4096:
    count_over_4096+=1
  else:
    count_err+=1

# %%
valore_medio_sotto_1024 /= count_0_1024
valore_max_medio /= numero_file

sorted_diz = dict(sorted(dizionario_dim_obf.items(), key=operator.itemgetter(1),reverse=True))

# %%
print("Valore più alto:", max_val)
print("Valore più basso:", min_val)
print("Dim1_min:", dim1_min)
print("Dim1_max:", dim1_max)
print("File più lungo:", labels[index_of_maxlen], ",", obf[index_of_maxlen])
print("Dim2_min:", dim2_min)
print("Dim2_max:", dim2_max)
print("Se esiste un valore di dim2 diverso da 64:", dim2diff)
print()
print("Numero dimensioni1 tra 0 e 1024:", count_0_1024)
print("Valore medio dimensioni1 sotto 1024:", valore_medio_sotto_1024)
print("Numero dimensioni1 tra 1024 e 2048:", count_1024_2048)
print("Numero dimensioni1 tra 2048 e 4096:", count_2048_4096)
print("Numero dimensioni1 oltre il 4096:", count_over_4096)
print("Errori nel contare:", count_err)
print()
print("Controllo che il massimo di ogni immagine sia uguale per tutte (ossia 65535):", valore_max_medio)
# Out:
# Valore più alto: 65535
# Valore più basso: 0
# Dim1_min: 7
# Dim1_max: 7928
# File più lungo: fair_warning , InitOpaque-EncodeArithmetic-RandomFuns
# Dim2_min: 64
# Dim2_max: 64
# Se esiste un valore di dim2 diverso da 64: 999999
#
# Numero dimensioni1 tra 0 e 1024: 34165
# Valore medio dimensioni1 sotto 1024: 80.30961510317576
# Numero dimensioni1 tra 1024 e 2048: 238
# Numero dimensioni1 tra 2048 e 4096: 799
# Numero dimensioni1 oltre il 4096: 798
# Errori nel contare: 0
#
# Controllo che il massimo di ogni immagine sia uguale per tutte (ossia 65535): 65535.0

# %%
counter = 25
for key in sorted_diz:
  print("Lunghezza:", sorted_diz[key], end=", ")
  print(obf[key], end="\t ---> \t\t")
  print(labels[key])
  counter-=1
  if counter == 0:
    break
# Out:
# Lunghezza: 7928, InitOpaque-EncodeArithmetic-RandomFuns	 ---> 		fair_warning
# Lunghezza: 7928, EncodeArithmetic-RandomFuns-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7928, EncodeArithmetic-InitOpaque-RandomFuns	 ---> 		fair_warning
# Lunghezza: 7912, InitOpaque-EncodeLiterals-RandomFuns	 ---> 		fair_warning
# Lunghezza: 7911, Flatten-InitOpaque-RandomFuns	 ---> 		fair_warning
# Lunghezza: 7911, InitOpaque-Flatten-RandomFuns	 ---> 		fair_warning
# Lunghezza: 7911, Flatten-RandomFuns-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7899, InitOpaque-EncodeArithmetic-EncodeLiterals	 ---> 		fair_warning
# Lunghezza: 7899, EncodeArithmetic-InitOpaque-EncodeLiterals	 ---> 		fair_warning
# Lunghezza: 7898, InitOpaque-EncodeLiterals-EncodeArithmetic	 ---> 		fair_warning
# Lunghezza: 7894, Flatten-InitOpaque-EncodeLiterals	 ---> 		fair_warning
# Lunghezza: 7894, RandomFuns-InitOpaque-EncodeLiterals	 ---> 		fair_warning
# Lunghezza: 7894, InitOpaque-Flatten-EncodeLiterals	 ---> 		fair_warning
# Lunghezza: 7894, InitOpaque-RandomFuns-EncodeLiterals	 ---> 		fair_warning
# Lunghezza: 7891, RandomFuns-EncodeLiterals-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7891, EncodeLiterals-InitOpaque-RandomFuns	 ---> 		fair_warning
# Lunghezza: 7891, EncodeLiterals-RandomFuns-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7890, InitOpaque-EncodeLiterals-Flatten	 ---> 		fair_warning
# Lunghezza: 7889, InitOpaque-RandomFuns-EncodeArithmetic	 ---> 		fair_warning
# Lunghezza: 7889, RandomFuns-EncodeArithmetic-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7889, InitOpaque-EncodeLiterals-Split	 ---> 		fair_warning
# Lunghezza: 7889, RandomFuns-InitOpaque-EncodeArithmetic	 ---> 		fair_warning
# Lunghezza: 7887, RandomFuns-InitOpaque-Flatten	 ---> 		fair_warning
# Lunghezza: 7887, RandomFuns-Flatten-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7887, InitOpaque-RandomFuns-Flatten	 ---> 		fair_warning

# %%
images.size
# Out:
# 36000

# %%
classi_e_val = list()

for indice in range(images.size):
  dimensione_classe = images[indice].shape[0]
  classe = labels[indice]
  classi_e_val.append((classe, dimensione_classe))

# %%
from itertools import groupby
from operator import itemgetter
from statistics import mean


#s = [('A', 1), ('B', 2), ('C', 3), ('A', 9), ('B', 8)]
s = classi_e_val
s2 = sorted(s, key=itemgetter(0))   # sorting the tuple based on 0th index

dimension_list = [(k, int(mean(list(zip(*g))[1]))) for k, g in groupby(s2, itemgetter(0))]

# %%
sorted_by_second = sorted(dimension_list, key=lambda tup: tup[1])

# %%
for elem in sorted_by_second:
  print(elem)
# Out:
# ('hello_world', 45)
# ('sum', 48)
# ('times_table', 48)
# ('count_digits', 49)
# ('pyramid', 49)
# ('reverse_integer', 49)
# ('factorial_rec', 50)
# ('factors', 50)
# ('fib_1', 50)
# ('strcpy', 50)
# ('strlen', 50)
# ('fib_2', 51)
# ('gcd', 51)
# ('gcd_rec', 51)
# ('lcm', 51)
# ('n_is_palindrome', 51)
# ('power_n', 51)
# ('n_is_prime', 52)
# ('positive_or_negative', 52)
# ('factorial', 53)
# ('prime_n_between_intervals', 53)
# ('remove_char', 53)
# ('armstrong_n', 54)
# ('char_frequency', 54)
# ('leap_year', 54)
# ('quotient_remainder', 54)
# ('strcat', 54)
# ('minimum_scalar_product', 55)
# ('n_is_sum_of_primes', 55)
# ('stringsort', 56)
# ('candy_splitting', 57)
# ('snapper_chain', 57)
# ('calculator', 60)
# ('store_struct', 62)
# ('count_vowels', 63)
# ('fly_swatter', 66)
# ('saving_the_universe', 66)
# ('train_time_table', 73)
# ('bot_trust', 90)
# ('rotate', 90)
# ('welcome_to_codejam', 128)
# ('multibase_happiness', 160)
# ('theme_park', 264)
# ('watersheds', 1005)
# ('magicka', 3590)
# ('alien_language', 4556)
# ('fair_warning', 7792)

# %%
#Soluzione Aurora
'''
from itertools import groupby
from operator import itemgetter
from statistics import mean


#s = [('A', 1), ('B', 2), ('C', 3), ('A', 9), ('B', 8)]
s = classi_e_val
s2 = sorted(s, key=itemgetter(0))   # sorting the tuple based on 0th index

print([(k, int(mean(list(zip(*g))[1]))) for k, g in groupby(s2, itemgetter(0))])


from collections import defaultdict

sample = [("A", 1), ("B", 2), ("C", 3), ("A", 9), ("B", 8)]

sample = classi_e_val

store_alphabet_count = defaultdict(list)

for alphabet, count in sample:
    store_alphabet_count[alphabet].append(count)

result = [
    (key, sum(value) // len(value)) for key, value in store_alphabet_count.items()
]

print(result)


def media(istanza):
    lettere=[]
    solu=[]
    for i in range(len(istanza)):
        if istanza[i][0] not in lettere:
            lettere.append(istanza[i][0])
    for lettera in lettere:
        numero_lettera=0
        somma=0
        for i in range(len(istanza)):
            if istanza[i][0]==lettera:
                numero_lettera+=1
                somma+=istanza[i][1]
        solu.append((lettera,somma/numero_lettera))
    return(solu)
'''
# Out:
# '\nfrom itertools import groupby\nfrom operator import itemgetter\nfrom statistics import mean\n\n\n#s = [(\'A\', 1), (\'B\', 2), (\'C\', 3), (\'A\', 9), (\'B\', 8)]\ns = classi_e_val\ns2 = sorted(s, key=itemgetter(0))   # sorting the tuple based on 0th index\n\nprint([(k, int(mean(list(zip(*g))[1]))) for k, g in groupby(s2, itemgetter(0))])\n\n\nfrom collections import defaultdict\n\nsample = [("A", 1), ("B", 2), ("C", 3), ("A", 9), ("B", 8)]\n\nsample = classi_e_val\n\nstore_alphabet_count = defaultdict(list)\n\nfor alphabet, count in sample:\n    store_alphabet_count[alphabet].append(count)\n\nresult = [\n    (key, sum(value) // len(value)) for key, value in store_alphabet_count.items()\n]\n\nprint(result)\n\n\ndef media(istanza):\n    lettere=[]\n    solu=[]\n    for i in range(len(istanza)):\n        if istanza[i][0] not in lettere:\n            lettere.append(istanza[i][0])\n    for lettera in lettere:\n        numero_lettera=0\n        somma=0\n        for i in range(len(istanza)):\n            if istanza[i][0]==lettera:\n                numero_lettera+=1\n                somma+=istanza[i][1]\n        solu.append((lettera,somma/numero_lettera))\n    return(solu)\n'

# %%
obf_set = set()

for index in range(obf.size):
  for elem in obf[index].split('-'):
    obf_set.add(elem)

print("Trasformazioni applicate:")
print(sorted(obf_set))

sorted_obf_set = sorted(obf_set)
counter = 1
for elem in (sorted_obf_set):
  print("{}: {}".format(counter, elem))
  counter += 1
# Out:
# Trasformazioni applicate:
# ['EncodeArithmetic', 'EncodeLiterals', 'Flatten', 'InitEntropy', 'InitImplicitFlow', 'InitOpaque', 'RandomFuns', 'Split', 'base']
# 1: EncodeArithmetic
# 2: EncodeLiterals
# 3: Flatten
# 4: InitEntropy
# 5: InitImplicitFlow
# 6: InitOpaque
# 7: RandomFuns
# 8: Split
# 9: base

# %%
labels_set = set()

for index in range(obf.size):
  for elem in labels[index].split('-'):
    labels_set.add(elem)

print("Programmi (labels) analizzati:")

sorted_labels_set = sorted(labels_set)
counter = 1
for elem in (sorted_labels_set):
  print("{}: {}".format(counter, elem))
  counter += 1
# Out:
# Programmi (labels) analizzati:
# 1: alien_language
# 2: armstrong_n
# 3: bot_trust
# 4: calculator
# 5: candy_splitting
# 6: char_frequency
# 7: count_digits
# 8: count_vowels
# 9: factorial
# 10: factorial_rec
# 11: factors
# 12: fair_warning
# 13: fib_1
# 14: fib_2
# 15: fly_swatter
# 16: gcd
# 17: gcd_rec
# 18: hello_world
# 19: lcm
# 20: leap_year
# 21: magicka
# 22: minimum_scalar_product
# 23: multibase_happiness
# 24: n_is_palindrome
# 25: n_is_prime
# 26: n_is_sum_of_primes
# 27: positive_or_negative
# 28: power_n
# 29: prime_n_between_intervals
# 30: pyramid
# 31: quotient_remainder
# 32: remove_char
# 33: reverse_integer
# 34: rotate
# 35: saving_the_universe
# 36: snapper_chain
# 37: store_struct
# 38: strcat
# 39: strcpy
# 40: stringsort
# 41: strlen
# 42: sum
# 43: theme_park
# 44: times_table
# 45: train_time_table
# 46: watersheds
# 47: welcome_to_codejam

# %%
set_transformations = set()

for elem in obf:
  set_transformations.add(elem)

number_of_unique_trans = len(set_transformations)
print(number_of_unique_trans)

set_transformations_sorted = sorted(set_transformations)
# Out:
# 800

# %%
print("Trasformazioni applicate: ")
counter = 1
for elem in set_transformations_sorted:
  print("{}: {}".format(counter, elem))
  counter += 1
# Out:
# Trasformazioni applicate:
# 1: EncodeArithmetic
# 2: EncodeArithmetic-EncodeLiterals
# 3: EncodeArithmetic-EncodeLiterals-Flatten
# 4: EncodeArithmetic-EncodeLiterals-Flatten-Split
# 5: EncodeArithmetic-EncodeLiterals-InitEntropy
# 6: EncodeArithmetic-EncodeLiterals-InitEntropy-Split
# 7: EncodeArithmetic-EncodeLiterals-InitImplicitFlow
# 8: EncodeArithmetic-EncodeLiterals-InitImplicitFlow-Split
# 9: EncodeArithmetic-EncodeLiterals-InitOpaque
# 10: EncodeArithmetic-EncodeLiterals-InitOpaque-Split
# 11: EncodeArithmetic-EncodeLiterals-RandomFuns
# 12: EncodeArithmetic-EncodeLiterals-RandomFuns-Split
# 13: EncodeArithmetic-EncodeLiterals-Split
# 14: EncodeArithmetic-EncodeLiterals-Split-Flatten
# 15: EncodeArithmetic-EncodeLiterals-Split-InitEntropy
# 16: EncodeArithmetic-EncodeLiterals-Split-InitImplicitFlow
# 17: EncodeArithmetic-EncodeLiterals-Split-InitOpaque
# 18: EncodeArithmetic-EncodeLiterals-Split-RandomFuns
# 19: EncodeArithmetic-Flatten
# 20: EncodeArithmetic-Flatten-EncodeLiterals
# 21: EncodeArithmetic-Flatten-EncodeLiterals-Split
# 22: EncodeArithmetic-Flatten-InitEntropy
# 23: EncodeArithmetic-Flatten-InitImplicitFlow
# 24: EncodeArithmetic-Flatten-InitOpaque
# 25: EncodeArithmetic-Flatten-RandomFuns
# 26: EncodeArithmetic-Flatten-Split
# 27: EncodeArithmetic-Flatten-Split-EncodeLiterals
# 28: EncodeArithmetic-InitEntropy
# 29: EncodeArithmetic-InitEntropy-EncodeLiterals
# 30: EncodeArithmetic-InitEntropy-EncodeLiterals-Split
# 31: EncodeArithmetic-InitEntropy-Flatten
# 32: EncodeArithmetic-InitEntropy-InitImplicitFlow
# 33: EncodeArithmetic-InitEntropy-InitImplicitFlow-Split
# 34: EncodeArithmetic-InitEntropy-InitOpaque
# 35: EncodeArithmetic-InitEntropy-RandomFuns
# 36: EncodeArithmetic-InitEntropy-RandomFuns-Split
# 37: EncodeArithmetic-InitEntropy-Split
# 38: EncodeArithmetic-InitEntropy-Split-EncodeLiterals
# 39: EncodeArithmetic-InitEntropy-Split-InitImplicitFlow
# 40: EncodeArithmetic-InitEntropy-Split-RandomFuns
# 41: EncodeArithmetic-InitImplicitFlow
# 42: EncodeArithmetic-InitImplicitFlow-EncodeLiterals
# 43: EncodeArithmetic-InitImplicitFlow-EncodeLiterals-Split
# 44: EncodeArithmetic-InitImplicitFlow-Flatten
# 45: EncodeArithmetic-InitImplicitFlow-InitEntropy
# 46: EncodeArithmetic-InitImplicitFlow-InitEntropy-Split
# 47: EncodeArithmetic-InitImplicitFlow-InitOpaque
# 48: EncodeArithmetic-InitImplicitFlow-RandomFuns
# 49: EncodeArithmetic-InitImplicitFlow-Split
# 50: EncodeArithmetic-InitImplicitFlow-Split-EncodeLiterals
# 51: EncodeArithmetic-InitImplicitFlow-Split-InitEntropy
# 52: EncodeArithmetic-InitOpaque
# 53: EncodeArithmetic-InitOpaque-EncodeLiterals
# 54: EncodeArithmetic-InitOpaque-EncodeLiterals-Split
# 55: EncodeArithmetic-InitOpaque-Flatten
# 56: EncodeArithmetic-InitOpaque-InitEntropy
# 57: EncodeArithmetic-InitOpaque-InitImplicitFlow
# 58: EncodeArithmetic-InitOpaque-RandomFuns
# 59: EncodeArithmetic-InitOpaque-Split
# 60: EncodeArithmetic-InitOpaque-Split-EncodeLiterals
# 61: EncodeArithmetic-RandomFuns
# 62: EncodeArithmetic-RandomFuns-EncodeLiterals
# 63: EncodeArithmetic-RandomFuns-EncodeLiterals-Split
# 64: EncodeArithmetic-RandomFuns-Flatten
# 65: EncodeArithmetic-RandomFuns-InitEntropy
# 66: EncodeArithmetic-RandomFuns-InitEntropy-Split
# 67: EncodeArithmetic-RandomFuns-InitImplicitFlow
# 68: EncodeArithmetic-RandomFuns-InitOpaque
# 69: EncodeArithmetic-RandomFuns-Split
# 70: EncodeArithmetic-RandomFuns-Split-EncodeLiterals
# 71: EncodeArithmetic-RandomFuns-Split-InitEntropy
# 72: EncodeArithmetic-Split
# 73: EncodeArithmetic-Split-EncodeLiterals
# 74: EncodeArithmetic-Split-EncodeLiterals-Flatten
# 75: EncodeArithmetic-Split-EncodeLiterals-InitEntropy
# 76: EncodeArithmetic-Split-EncodeLiterals-InitImplicitFlow
# 77: EncodeArithmetic-Split-EncodeLiterals-InitOpaque
# 78: EncodeArithmetic-Split-EncodeLiterals-RandomFuns
# 79: EncodeArithmetic-Split-Flatten
# 80: EncodeArithmetic-Split-Flatten-EncodeLiterals
# 81: EncodeArithmetic-Split-InitEntropy
# 82: EncodeArithmetic-Split-InitEntropy-EncodeLiterals
# 83: EncodeArithmetic-Split-InitEntropy-InitImplicitFlow
# 84: EncodeArithmetic-Split-InitEntropy-RandomFuns
# 85: EncodeArithmetic-Split-InitImplicitFlow
# 86: EncodeArithmetic-Split-InitImplicitFlow-EncodeLiterals
# 87: EncodeArithmetic-Split-InitImplicitFlow-InitEntropy
# 88: EncodeArithmetic-Split-InitOpaque
# 89: EncodeArithmetic-Split-InitOpaque-EncodeLiterals
# 90: EncodeArithmetic-Split-RandomFuns
# 91: EncodeArithmetic-Split-RandomFuns-EncodeLiterals
# 92: EncodeArithmetic-Split-RandomFuns-InitEntropy
# 93: EncodeLiterals
# 94: EncodeLiterals-EncodeArithmetic
# 95: EncodeLiterals-EncodeArithmetic-Flatten
# 96: EncodeLiterals-EncodeArithmetic-Flatten-Split
# 97: EncodeLiterals-EncodeArithmetic-InitEntropy
# 98: EncodeLiterals-EncodeArithmetic-InitEntropy-Split
# 99: EncodeLiterals-EncodeArithmetic-InitImplicitFlow
# 100: EncodeLiterals-EncodeArithmetic-InitImplicitFlow-Split
# 101: EncodeLiterals-EncodeArithmetic-InitOpaque
# 102: EncodeLiterals-EncodeArithmetic-InitOpaque-Split
# 103: EncodeLiterals-EncodeArithmetic-RandomFuns
# 104: EncodeLiterals-EncodeArithmetic-RandomFuns-Split
# 105: EncodeLiterals-EncodeArithmetic-Split
# 106: EncodeLiterals-EncodeArithmetic-Split-Flatten
# 107: EncodeLiterals-EncodeArithmetic-Split-InitEntropy
# 108: EncodeLiterals-EncodeArithmetic-Split-InitImplicitFlow
# 109: EncodeLiterals-EncodeArithmetic-Split-InitOpaque
# 110: EncodeLiterals-EncodeArithmetic-Split-RandomFuns
# 111: EncodeLiterals-Flatten
# 112: EncodeLiterals-Flatten-EncodeArithmetic
# 113: EncodeLiterals-Flatten-EncodeArithmetic-Split
# 114: EncodeLiterals-Flatten-InitEntropy
# 115: EncodeLiterals-Flatten-InitEntropy-Split
# 116: EncodeLiterals-Flatten-InitImplicitFlow
# 117: EncodeLiterals-Flatten-InitImplicitFlow-Split
# 118: EncodeLiterals-Flatten-InitOpaque
# 119: EncodeLiterals-Flatten-InitOpaque-Split
# 120: EncodeLiterals-Flatten-RandomFuns
# 121: EncodeLiterals-Flatten-RandomFuns-Split
# 122: EncodeLiterals-Flatten-Split
# 123: EncodeLiterals-Flatten-Split-EncodeArithmetic
# 124: EncodeLiterals-Flatten-Split-InitEntropy
# 125: EncodeLiterals-Flatten-Split-InitImplicitFlow
# 126: EncodeLiterals-Flatten-Split-InitOpaque
# 127: EncodeLiterals-Flatten-Split-RandomFuns
# 128: EncodeLiterals-InitEntropy
# 129: EncodeLiterals-InitEntropy-EncodeArithmetic
# 130: EncodeLiterals-InitEntropy-EncodeArithmetic-Split
# 131: EncodeLiterals-InitEntropy-Flatten
# 132: EncodeLiterals-InitEntropy-Flatten-Split
# 133: EncodeLiterals-InitEntropy-InitImplicitFlow
# 134: EncodeLiterals-InitEntropy-InitImplicitFlow-Split
# 135: EncodeLiterals-InitEntropy-InitOpaque
# 136: EncodeLiterals-InitEntropy-InitOpaque-Split
# 137: EncodeLiterals-InitEntropy-RandomFuns
# 138: EncodeLiterals-InitEntropy-RandomFuns-Split
# 139: EncodeLiterals-InitEntropy-Split
# 140: EncodeLiterals-InitEntropy-Split-EncodeArithmetic
# 141: EncodeLiterals-InitEntropy-Split-Flatten
# 142: EncodeLiterals-InitEntropy-Split-InitImplicitFlow
# 143: EncodeLiterals-InitEntropy-Split-InitOpaque
# 144: EncodeLiterals-InitEntropy-Split-RandomFuns
# 145: EncodeLiterals-InitImplicitFlow
# 146: EncodeLiterals-InitImplicitFlow-EncodeArithmetic
# 147: EncodeLiterals-InitImplicitFlow-EncodeArithmetic-Split
# 148: EncodeLiterals-InitImplicitFlow-Flatten
# 149: EncodeLiterals-InitImplicitFlow-Flatten-Split
# 150: EncodeLiterals-InitImplicitFlow-InitEntropy
# 151: EncodeLiterals-InitImplicitFlow-InitEntropy-Split
# 152: EncodeLiterals-InitImplicitFlow-InitOpaque
# 153: EncodeLiterals-InitImplicitFlow-InitOpaque-Split
# 154: EncodeLiterals-InitImplicitFlow-RandomFuns
# 155: EncodeLiterals-InitImplicitFlow-RandomFuns-Split
# 156: EncodeLiterals-InitImplicitFlow-Split
# 157: EncodeLiterals-InitImplicitFlow-Split-EncodeArithmetic
# 158: EncodeLiterals-InitImplicitFlow-Split-Flatten
# 159: EncodeLiterals-InitImplicitFlow-Split-InitEntropy
# 160: EncodeLiterals-InitImplicitFlow-Split-InitOpaque
# 161: EncodeLiterals-InitImplicitFlow-Split-RandomFuns
# 162: EncodeLiterals-InitOpaque
# 163: EncodeLiterals-InitOpaque-EncodeArithmetic
# 164: EncodeLiterals-InitOpaque-EncodeArithmetic-Split
# 165: EncodeLiterals-InitOpaque-Flatten
# 166: EncodeLiterals-InitOpaque-Flatten-Split
# 167: EncodeLiterals-InitOpaque-InitEntropy
# 168: EncodeLiterals-InitOpaque-InitEntropy-Split
# 169: EncodeLiterals-InitOpaque-InitImplicitFlow
# 170: EncodeLiterals-InitOpaque-InitImplicitFlow-Split
# 171: EncodeLiterals-InitOpaque-RandomFuns
# 172: EncodeLiterals-InitOpaque-RandomFuns-Split
# 173: EncodeLiterals-InitOpaque-Split
# 174: EncodeLiterals-InitOpaque-Split-EncodeArithmetic
# 175: EncodeLiterals-InitOpaque-Split-Flatten
# 176: EncodeLiterals-InitOpaque-Split-InitEntropy
# 177: EncodeLiterals-InitOpaque-Split-InitImplicitFlow
# 178: EncodeLiterals-InitOpaque-Split-RandomFuns
# 179: EncodeLiterals-RandomFuns
# 180: EncodeLiterals-RandomFuns-EncodeArithmetic
# 181: EncodeLiterals-RandomFuns-EncodeArithmetic-Split
# 182: EncodeLiterals-RandomFuns-Flatten
# 183: EncodeLiterals-RandomFuns-Flatten-Split
# 184: EncodeLiterals-RandomFuns-InitEntropy
# 185: EncodeLiterals-RandomFuns-InitEntropy-Split
# 186: EncodeLiterals-RandomFuns-InitImplicitFlow
# 187: EncodeLiterals-RandomFuns-InitImplicitFlow-Split
# 188: EncodeLiterals-RandomFuns-InitOpaque
# 189: EncodeLiterals-RandomFuns-InitOpaque-Split
# 190: EncodeLiterals-RandomFuns-Split
# 191: EncodeLiterals-RandomFuns-Split-EncodeArithmetic
# 192: EncodeLiterals-RandomFuns-Split-Flatten
# 193: EncodeLiterals-RandomFuns-Split-InitEntropy
# 194: EncodeLiterals-RandomFuns-Split-InitImplicitFlow
# 195: EncodeLiterals-RandomFuns-Split-InitOpaque
# 196: EncodeLiterals-Split
# 197: EncodeLiterals-Split-EncodeArithmetic
# 198: EncodeLiterals-Split-EncodeArithmetic-Flatten
# 199: EncodeLiterals-Split-EncodeArithmetic-InitEntropy
# 200: EncodeLiterals-Split-EncodeArithmetic-InitImplicitFlow
# 201: EncodeLiterals-Split-EncodeArithmetic-InitOpaque
# 202: EncodeLiterals-Split-EncodeArithmetic-RandomFuns
# 203: EncodeLiterals-Split-Flatten
# 204: EncodeLiterals-Split-Flatten-EncodeArithmetic
# 205: EncodeLiterals-Split-Flatten-InitEntropy
# 206: EncodeLiterals-Split-Flatten-InitImplicitFlow
# 207: EncodeLiterals-Split-Flatten-InitOpaque
# 208: EncodeLiterals-Split-Flatten-RandomFuns
# 209: EncodeLiterals-Split-InitEntropy
# 210: EncodeLiterals-Split-InitEntropy-EncodeArithmetic
# 211: EncodeLiterals-Split-InitEntropy-Flatten
# 212: EncodeLiterals-Split-InitEntropy-InitImplicitFlow
# 213: EncodeLiterals-Split-InitEntropy-InitOpaque
# 214: EncodeLiterals-Split-InitEntropy-RandomFuns
# 215: EncodeLiterals-Split-InitImplicitFlow
# 216: EncodeLiterals-Split-InitImplicitFlow-EncodeArithmetic
# 217: EncodeLiterals-Split-InitImplicitFlow-Flatten
# 218: EncodeLiterals-Split-InitImplicitFlow-InitEntropy
# 219: EncodeLiterals-Split-InitImplicitFlow-InitOpaque
# 220: EncodeLiterals-Split-InitImplicitFlow-RandomFuns
# 221: EncodeLiterals-Split-InitOpaque
# 222: EncodeLiterals-Split-InitOpaque-EncodeArithmetic
# 223: EncodeLiterals-Split-InitOpaque-Flatten
# 224: EncodeLiterals-Split-InitOpaque-InitEntropy
# 225: EncodeLiterals-Split-InitOpaque-InitImplicitFlow
# 226: EncodeLiterals-Split-InitOpaque-RandomFuns
# 227: EncodeLiterals-Split-RandomFuns
# 228: EncodeLiterals-Split-RandomFuns-EncodeArithmetic
# 229: EncodeLiterals-Split-RandomFuns-Flatten
# 230: EncodeLiterals-Split-RandomFuns-InitEntropy
# 231: EncodeLiterals-Split-RandomFuns-InitImplicitFlow
# 232: EncodeLiterals-Split-RandomFuns-InitOpaque
# 233: Flatten
# 234: Flatten-EncodeArithmetic
# 235: Flatten-EncodeArithmetic-EncodeLiterals
# 236: Flatten-EncodeArithmetic-EncodeLiterals-Split
# 237: Flatten-EncodeArithmetic-InitEntropy
# 238: Flatten-EncodeArithmetic-InitImplicitFlow
# 239: Flatten-EncodeArithmetic-InitOpaque
# 240: Flatten-EncodeArithmetic-RandomFuns
# 241: Flatten-EncodeArithmetic-Split
# 242: Flatten-EncodeArithmetic-Split-EncodeLiterals
# 243: Flatten-EncodeLiterals
# 244: Flatten-EncodeLiterals-EncodeArithmetic
# 245: Flatten-EncodeLiterals-EncodeArithmetic-Split
# 246: Flatten-EncodeLiterals-InitEntropy
# 247: Flatten-EncodeLiterals-InitEntropy-Split
# 248: Flatten-EncodeLiterals-InitImplicitFlow
# 249: Flatten-EncodeLiterals-InitImplicitFlow-Split
# 250: Flatten-EncodeLiterals-InitOpaque
# 251: Flatten-EncodeLiterals-InitOpaque-Split
# 252: Flatten-EncodeLiterals-RandomFuns
# 253: Flatten-EncodeLiterals-RandomFuns-Split
# 254: Flatten-EncodeLiterals-Split
# 255: Flatten-EncodeLiterals-Split-EncodeArithmetic
# 256: Flatten-EncodeLiterals-Split-InitEntropy
# 257: Flatten-EncodeLiterals-Split-InitImplicitFlow
# 258: Flatten-EncodeLiterals-Split-InitOpaque
# 259: Flatten-EncodeLiterals-Split-RandomFuns
# 260: Flatten-InitEntropy
# 261: Flatten-InitEntropy-EncodeArithmetic
# 262: Flatten-InitEntropy-EncodeLiterals
# 263: Flatten-InitEntropy-EncodeLiterals-Split
# 264: Flatten-InitEntropy-InitImplicitFlow
# 265: Flatten-InitEntropy-InitOpaque
# 266: Flatten-InitEntropy-RandomFuns
# 267: Flatten-InitEntropy-Split
# 268: Flatten-InitEntropy-Split-EncodeLiterals
# 269: Flatten-InitImplicitFlow
# 270: Flatten-InitImplicitFlow-EncodeArithmetic
# 271: Flatten-InitImplicitFlow-EncodeLiterals
# 272: Flatten-InitImplicitFlow-EncodeLiterals-Split
# 273: Flatten-InitImplicitFlow-InitEntropy
# 274: Flatten-InitImplicitFlow-InitOpaque
# 275: Flatten-InitImplicitFlow-RandomFuns
# 276: Flatten-InitImplicitFlow-Split
# 277: Flatten-InitImplicitFlow-Split-EncodeLiterals
# 278: Flatten-InitOpaque
# 279: Flatten-InitOpaque-EncodeArithmetic
# 280: Flatten-InitOpaque-EncodeLiterals
# 281: Flatten-InitOpaque-EncodeLiterals-Split
# 282: Flatten-InitOpaque-InitEntropy
# 283: Flatten-InitOpaque-InitImplicitFlow
# 284: Flatten-InitOpaque-RandomFuns
# 285: Flatten-InitOpaque-Split
# 286: Flatten-InitOpaque-Split-EncodeLiterals
# 287: Flatten-RandomFuns
# 288: Flatten-RandomFuns-EncodeArithmetic
# 289: Flatten-RandomFuns-EncodeLiterals
# 290: Flatten-RandomFuns-EncodeLiterals-Split
# 291: Flatten-RandomFuns-InitEntropy
# 292: Flatten-RandomFuns-InitImplicitFlow
# 293: Flatten-RandomFuns-InitOpaque
# 294: Flatten-RandomFuns-Split
# 295: Flatten-RandomFuns-Split-EncodeLiterals
# 296: Flatten-Split
# 297: Flatten-Split-EncodeArithmetic
# 298: Flatten-Split-EncodeArithmetic-EncodeLiterals
# 299: Flatten-Split-EncodeLiterals
# 300: Flatten-Split-EncodeLiterals-EncodeArithmetic
# 301: Flatten-Split-EncodeLiterals-InitEntropy
# 302: Flatten-Split-EncodeLiterals-InitImplicitFlow
# 303: Flatten-Split-EncodeLiterals-InitOpaque
# 304: Flatten-Split-EncodeLiterals-RandomFuns
# 305: Flatten-Split-InitEntropy
# 306: Flatten-Split-InitEntropy-EncodeLiterals
# 307: Flatten-Split-InitImplicitFlow
# 308: Flatten-Split-InitImplicitFlow-EncodeLiterals
# 309: Flatten-Split-InitOpaque
# 310: Flatten-Split-InitOpaque-EncodeLiterals
# 311: Flatten-Split-RandomFuns
# 312: Flatten-Split-RandomFuns-EncodeLiterals
# 313: InitEntropy
# 314: InitEntropy-EncodeArithmetic
# 315: InitEntropy-EncodeArithmetic-EncodeLiterals
# 316: InitEntropy-EncodeArithmetic-EncodeLiterals-Split
# 317: InitEntropy-EncodeArithmetic-Flatten
# 318: InitEntropy-EncodeArithmetic-InitImplicitFlow
# 319: InitEntropy-EncodeArithmetic-InitOpaque
# 320: InitEntropy-EncodeArithmetic-RandomFuns
# 321: InitEntropy-EncodeArithmetic-RandomFuns-Split
# 322: InitEntropy-EncodeArithmetic-Split
# 323: InitEntropy-EncodeArithmetic-Split-EncodeLiterals
# 324: InitEntropy-EncodeArithmetic-Split-InitImplicitFlow
# 325: InitEntropy-EncodeArithmetic-Split-RandomFuns
# 326: InitEntropy-EncodeLiterals
# 327: InitEntropy-EncodeLiterals-EncodeArithmetic
# 328: InitEntropy-EncodeLiterals-EncodeArithmetic-Split
# 329: InitEntropy-EncodeLiterals-Flatten
# 330: InitEntropy-EncodeLiterals-Flatten-Split
# 331: InitEntropy-EncodeLiterals-InitImplicitFlow
# 332: InitEntropy-EncodeLiterals-InitImplicitFlow-Split
# 333: InitEntropy-EncodeLiterals-InitOpaque
# 334: InitEntropy-EncodeLiterals-InitOpaque-Split
# 335: InitEntropy-EncodeLiterals-RandomFuns
# 336: InitEntropy-EncodeLiterals-RandomFuns-Split
# 337: InitEntropy-EncodeLiterals-Split
# 338: InitEntropy-EncodeLiterals-Split-EncodeArithmetic
# 339: InitEntropy-EncodeLiterals-Split-Flatten
# 340: InitEntropy-EncodeLiterals-Split-InitImplicitFlow
# 341: InitEntropy-EncodeLiterals-Split-InitOpaque
# 342: InitEntropy-EncodeLiterals-Split-RandomFuns
# 343: InitEntropy-Flatten
# 344: InitEntropy-Flatten-EncodeArithmetic
# 345: InitEntropy-Flatten-EncodeLiterals
# 346: InitEntropy-Flatten-EncodeLiterals-Split
# 347: InitEntropy-Flatten-InitImplicitFlow
# 348: InitEntropy-Flatten-InitOpaque
# 349: InitEntropy-Flatten-RandomFuns
# 350: InitEntropy-Flatten-Split
# 351: InitEntropy-Flatten-Split-EncodeLiterals
# 352: InitEntropy-InitImplicitFlow
# 353: InitEntropy-InitImplicitFlow-EncodeArithmetic
# 354: InitEntropy-InitImplicitFlow-EncodeLiterals
# 355: InitEntropy-InitImplicitFlow-EncodeLiterals-Split
# 356: InitEntropy-InitImplicitFlow-Flatten
# 357: InitEntropy-InitImplicitFlow-InitOpaque
# 358: InitEntropy-InitImplicitFlow-RandomFuns
# 359: InitEntropy-InitImplicitFlow-Split
# 360: InitEntropy-InitImplicitFlow-Split-EncodeLiterals
# 361: InitEntropy-InitOpaque
# 362: InitEntropy-InitOpaque-EncodeArithmetic
# 363: InitEntropy-InitOpaque-EncodeLiterals
# 364: InitEntropy-InitOpaque-EncodeLiterals-Split
# 365: InitEntropy-InitOpaque-Flatten
# 366: InitEntropy-InitOpaque-InitImplicitFlow
# 367: InitEntropy-InitOpaque-RandomFuns
# 368: InitEntropy-InitOpaque-Split
# 369: InitEntropy-InitOpaque-Split-EncodeLiterals
# 370: InitEntropy-RandomFuns
# 371: InitEntropy-RandomFuns-EncodeArithmetic
# 372: InitEntropy-RandomFuns-EncodeArithmetic-Split
# 373: InitEntropy-RandomFuns-EncodeLiterals
# 374: InitEntropy-RandomFuns-EncodeLiterals-Split
# 375: InitEntropy-RandomFuns-Flatten
# 376: InitEntropy-RandomFuns-InitImplicitFlow
# 377: InitEntropy-RandomFuns-InitOpaque
# 378: InitEntropy-RandomFuns-Split
# 379: InitEntropy-RandomFuns-Split-EncodeArithmetic
# 380: InitEntropy-RandomFuns-Split-EncodeLiterals
# 381: InitEntropy-Split
# 382: InitEntropy-Split-EncodeArithmetic
# 383: InitEntropy-Split-EncodeArithmetic-EncodeLiterals
# 384: InitEntropy-Split-EncodeArithmetic-InitImplicitFlow
# 385: InitEntropy-Split-EncodeArithmetic-RandomFuns
# 386: InitEntropy-Split-EncodeLiterals
# 387: InitEntropy-Split-EncodeLiterals-EncodeArithmetic
# 388: InitEntropy-Split-EncodeLiterals-Flatten
# 389: InitEntropy-Split-EncodeLiterals-InitImplicitFlow
# 390: InitEntropy-Split-EncodeLiterals-InitOpaque
# 391: InitEntropy-Split-EncodeLiterals-RandomFuns
# 392: InitEntropy-Split-Flatten
# 393: InitEntropy-Split-Flatten-EncodeLiterals
# 394: InitEntropy-Split-InitImplicitFlow
# 395: InitEntropy-Split-InitImplicitFlow-EncodeArithmetic
# 396: InitEntropy-Split-InitImplicitFlow-EncodeLiterals
# 397: InitEntropy-Split-InitOpaque
# 398: InitEntropy-Split-InitOpaque-EncodeLiterals
# 399: InitEntropy-Split-RandomFuns
# 400: InitEntropy-Split-RandomFuns-EncodeArithmetic
# 401: InitEntropy-Split-RandomFuns-EncodeLiterals
# 402: InitImplicitFlow
# 403: InitImplicitFlow-EncodeArithmetic
# 404: InitImplicitFlow-EncodeArithmetic-EncodeLiterals
# 405: InitImplicitFlow-EncodeArithmetic-EncodeLiterals-Split
# 406: InitImplicitFlow-EncodeArithmetic-Flatten
# 407: InitImplicitFlow-EncodeArithmetic-InitEntropy
# 408: InitImplicitFlow-EncodeArithmetic-InitOpaque
# 409: InitImplicitFlow-EncodeArithmetic-RandomFuns
# 410: InitImplicitFlow-EncodeArithmetic-Split
# 411: InitImplicitFlow-EncodeArithmetic-Split-EncodeLiterals
# 412: InitImplicitFlow-EncodeLiterals
# 413: InitImplicitFlow-EncodeLiterals-EncodeArithmetic
# 414: InitImplicitFlow-EncodeLiterals-EncodeArithmetic-Split
# 415: InitImplicitFlow-EncodeLiterals-Flatten
# 416: InitImplicitFlow-EncodeLiterals-Flatten-Split
# 417: InitImplicitFlow-EncodeLiterals-InitEntropy
# 418: InitImplicitFlow-EncodeLiterals-InitEntropy-Split
# 419: InitImplicitFlow-EncodeLiterals-InitOpaque
# 420: InitImplicitFlow-EncodeLiterals-InitOpaque-Split
# 421: InitImplicitFlow-EncodeLiterals-RandomFuns
# 422: InitImplicitFlow-EncodeLiterals-RandomFuns-Split
# 423: InitImplicitFlow-EncodeLiterals-Split
# 424: InitImplicitFlow-EncodeLiterals-Split-EncodeArithmetic
# 425: InitImplicitFlow-EncodeLiterals-Split-Flatten
# 426: InitImplicitFlow-EncodeLiterals-Split-InitEntropy
# 427: InitImplicitFlow-EncodeLiterals-Split-InitOpaque
# 428: InitImplicitFlow-EncodeLiterals-Split-RandomFuns
# 429: InitImplicitFlow-Flatten
# 430: InitImplicitFlow-Flatten-EncodeArithmetic
# 431: InitImplicitFlow-Flatten-EncodeLiterals
# 432: InitImplicitFlow-Flatten-EncodeLiterals-Split
# 433: InitImplicitFlow-Flatten-InitEntropy
# 434: InitImplicitFlow-Flatten-InitOpaque
# 435: InitImplicitFlow-Flatten-RandomFuns
# 436: InitImplicitFlow-Flatten-Split
# 437: InitImplicitFlow-Flatten-Split-EncodeLiterals
# 438: InitImplicitFlow-InitEntropy
# 439: InitImplicitFlow-InitEntropy-EncodeArithmetic
# 440: InitImplicitFlow-InitEntropy-EncodeLiterals
# 441: InitImplicitFlow-InitEntropy-EncodeLiterals-Split
# 442: InitImplicitFlow-InitEntropy-Flatten
# 443: InitImplicitFlow-InitEntropy-InitOpaque
# 444: InitImplicitFlow-InitEntropy-RandomFuns
# 445: InitImplicitFlow-InitEntropy-Split
# 446: InitImplicitFlow-InitEntropy-Split-EncodeLiterals
# 447: InitImplicitFlow-InitOpaque
# 448: InitImplicitFlow-InitOpaque-EncodeArithmetic
# 449: InitImplicitFlow-InitOpaque-EncodeLiterals
# 450: InitImplicitFlow-InitOpaque-EncodeLiterals-Split
# 451: InitImplicitFlow-InitOpaque-Flatten
# 452: InitImplicitFlow-InitOpaque-InitEntropy
# 453: InitImplicitFlow-InitOpaque-RandomFuns
# 454: InitImplicitFlow-InitOpaque-Split
# 455: InitImplicitFlow-InitOpaque-Split-EncodeLiterals
# 456: InitImplicitFlow-RandomFuns
# 457: InitImplicitFlow-RandomFuns-EncodeArithmetic
# 458: InitImplicitFlow-RandomFuns-EncodeLiterals
# 459: InitImplicitFlow-RandomFuns-EncodeLiterals-Split
# 460: InitImplicitFlow-RandomFuns-Flatten
# 461: InitImplicitFlow-RandomFuns-InitEntropy
# 462: InitImplicitFlow-RandomFuns-InitOpaque
# 463: InitImplicitFlow-RandomFuns-Split
# 464: InitImplicitFlow-RandomFuns-Split-EncodeLiterals
# 465: InitImplicitFlow-Split
# 466: InitImplicitFlow-Split-EncodeArithmetic
# 467: InitImplicitFlow-Split-EncodeArithmetic-EncodeLiterals
# 468: InitImplicitFlow-Split-EncodeLiterals
# 469: InitImplicitFlow-Split-EncodeLiterals-EncodeArithmetic
# 470: InitImplicitFlow-Split-EncodeLiterals-Flatten
# 471: InitImplicitFlow-Split-EncodeLiterals-InitEntropy
# 472: InitImplicitFlow-Split-EncodeLiterals-InitOpaque
# 473: InitImplicitFlow-Split-EncodeLiterals-RandomFuns
# 474: InitImplicitFlow-Split-Flatten
# 475: InitImplicitFlow-Split-Flatten-EncodeLiterals
# 476: InitImplicitFlow-Split-InitEntropy
# 477: InitImplicitFlow-Split-InitEntropy-EncodeLiterals
# 478: InitImplicitFlow-Split-InitOpaque
# 479: InitImplicitFlow-Split-InitOpaque-EncodeLiterals
# 480: InitImplicitFlow-Split-RandomFuns
# 481: InitImplicitFlow-Split-RandomFuns-EncodeLiterals
# 482: InitOpaque
# 483: InitOpaque-EncodeArithmetic
# 484: InitOpaque-EncodeArithmetic-EncodeLiterals
# 485: InitOpaque-EncodeArithmetic-EncodeLiterals-Split
# 486: InitOpaque-EncodeArithmetic-Flatten
# 487: InitOpaque-EncodeArithmetic-InitEntropy
# 488: InitOpaque-EncodeArithmetic-InitImplicitFlow
# 489: InitOpaque-EncodeArithmetic-RandomFuns
# 490: InitOpaque-EncodeArithmetic-Split
# 491: InitOpaque-EncodeArithmetic-Split-EncodeLiterals
# 492: InitOpaque-EncodeLiterals
# 493: InitOpaque-EncodeLiterals-EncodeArithmetic
# 494: InitOpaque-EncodeLiterals-EncodeArithmetic-Split
# 495: InitOpaque-EncodeLiterals-Flatten
# 496: InitOpaque-EncodeLiterals-Flatten-Split
# 497: InitOpaque-EncodeLiterals-InitEntropy
# 498: InitOpaque-EncodeLiterals-InitEntropy-Split
# 499: InitOpaque-EncodeLiterals-InitImplicitFlow
# 500: InitOpaque-EncodeLiterals-InitImplicitFlow-Split
# 501: InitOpaque-EncodeLiterals-RandomFuns
# 502: InitOpaque-EncodeLiterals-RandomFuns-Split
# 503: InitOpaque-EncodeLiterals-Split
# 504: InitOpaque-EncodeLiterals-Split-EncodeArithmetic
# 505: InitOpaque-EncodeLiterals-Split-Flatten
# 506: InitOpaque-EncodeLiterals-Split-InitEntropy
# 507: InitOpaque-EncodeLiterals-Split-InitImplicitFlow
# 508: InitOpaque-EncodeLiterals-Split-RandomFuns
# 509: InitOpaque-Flatten
# 510: InitOpaque-Flatten-EncodeArithmetic
# 511: InitOpaque-Flatten-EncodeLiterals
# 512: InitOpaque-Flatten-EncodeLiterals-Split
# 513: InitOpaque-Flatten-InitEntropy
# 514: InitOpaque-Flatten-InitImplicitFlow
# 515: InitOpaque-Flatten-RandomFuns
# 516: InitOpaque-Flatten-Split
# 517: InitOpaque-Flatten-Split-EncodeLiterals
# 518: InitOpaque-InitEntropy
# 519: InitOpaque-InitEntropy-EncodeArithmetic
# 520: InitOpaque-InitEntropy-EncodeLiterals
# 521: InitOpaque-InitEntropy-EncodeLiterals-Split
# 522: InitOpaque-InitEntropy-Flatten
# 523: InitOpaque-InitEntropy-InitImplicitFlow
# 524: InitOpaque-InitEntropy-RandomFuns
# 525: InitOpaque-InitEntropy-Split
# 526: InitOpaque-InitEntropy-Split-EncodeLiterals
# 527: InitOpaque-InitImplicitFlow
# 528: InitOpaque-InitImplicitFlow-EncodeArithmetic
# 529: InitOpaque-InitImplicitFlow-EncodeLiterals
# 530: InitOpaque-InitImplicitFlow-EncodeLiterals-Split
# 531: InitOpaque-InitImplicitFlow-Flatten
# 532: InitOpaque-InitImplicitFlow-InitEntropy
# 533: InitOpaque-InitImplicitFlow-RandomFuns
# 534: InitOpaque-InitImplicitFlow-Split
# 535: InitOpaque-InitImplicitFlow-Split-EncodeLiterals
# 536: InitOpaque-RandomFuns
# 537: InitOpaque-RandomFuns-EncodeArithmetic
# 538: InitOpaque-RandomFuns-EncodeLiterals
# 539: InitOpaque-RandomFuns-EncodeLiterals-Split
# 540: InitOpaque-RandomFuns-Flatten
# 541: InitOpaque-RandomFuns-InitEntropy
# 542: InitOpaque-RandomFuns-InitImplicitFlow
# 543: InitOpaque-RandomFuns-Split
# 544: InitOpaque-RandomFuns-Split-EncodeLiterals
# 545: InitOpaque-Split
# 546: InitOpaque-Split-EncodeArithmetic
# 547: InitOpaque-Split-EncodeArithmetic-EncodeLiterals
# 548: InitOpaque-Split-EncodeLiterals
# 549: InitOpaque-Split-EncodeLiterals-EncodeArithmetic
# 550: InitOpaque-Split-EncodeLiterals-Flatten
# 551: InitOpaque-Split-EncodeLiterals-InitEntropy
# 552: InitOpaque-Split-EncodeLiterals-InitImplicitFlow
# 553: InitOpaque-Split-EncodeLiterals-RandomFuns
# 554: InitOpaque-Split-Flatten
# 555: InitOpaque-Split-Flatten-EncodeLiterals
# 556: InitOpaque-Split-InitEntropy
# 557: InitOpaque-Split-InitEntropy-EncodeLiterals
# 558: InitOpaque-Split-InitImplicitFlow
# 559: InitOpaque-Split-InitImplicitFlow-EncodeLiterals
# 560: InitOpaque-Split-RandomFuns
# 561: InitOpaque-Split-RandomFuns-EncodeLiterals
# 562: RandomFuns
# 563: RandomFuns-EncodeArithmetic
# 564: RandomFuns-EncodeArithmetic-EncodeLiterals
# 565: RandomFuns-EncodeArithmetic-EncodeLiterals-Split
# 566: RandomFuns-EncodeArithmetic-Flatten
# 567: RandomFuns-EncodeArithmetic-InitEntropy
# 568: RandomFuns-EncodeArithmetic-InitEntropy-Split
# 569: RandomFuns-EncodeArithmetic-InitImplicitFlow
# 570: RandomFuns-EncodeArithmetic-InitOpaque
# 571: RandomFuns-EncodeArithmetic-Split
# 572: RandomFuns-EncodeArithmetic-Split-EncodeLiterals
# 573: RandomFuns-EncodeArithmetic-Split-InitEntropy
# 574: RandomFuns-EncodeLiterals
# 575: RandomFuns-EncodeLiterals-EncodeArithmetic
# 576: RandomFuns-EncodeLiterals-EncodeArithmetic-Split
# 577: RandomFuns-EncodeLiterals-Flatten
# 578: RandomFuns-EncodeLiterals-Flatten-Split
# 579: RandomFuns-EncodeLiterals-InitEntropy
# 580: RandomFuns-EncodeLiterals-InitEntropy-Split
# 581: RandomFuns-EncodeLiterals-InitImplicitFlow
# 582: RandomFuns-EncodeLiterals-InitImplicitFlow-Split
# 583: RandomFuns-EncodeLiterals-InitOpaque
# 584: RandomFuns-EncodeLiterals-InitOpaque-Split
# 585: RandomFuns-EncodeLiterals-Split
# 586: RandomFuns-EncodeLiterals-Split-EncodeArithmetic
# 587: RandomFuns-EncodeLiterals-Split-Flatten
# 588: RandomFuns-EncodeLiterals-Split-InitEntropy
# 589: RandomFuns-EncodeLiterals-Split-InitImplicitFlow
# 590: RandomFuns-EncodeLiterals-Split-InitOpaque
# 591: RandomFuns-Flatten
# 592: RandomFuns-Flatten-EncodeArithmetic
# 593: RandomFuns-Flatten-EncodeLiterals
# 594: RandomFuns-Flatten-EncodeLiterals-Split
# 595: RandomFuns-Flatten-InitEntropy
# 596: RandomFuns-Flatten-InitImplicitFlow
# 597: RandomFuns-Flatten-InitOpaque
# 598: RandomFuns-Flatten-Split
# 599: RandomFuns-Flatten-Split-EncodeLiterals
# 600: RandomFuns-InitEntropy
# 601: RandomFuns-InitEntropy-EncodeArithmetic
# 602: RandomFuns-InitEntropy-EncodeArithmetic-Split
# 603: RandomFuns-InitEntropy-EncodeLiterals
# 604: RandomFuns-InitEntropy-EncodeLiterals-Split
# 605: RandomFuns-InitEntropy-Flatten
# 606: RandomFuns-InitEntropy-InitImplicitFlow
# 607: RandomFuns-InitEntropy-InitOpaque
# 608: RandomFuns-InitEntropy-Split
# 609: RandomFuns-InitEntropy-Split-EncodeArithmetic
# 610: RandomFuns-InitEntropy-Split-EncodeLiterals
# 611: RandomFuns-InitImplicitFlow
# 612: RandomFuns-InitImplicitFlow-EncodeArithmetic
# 613: RandomFuns-InitImplicitFlow-EncodeLiterals
# 614: RandomFuns-InitImplicitFlow-EncodeLiterals-Split
# 615: RandomFuns-InitImplicitFlow-Flatten
# 616: RandomFuns-InitImplicitFlow-InitEntropy
# 617: RandomFuns-InitImplicitFlow-InitOpaque
# 618: RandomFuns-InitImplicitFlow-Split
# 619: RandomFuns-InitImplicitFlow-Split-EncodeLiterals
# 620: RandomFuns-InitOpaque
# 621: RandomFuns-InitOpaque-EncodeArithmetic
# 622: RandomFuns-InitOpaque-EncodeLiterals
# 623: RandomFuns-InitOpaque-EncodeLiterals-Split
# 624: RandomFuns-InitOpaque-Flatten
# 625: RandomFuns-InitOpaque-InitEntropy
# 626: RandomFuns-InitOpaque-InitImplicitFlow
# 627: RandomFuns-InitOpaque-Split
# 628: RandomFuns-InitOpaque-Split-EncodeLiterals
# 629: RandomFuns-Split
# 630: RandomFuns-Split-EncodeArithmetic
# 631: RandomFuns-Split-EncodeArithmetic-EncodeLiterals
# 632: RandomFuns-Split-EncodeArithmetic-InitEntropy
# 633: RandomFuns-Split-EncodeLiterals
# 634: RandomFuns-Split-EncodeLiterals-EncodeArithmetic
# 635: RandomFuns-Split-EncodeLiterals-Flatten
# 636: RandomFuns-Split-EncodeLiterals-InitEntropy
# 637: RandomFuns-Split-EncodeLiterals-InitImplicitFlow
# 638: RandomFuns-Split-EncodeLiterals-InitOpaque
# 639: RandomFuns-Split-Flatten
# 640: RandomFuns-Split-Flatten-EncodeLiterals
# 641: RandomFuns-Split-InitEntropy
# 642: RandomFuns-Split-InitEntropy-EncodeArithmetic
# 643: RandomFuns-Split-InitEntropy-EncodeLiterals
# 644: RandomFuns-Split-InitImplicitFlow
# 645: RandomFuns-Split-InitImplicitFlow-EncodeLiterals
# 646: RandomFuns-Split-InitOpaque
# 647: RandomFuns-Split-InitOpaque-EncodeLiterals
# 648: Split
# 649: Split-EncodeArithmetic
# 650: Split-EncodeArithmetic-EncodeLiterals
# 651: Split-EncodeArithmetic-EncodeLiterals-Flatten
# 652: Split-EncodeArithmetic-EncodeLiterals-InitEntropy
# 653: Split-EncodeArithmetic-EncodeLiterals-InitImplicitFlow
# 654: Split-EncodeArithmetic-EncodeLiterals-InitOpaque
# 655: Split-EncodeArithmetic-EncodeLiterals-RandomFuns
# 656: Split-EncodeArithmetic-Flatten
# 657: Split-EncodeArithmetic-Flatten-EncodeLiterals
# 658: Split-EncodeArithmetic-InitEntropy
# 659: Split-EncodeArithmetic-InitEntropy-EncodeLiterals
# 660: Split-EncodeArithmetic-InitEntropy-InitImplicitFlow
# 661: Split-EncodeArithmetic-InitEntropy-RandomFuns
# 662: Split-EncodeArithmetic-InitImplicitFlow
# 663: Split-EncodeArithmetic-InitImplicitFlow-EncodeLiterals
# 664: Split-EncodeArithmetic-InitImplicitFlow-InitEntropy
# 665: Split-EncodeArithmetic-InitOpaque
# 666: Split-EncodeArithmetic-InitOpaque-EncodeLiterals
# 667: Split-EncodeArithmetic-RandomFuns
# 668: Split-EncodeArithmetic-RandomFuns-EncodeLiterals
# 669: Split-EncodeArithmetic-RandomFuns-InitEntropy
# 670: Split-EncodeLiterals
# 671: Split-EncodeLiterals-EncodeArithmetic
# 672: Split-EncodeLiterals-EncodeArithmetic-Flatten
# 673: Split-EncodeLiterals-EncodeArithmetic-InitEntropy
# 674: Split-EncodeLiterals-EncodeArithmetic-InitImplicitFlow
# 675: Split-EncodeLiterals-EncodeArithmetic-InitOpaque
# 676: Split-EncodeLiterals-EncodeArithmetic-RandomFuns
# 677: Split-EncodeLiterals-Flatten
# 678: Split-EncodeLiterals-Flatten-EncodeArithmetic
# 679: Split-EncodeLiterals-Flatten-InitEntropy
# 680: Split-EncodeLiterals-Flatten-InitImplicitFlow
# 681: Split-EncodeLiterals-Flatten-InitOpaque
# 682: Split-EncodeLiterals-Flatten-RandomFuns
# 683: Split-EncodeLiterals-InitEntropy
# 684: Split-EncodeLiterals-InitEntropy-EncodeArithmetic
# 685: Split-EncodeLiterals-InitEntropy-Flatten
# 686: Split-EncodeLiterals-InitEntropy-InitImplicitFlow
# 687: Split-EncodeLiterals-InitEntropy-InitOpaque
# 688: Split-EncodeLiterals-InitEntropy-RandomFuns
# 689: Split-EncodeLiterals-InitImplicitFlow
# 690: Split-EncodeLiterals-InitImplicitFlow-EncodeArithmetic
# 691: Split-EncodeLiterals-InitImplicitFlow-Flatten
# 692: Split-EncodeLiterals-InitImplicitFlow-InitEntropy
# 693: Split-EncodeLiterals-InitImplicitFlow-InitOpaque
# 694: Split-EncodeLiterals-InitImplicitFlow-RandomFuns
# 695: Split-EncodeLiterals-InitOpaque
# 696: Split-EncodeLiterals-InitOpaque-EncodeArithmetic
# 697: Split-EncodeLiterals-InitOpaque-Flatten
# 698: Split-EncodeLiterals-InitOpaque-InitEntropy
# 699: Split-EncodeLiterals-InitOpaque-InitImplicitFlow
# 700: Split-EncodeLiterals-InitOpaque-RandomFuns
# 701: Split-EncodeLiterals-RandomFuns
# 702: Split-EncodeLiterals-RandomFuns-EncodeArithmetic
# 703: Split-EncodeLiterals-RandomFuns-Flatten
# 704: Split-EncodeLiterals-RandomFuns-InitEntropy
# 705: Split-EncodeLiterals-RandomFuns-InitImplicitFlow
# 706: Split-EncodeLiterals-RandomFuns-InitOpaque
# 707: Split-Flatten
# 708: Split-Flatten-EncodeArithmetic
# 709: Split-Flatten-EncodeArithmetic-EncodeLiterals
# 710: Split-Flatten-EncodeLiterals
# 711: Split-Flatten-EncodeLiterals-EncodeArithmetic
# 712: Split-Flatten-EncodeLiterals-InitEntropy
# 713: Split-Flatten-EncodeLiterals-InitImplicitFlow
# 714: Split-Flatten-EncodeLiterals-InitOpaque
# 715: Split-Flatten-EncodeLiterals-RandomFuns
# 716: Split-Flatten-InitEntropy
# 717: Split-Flatten-InitEntropy-EncodeLiterals
# 718: Split-Flatten-InitImplicitFlow
# 719: Split-Flatten-InitImplicitFlow-EncodeLiterals
# 720: Split-Flatten-InitOpaque
# 721: Split-Flatten-InitOpaque-EncodeLiterals
# 722: Split-Flatten-RandomFuns
# 723: Split-Flatten-RandomFuns-EncodeLiterals
# 724: Split-InitEntropy
# 725: Split-InitEntropy-EncodeArithmetic
# 726: Split-InitEntropy-EncodeArithmetic-EncodeLiterals
# 727: Split-InitEntropy-EncodeArithmetic-InitImplicitFlow
# 728: Split-InitEntropy-EncodeArithmetic-RandomFuns
# 729: Split-InitEntropy-EncodeLiterals
# 730: Split-InitEntropy-EncodeLiterals-EncodeArithmetic
# 731: Split-InitEntropy-EncodeLiterals-Flatten
# 732: Split-InitEntropy-EncodeLiterals-InitImplicitFlow
# 733: Split-InitEntropy-EncodeLiterals-InitOpaque
# 734: Split-InitEntropy-EncodeLiterals-RandomFuns
# 735: Split-InitEntropy-Flatten
# 736: Split-InitEntropy-Flatten-EncodeLiterals
# 737: Split-InitEntropy-InitImplicitFlow
# 738: Split-InitEntropy-InitImplicitFlow-EncodeArithmetic
# 739: Split-InitEntropy-InitImplicitFlow-EncodeLiterals
# 740: Split-InitEntropy-InitOpaque
# 741: Split-InitEntropy-InitOpaque-EncodeLiterals
# 742: Split-InitEntropy-RandomFuns
# 743: Split-InitEntropy-RandomFuns-EncodeArithmetic
# 744: Split-InitEntropy-RandomFuns-EncodeLiterals
# 745: Split-InitImplicitFlow
# 746: Split-InitImplicitFlow-EncodeArithmetic
# 747: Split-InitImplicitFlow-EncodeArithmetic-EncodeLiterals
# 748: Split-InitImplicitFlow-EncodeArithmetic-InitEntropy
# 749: Split-InitImplicitFlow-EncodeLiterals
# 750: Split-InitImplicitFlow-EncodeLiterals-EncodeArithmetic
# 751: Split-InitImplicitFlow-EncodeLiterals-Flatten
# 752: Split-InitImplicitFlow-EncodeLiterals-InitEntropy
# 753: Split-InitImplicitFlow-EncodeLiterals-InitOpaque
# 754: Split-InitImplicitFlow-EncodeLiterals-RandomFuns
# 755: Split-InitImplicitFlow-Flatten
# 756: Split-InitImplicitFlow-Flatten-EncodeLiterals
# 757: Split-InitImplicitFlow-InitEntropy
# 758: Split-InitImplicitFlow-InitEntropy-EncodeArithmetic
# 759: Split-InitImplicitFlow-InitEntropy-EncodeLiterals
# 760: Split-InitImplicitFlow-InitOpaque
# 761: Split-InitImplicitFlow-InitOpaque-EncodeLiterals
# 762: Split-InitImplicitFlow-RandomFuns
# 763: Split-InitImplicitFlow-RandomFuns-EncodeLiterals
# 764: Split-InitOpaque
# 765: Split-InitOpaque-EncodeArithmetic
# 766: Split-InitOpaque-EncodeArithmetic-EncodeLiterals
# 767: Split-InitOpaque-EncodeLiterals
# 768: Split-InitOpaque-EncodeLiterals-EncodeArithmetic
# 769: Split-InitOpaque-EncodeLiterals-Flatten
# 770: Split-InitOpaque-EncodeLiterals-InitEntropy
# 771: Split-InitOpaque-EncodeLiterals-InitImplicitFlow
# 772: Split-InitOpaque-EncodeLiterals-RandomFuns
# 773: Split-InitOpaque-Flatten
# 774: Split-InitOpaque-Flatten-EncodeLiterals
# 775: Split-InitOpaque-InitEntropy
# 776: Split-InitOpaque-InitEntropy-EncodeLiterals
# 777: Split-InitOpaque-InitImplicitFlow
# 778: Split-InitOpaque-InitImplicitFlow-EncodeLiterals
# 779: Split-InitOpaque-RandomFuns
# 780: Split-InitOpaque-RandomFuns-EncodeLiterals
# 781: Split-RandomFuns
# 782: Split-RandomFuns-EncodeArithmetic
# 783: Split-RandomFuns-EncodeArithmetic-EncodeLiterals
# 784: Split-RandomFuns-EncodeArithmetic-InitEntropy
# 785: Split-RandomFuns-EncodeLiterals
# 786: Split-RandomFuns-EncodeLiterals-EncodeArithmetic
# 787: Split-RandomFuns-EncodeLiterals-Flatten
# 788: Split-RandomFuns-EncodeLiterals-InitEntropy
# 789: Split-RandomFuns-EncodeLiterals-InitImplicitFlow
# 790: Split-RandomFuns-EncodeLiterals-InitOpaque
# 791: Split-RandomFuns-Flatten
# 792: Split-RandomFuns-Flatten-EncodeLiterals
# 793: Split-RandomFuns-InitEntropy
# 794: Split-RandomFuns-InitEntropy-EncodeArithmetic
# 795: Split-RandomFuns-InitEntropy-EncodeLiterals
# 796: Split-RandomFuns-InitImplicitFlow
# 797: Split-RandomFuns-InitImplicitFlow-EncodeLiterals
# 798: Split-RandomFuns-InitOpaque
# 799: Split-RandomFuns-InitOpaque-EncodeLiterals
# 800: base

# %%
def indices(lst, element):
    result = []
    offset = -1
    while True:
        try:
            offset = lst.index(element, offset+1)
        except ValueError:
            return result
        result.append(offset)

# %%
print("Programmi che non hanno tutte le trasformazioni, e trasformazioni da loro saltate:")

counterOk = 0
counterWrong = 0

for class_name in class_names:
  print("Analizzo la classe: " + class_name)

  set_of_obf_per_class = set()
  #setDiff = set()

  indici = indices(labels_list, class_name)

  for elem in indici:
    set_of_obf_per_class.add(obf_list[elem])


  setDiff = set_transformations - set_of_obf_per_class

  if len(setDiff) == 0:
    print("APPOSTO")
    counterOk += 1
  else:
    counterWrong += 1
    counterDiff = 1
    for elem in setDiff:
      print("{}: {}".format(counterDiff, elem))
      counterDiff += 1

print("{}: {}".format("Numero di classi senza problemi", counterOk))
print("{}: {}".format("Numero di classi CON problemi", counterWrong))
# Out:
# Programmi che non hanno tutte le trasformazioni, e trasformazioni da loro saltate:
# Analizzo la classe: fib_1
# APPOSTO
# Analizzo la classe: rotate
# APPOSTO
# Analizzo la classe: saving_the_universe
# APPOSTO
# Analizzo la classe: quotient_remainder
# APPOSTO
# Analizzo la classe: count_vowels
# APPOSTO
# Analizzo la classe: bot_trust
# APPOSTO
# Analizzo la classe: gcd_rec
# APPOSTO
# Analizzo la classe: n_is_prime
# APPOSTO
# Analizzo la classe: count_digits
# APPOSTO
# Analizzo la classe: sum
# APPOSTO
# Analizzo la classe: armstrong_n
# APPOSTO
# Analizzo la classe: pyramid
# APPOSTO
# Analizzo la classe: multibase_happiness
# APPOSTO
# Analizzo la classe: store_struct
# APPOSTO
# Analizzo la classe: strlen
# APPOSTO
# Analizzo la classe: watersheds
# APPOSTO
# Analizzo la classe: reverse_integer
# APPOSTO
# Analizzo la classe: stringsort
# APPOSTO
# Analizzo la classe: snapper_chain
# APPOSTO
# Analizzo la classe: positive_or_negative
# APPOSTO
# Analizzo la classe: char_frequency
# APPOSTO
# Analizzo la classe: gcd
# APPOSTO
# Analizzo la classe: power_n
# APPOSTO
# Analizzo la classe: factors
# APPOSTO
# Analizzo la classe: welcome_to_codejam
# APPOSTO
# Analizzo la classe: minimum_scalar_product
# APPOSTO
# Analizzo la classe: times_table
# APPOSTO
# Analizzo la classe: prime_n_between_intervals
# APPOSTO
# Analizzo la classe: alien_language
# 1: Split-EncodeLiterals-Flatten-RandomFuns
# 2: EncodeArithmetic-RandomFuns-Split-InitEntropy
# 3: Flatten-EncodeArithmetic-EncodeLiterals-Split
# 4: EncodeLiterals-Split-InitOpaque-Flatten
# 5: EncodeArithmetic-RandomFuns-Split-EncodeLiterals
# 6: EncodeLiterals-InitEntropy-Split-Flatten
# 7: Split-EncodeArithmetic-InitEntropy-InitImplicitFlow
# 8: EncodeLiterals-RandomFuns-EncodeArithmetic-Split
# 9: EncodeArithmetic-InitOpaque-Split-EncodeLiterals
# 10: EncodeLiterals-EncodeArithmetic-InitOpaque-Split
# 11: EncodeLiterals-InitImplicitFlow-InitEntropy-Split
# 12: Split-EncodeLiterals-InitImplicitFlow-RandomFuns
# 13: Split-InitOpaque-Flatten-EncodeLiterals
# 14: Flatten-InitOpaque-EncodeLiterals-Split
# 15: Split-EncodeLiterals-EncodeArithmetic-InitEntropy
# 16: EncodeArithmetic-InitOpaque-EncodeLiterals-Split
# 17: InitOpaque-Flatten-InitImplicitFlow
# 18: EncodeArithmetic-Split-RandomFuns-EncodeLiterals
# 19: Flatten-Split-EncodeLiterals-InitOpaque
# 20: Split-InitImplicitFlow-Flatten-EncodeLiterals
# 21: Split-RandomFuns-InitEntropy-EncodeArithmetic
# 22: EncodeLiterals-InitEntropy-Split-RandomFuns
# 23: Split-EncodeLiterals-RandomFuns-InitEntropy
# 24: EncodeArithmetic-Split-EncodeLiterals-RandomFuns
# 25: Split-Flatten-EncodeLiterals-InitEntropy
# 26: Split-InitEntropy-EncodeArithmetic-EncodeLiterals
# 27: Flatten-EncodeLiterals-EncodeArithmetic-Split
# 28: EncodeArithmetic-InitImplicitFlow-Split-InitEntropy
# 29: Flatten-RandomFuns-Split-EncodeLiterals
# 30: EncodeArithmetic-Split-Flatten-EncodeLiterals
# 31: InitImplicitFlow-Split-EncodeLiterals-EncodeArithmetic
# 32: InitEntropy-EncodeLiterals-Split-InitImplicitFlow
# 33: EncodeArithmetic-InitEntropy-Split-EncodeLiterals
# 34: EncodeArithmetic-Split-RandomFuns-InitEntropy
# 35: EncodeLiterals-EncodeArithmetic-Split-InitEntropy
# 36: EncodeLiterals-Split-InitEntropy-InitOpaque
# 37: RandomFuns-EncodeLiterals-Split-InitOpaque
# 38: EncodeArithmetic-InitEntropy-RandomFuns-Split
# 39: Split-RandomFuns-EncodeLiterals-InitImplicitFlow
# 40: EncodeLiterals-EncodeArithmetic-Split-RandomFuns
# 41: Split-EncodeLiterals-EncodeArithmetic-Flatten
# 42: InitOpaque-InitEntropy-EncodeLiterals-Split
# 43: EncodeLiterals-Split-RandomFuns-InitOpaque
# 44: InitEntropy-InitOpaque-EncodeLiterals-Split
# 45: EncodeArithmetic-Split-InitImplicitFlow-EncodeLiterals
# 46: Split-EncodeLiterals-RandomFuns-EncodeArithmetic
# 47: Split-EncodeArithmetic-InitImplicitFlow-EncodeLiterals
# 48: InitImplicitFlow-RandomFuns-EncodeLiterals-Split
# 49: InitImplicitFlow-Split-EncodeLiterals-InitEntropy
# 50: Flatten-Split-EncodeArithmetic-EncodeLiterals
# 51: RandomFuns-InitEntropy-Split-EncodeArithmetic
# 52: EncodeArithmetic-InitEntropy-Split-InitImplicitFlow
# 53: EncodeLiterals-Flatten-RandomFuns-Split
# 54: EncodeLiterals-InitEntropy-RandomFuns-Split
# 55: EncodeArithmetic-Split-EncodeLiterals-InitOpaque
# 56: Split-RandomFuns-EncodeArithmetic-EncodeLiterals
# 57: Split-InitEntropy-EncodeLiterals-RandomFuns
# 58: EncodeLiterals-Split-EncodeArithmetic-RandomFuns
# 59: EncodeArithmetic-InitImplicitFlow-Split-EncodeLiterals
# 60: InitImplicitFlow-Split-EncodeLiterals-InitOpaque
# 61: Split-EncodeLiterals-InitOpaque-InitEntropy
# 62: EncodeLiterals-Split-InitImplicitFlow-InitEntropy
# 63: InitEntropy-InitOpaque-Split-EncodeLiterals
# 64: InitOpaque-Split-EncodeArithmetic-EncodeLiterals
# 65: InitEntropy-Split-EncodeLiterals-EncodeArithmetic
# 66: Split-Flatten-InitOpaque-EncodeLiterals
# 67: Split-Flatten-EncodeLiterals-EncodeArithmetic
# 68: Flatten-Split-InitEntropy-EncodeLiterals
# 69: RandomFuns-Flatten-EncodeLiterals-Split
# 70: Split-InitOpaque-EncodeLiterals-InitEntropy
# 71: Flatten-EncodeLiterals-InitEntropy-Split
# 72: EncodeLiterals-InitOpaque-Split-Flatten
# 73: InitImplicitFlow-EncodeLiterals-RandomFuns-Split
# 74: InitImplicitFlow-EncodeArithmetic-Split-EncodeLiterals
# 75: EncodeLiterals-Split-InitOpaque-EncodeArithmetic
# 76: Split-Flatten-InitEntropy-EncodeLiterals
# 77: RandomFuns-Split-EncodeLiterals-Flatten
# 78: Split-InitEntropy-EncodeArithmetic-RandomFuns
# 79: RandomFuns-EncodeArithmetic-Split-InitEntropy
# 80: EncodeArithmetic-EncodeLiterals-RandomFuns-Split
# 81: RandomFuns-EncodeLiterals-Flatten-Split
# 82: EncodeArithmetic-InitImplicitFlow-EncodeLiterals-Split
# 83: InitOpaque-InitEntropy-Split-EncodeLiterals
# 84: Split-InitEntropy-EncodeLiterals-EncodeArithmetic
# 85: EncodeArithmetic-Split-InitEntropy-EncodeLiterals
# 86: InitOpaque-EncodeLiterals-InitEntropy-Split
# 87: EncodeLiterals-RandomFuns-Split-InitEntropy
# 88: InitOpaque-Split-InitEntropy-EncodeLiterals
# 89: EncodeLiterals-Split-Flatten-InitEntropy
# 90: EncodeLiterals-Split-EncodeArithmetic-InitImplicitFlow
# 91: EncodeLiterals-Flatten-InitEntropy-Split
# 92: InitOpaque-Split-Flatten-EncodeLiterals
# 93: Split-RandomFuns-EncodeLiterals-EncodeArithmetic
# 94: EncodeLiterals-Split-InitOpaque-RandomFuns
# 95: EncodeLiterals-InitOpaque-Flatten-Split
# 96: InitOpaque-Split-RandomFuns-EncodeLiterals
# 97: InitImplicitFlow-Split-InitOpaque-EncodeLiterals
# 98: Flatten-Split-InitOpaque-EncodeLiterals
# 99: Split-InitEntropy-RandomFuns-EncodeArithmetic
# 100: InitImplicitFlow-Split-RandomFuns-EncodeLiterals
# 101: EncodeLiterals-EncodeArithmetic-Flatten-Split
# 102: InitOpaque-EncodeLiterals-InitImplicitFlow-Split
# 103: EncodeArithmetic-EncodeLiterals-Split-Flatten
# 104: EncodeLiterals-Split-InitEntropy-Flatten
# 105: Flatten-InitOpaque-Split-EncodeLiterals
# 106: Split-EncodeArithmetic-InitEntropy-RandomFuns
# 107: RandomFuns-EncodeLiterals-EncodeArithmetic-Split
# 108: EncodeLiterals-Split-InitOpaque-InitEntropy
# 109: EncodeLiterals-Split-InitEntropy-RandomFuns
# 110: Split-InitOpaque-EncodeArithmetic-EncodeLiterals
# 111: InitEntropy-Split-RandomFuns-EncodeLiterals
# 112: InitOpaque-EncodeArithmetic-EncodeLiterals-Split
# 113: Flatten-EncodeLiterals-Split-InitImplicitFlow
# 114: Split-EncodeLiterals-RandomFuns-InitOpaque
# 115: Flatten-InitImplicitFlow-Split-EncodeLiterals
# 116: Flatten-InitEntropy-Split-EncodeLiterals
# 117: EncodeLiterals-InitEntropy-InitImplicitFlow-Split
# 118: InitEntropy-EncodeArithmetic-Split-InitImplicitFlow
# 119: InitEntropy-EncodeLiterals-InitOpaque-Split
# 120: InitImplicitFlow-InitOpaque-EncodeLiterals-Split
# 121: Flatten-Split-EncodeLiterals-EncodeArithmetic
# 122: EncodeArithmetic-InitEntropy-EncodeLiterals-Split
# 123: EncodeLiterals-InitEntropy-EncodeArithmetic-Split
# 124: Split-InitOpaque-EncodeLiterals-EncodeArithmetic
# 125: Split-EncodeLiterals-InitImplicitFlow-EncodeArithmetic
# 126: InitEntropy-Split-EncodeLiterals-InitOpaque
# 127: InitImplicitFlow-InitEntropy-EncodeLiterals-Split
# 128: EncodeLiterals-Split-EncodeArithmetic-InitEntropy
# 129: EncodeLiterals-EncodeArithmetic-RandomFuns-Split
# 130: InitOpaque-EncodeLiterals-EncodeArithmetic-Split
# 131: InitImplicitFlow-EncodeLiterals-Split-Flatten
# 132: Split-RandomFuns-InitImplicitFlow-EncodeLiterals
# 133: EncodeLiterals-RandomFuns-Flatten-Split
# 134: EncodeLiterals-RandomFuns-Split-InitOpaque
# 135: EncodeLiterals-Split-InitImplicitFlow-Flatten
# 136: InitImplicitFlow-EncodeLiterals-InitEntropy-Split
# 137: RandomFuns-Split-EncodeArithmetic-EncodeLiterals
# 138: InitEntropy-RandomFuns-EncodeLiterals-Split
# 139: RandomFuns-EncodeLiterals-Split-EncodeArithmetic
# 140: Split-EncodeArithmetic-RandomFuns-InitEntropy
# 141: InitEntropy-Split-InitOpaque-EncodeLiterals
# 142: RandomFuns-Split-InitImplicitFlow-EncodeLiterals
# 143: Split-EncodeLiterals-EncodeArithmetic-InitImplicitFlow
# 144: EncodeArithmetic-EncodeLiterals-InitImplicitFlow-Split
# 145: InitEntropy-EncodeLiterals-EncodeArithmetic-Split
# 146: EncodeLiterals-InitEntropy-Split-InitImplicitFlow
# 147: Split-InitEntropy-EncodeArithmetic-InitImplicitFlow
# 148: EncodeLiterals-InitImplicitFlow-Split-Flatten
# 149: Split-EncodeArithmetic-Flatten-EncodeLiterals
# 150: InitImplicitFlow-Split-EncodeArithmetic-EncodeLiterals
# 151: RandomFuns-InitEntropy-Split-EncodeLiterals
# 152: InitEntropy-Split-EncodeArithmetic-RandomFuns
# 153: InitImplicitFlow-Split-Flatten-EncodeLiterals
# 154: EncodeLiterals-EncodeArithmetic-InitEntropy-Split
# 155: InitEntropy-EncodeArithmetic-Split-EncodeLiterals
# 156: InitImplicitFlow-Flatten-Split-EncodeLiterals
# 157: EncodeLiterals-RandomFuns-InitOpaque-Split
# 158: RandomFuns-InitEntropy-EncodeArithmetic-Split
# 159: Split-EncodeLiterals-InitEntropy-InitImplicitFlow
# 160: EncodeArithmetic-RandomFuns-EncodeLiterals-Split
# 161: InitEntropy-EncodeLiterals-Split-Flatten
# 162: RandomFuns-EncodeLiterals-InitEntropy-Split
# 163: Flatten-EncodeLiterals-Split-InitEntropy
# 164: Flatten-Split-InitImplicitFlow-EncodeLiterals
# 165: InitOpaque-EncodeLiterals-Split-EncodeArithmetic
# 166: InitEntropy-EncodeArithmetic-RandomFuns-Split
# 167: Split-EncodeLiterals-EncodeArithmetic-InitOpaque
# 168: InitImplicitFlow-EncodeLiterals-InitOpaque-Split
# 169: InitEntropy-RandomFuns-Split-EncodeArithmetic
# 170: Split-EncodeArithmetic-EncodeLiterals-RandomFuns
# 171: EncodeLiterals-Split-EncodeArithmetic-Flatten
# 172: EncodeLiterals-Flatten-Split-InitOpaque
# 173: EncodeLiterals-InitEntropy-Flatten-Split
# 174: EncodeLiterals-Flatten-Split-EncodeArithmetic
# 175: InitOpaque-Split-InitImplicitFlow-EncodeLiterals
# 176: InitEntropy-EncodeLiterals-Split-InitOpaque
# 177: RandomFuns-Split-InitEntropy-EncodeArithmetic
# 178: EncodeLiterals-EncodeArithmetic-Split-InitImplicitFlow
# 179: Split-InitEntropy-RandomFuns-EncodeLiterals
# 180: RandomFuns-InitOpaque-Split-EncodeLiterals
# 181: EncodeLiterals-Flatten-InitOpaque-Split
# 182: Split-EncodeLiterals-InitImplicitFlow-InitOpaque
# 183: Flatten-InitEntropy-EncodeLiterals-Split
# 184: Flatten-Split-RandomFuns-EncodeLiterals
# 185: Split-EncodeLiterals-InitEntropy-EncodeArithmetic
# 186: Split-EncodeLiterals-Flatten-EncodeArithmetic
# 187: Split-EncodeLiterals-Flatten-InitEntropy
# 188: EncodeLiterals-InitOpaque-EncodeArithmetic-Split
# 189: EncodeLiterals-RandomFuns-Split-EncodeArithmetic
# 190: InitOpaque-EncodeLiterals-Flatten-Split
# 191: EncodeLiterals-EncodeArithmetic-Split-Flatten
# 192: EncodeLiterals-InitImplicitFlow-Split-EncodeArithmetic
# 193: EncodeArithmetic-EncodeLiterals-InitOpaque-Split
# 194: EncodeLiterals-InitImplicitFlow-RandomFuns-Split
# 195: InitEntropy-RandomFuns-Split-EncodeLiterals
# 196: InitEntropy-Split-InitImplicitFlow-EncodeLiterals
# 197: Split-InitOpaque-EncodeLiterals-Flatten
# 198: InitEntropy-EncodeLiterals-Flatten-Split
# 199: RandomFuns-EncodeArithmetic-InitEntropy-Split
# 200: InitEntropy-InitImplicitFlow-Split-EncodeLiterals
# 201: EncodeLiterals-InitEntropy-Split-EncodeArithmetic
# 202: InitEntropy-EncodeLiterals-InitImplicitFlow-Split
# 203: InitImplicitFlow-Split-InitEntropy-EncodeLiterals
# 204: InitEntropy-Split-Flatten-EncodeLiterals
# 205: Split-RandomFuns-Flatten-EncodeLiterals
# 206: Split-RandomFuns-InitOpaque-EncodeLiterals
# 207: EncodeArithmetic-Split-InitEntropy-RandomFuns
# 208: InitOpaque-Split-EncodeLiterals-InitEntropy
# 209: InitOpaque-RandomFuns-Split-EncodeLiterals
# 210: EncodeLiterals-Split-Flatten-InitImplicitFlow
# 211: Split-InitImplicitFlow-EncodeLiterals-InitEntropy
# 212: EncodeLiterals-Split-RandomFuns-InitImplicitFlow
# 213: Split-EncodeArithmetic-InitEntropy-EncodeLiterals
# 214: EncodeArithmetic-InitEntropy-InitImplicitFlow-Split
# 215: EncodeLiterals-InitImplicitFlow-Split-RandomFuns
# 216: EncodeArithmetic-Flatten-EncodeLiterals-Split
# 217: RandomFuns-InitEntropy-EncodeLiterals-Split
# 218: Split-InitOpaque-EncodeLiterals-RandomFuns
# 219: RandomFuns-EncodeLiterals-Split-Flatten
# 220: EncodeArithmetic-EncodeLiterals-Split-InitEntropy
# 221: InitImplicitFlow-EncodeLiterals-EncodeArithmetic-Split
# 222: EncodeLiterals-EncodeArithmetic-Split-InitOpaque
# 223: EncodeArithmetic-EncodeLiterals-Split-InitOpaque
# 224: Split-EncodeArithmetic-EncodeLiterals-Flatten
# 225: EncodeLiterals-Split-RandomFuns-Flatten
# 226: RandomFuns-InitImplicitFlow-Split-EncodeLiterals
# 227: Split-InitImplicitFlow-EncodeLiterals-EncodeArithmetic
# 228: InitOpaque-Split-EncodeLiterals-EncodeArithmetic
# 229: InitEntropy-EncodeLiterals-Split-EncodeArithmetic
# 230: Flatten-EncodeLiterals-RandomFuns-Split
# 231: InitEntropy-Split-EncodeLiterals-Flatten
# 232: EncodeArithmetic-EncodeLiterals-Flatten-Split
# 233: Split-Flatten-EncodeLiterals-InitOpaque
# 234: InitOpaque-EncodeLiterals-Split-Flatten
# 235: RandomFuns-Split-EncodeLiterals-InitEntropy
# 236: Split-EncodeLiterals-InitEntropy-Flatten
# 237: Flatten-RandomFuns-EncodeLiterals-Split
# 238: Flatten-Split-EncodeLiterals-InitImplicitFlow
# 239: EncodeArithmetic-Split-InitOpaque-EncodeLiterals
# 240: RandomFuns-EncodeLiterals-Split-InitEntropy
# 241: InitOpaque-InitImplicitFlow-EncodeLiterals-Split
# 242: EncodeLiterals-Split-Flatten-InitOpaque
# 243: Flatten-EncodeLiterals-Split-InitOpaque
# 244: Split-EncodeArithmetic-EncodeLiterals-InitEntropy
# 245: RandomFuns-InitOpaque-EncodeLiterals-Split
# 246: RandomFuns-Split-InitOpaque-EncodeLiterals
# 247: InitEntropy-RandomFuns-EncodeArithmetic-Split
# 248: InitImplicitFlow-RandomFuns-Split-EncodeLiterals
# 249: InitEntropy-Split-RandomFuns-EncodeArithmetic
# 250: EncodeLiterals-InitOpaque-Split-EncodeArithmetic
# 251: Split-InitEntropy-Flatten-EncodeLiterals
# 252: EncodeArithmetic-Flatten-Split-EncodeLiterals
# 253: Split-Flatten-EncodeLiterals-RandomFuns
# 254: EncodeLiterals-Flatten-EncodeArithmetic-Split
# 255: Split-EncodeLiterals-InitEntropy-RandomFuns
# 256: InitOpaque-Split-EncodeLiterals-Flatten
# 257: Split-InitOpaque-EncodeLiterals-InitImplicitFlow
# 258: Split-InitOpaque-InitEntropy-EncodeLiterals
# 259: InitOpaque-RandomFuns-EncodeLiterals-Split
# 260: Split-Flatten-EncodeLiterals-InitImplicitFlow
# 261: Split-InitEntropy-InitImplicitFlow-EncodeArithmetic
# 262: EncodeLiterals-Flatten-Split-RandomFuns
# 263: InitImplicitFlow-EncodeArithmetic-EncodeLiterals-Split
# 264: EncodeLiterals-RandomFuns-InitImplicitFlow-Split
# 265: EncodeArithmetic-InitEntropy-Split-RandomFuns
# 266: Split-InitImplicitFlow-EncodeLiterals-Flatten
# 267: Split-EncodeLiterals-InitOpaque-Flatten
# 268: InitOpaque-Flatten-EncodeLiterals-Split
# 269: EncodeLiterals-Split-InitImplicitFlow-InitOpaque
# 270: Split-InitEntropy-InitOpaque-EncodeLiterals
# 271: Split-EncodeLiterals-InitOpaque-EncodeArithmetic
# 272: EncodeLiterals-InitOpaque-Split-RandomFuns
# 273: EncodeLiterals-Split-InitOpaque-InitImplicitFlow
# 274: InitEntropy-EncodeArithmetic-EncodeLiterals-Split
# 275: InitOpaque-EncodeLiterals-RandomFuns-Split
# 276: EncodeLiterals-Split-EncodeArithmetic-InitOpaque
# 277: InitEntropy-EncodeLiterals-RandomFuns-Split
# 278: EncodeArithmetic-EncodeLiterals-Split-RandomFuns
# 279: Split-EncodeLiterals-InitImplicitFlow-InitEntropy
# 280: InitEntropy-Flatten-Split-EncodeLiterals
# 281: Flatten-EncodeLiterals-InitOpaque-Split
# 282: RandomFuns-EncodeLiterals-Split-InitImplicitFlow
# 283: EncodeLiterals-InitOpaque-InitImplicitFlow-Split
# 284: Flatten-EncodeLiterals-InitImplicitFlow-Split
# 285: EncodeLiterals-Flatten-Split-InitEntropy
# 286: InitImplicitFlow-EncodeLiterals-Split-InitEntropy
# 287: EncodeLiterals-InitOpaque-InitEntropy-Split
# 288: Flatten-EncodeLiterals-Split-RandomFuns
# 289: InitEntropy-Split-EncodeArithmetic-EncodeLiterals
# 290: EncodeLiterals-RandomFuns-Split-Flatten
# 291: Split-EncodeArithmetic-InitImplicitFlow-InitEntropy
# 292: EncodeLiterals-EncodeArithmetic-InitImplicitFlow-Split
# 293: InitEntropy-Split-EncodeLiterals-RandomFuns
# 294: Split-RandomFuns-EncodeLiterals-InitOpaque
# 295: RandomFuns-Split-EncodeArithmetic-InitEntropy
# 296: EncodeLiterals-InitEntropy-InitOpaque-Split
# 297: EncodeArithmetic-RandomFuns-InitEntropy-Split
# 298: Split-EncodeLiterals-InitEntropy-InitOpaque
# 299: EncodeLiterals-Split-InitImplicitFlow-EncodeArithmetic
# 300: EncodeLiterals-Split-Flatten-EncodeArithmetic
# 301: EncodeLiterals-Split-RandomFuns-EncodeArithmetic
# 302: Split-EncodeArithmetic-EncodeLiterals-InitImplicitFlow
# 303: Split-InitImplicitFlow-EncodeArithmetic-InitEntropy
# 304: EncodeLiterals-InitOpaque-Split-InitEntropy
# 305: InitOpaque-EncodeLiterals-Split-InitEntropy
# 306: InitEntropy-EncodeArithmetic-Split-RandomFuns
# 307: InitImplicitFlow-EncodeLiterals-Split-InitOpaque
# 308: EncodeLiterals-InitOpaque-Split-InitImplicitFlow
# 309: EncodeArithmetic-Split-EncodeLiterals-Flatten
# 310: EncodeLiterals-InitImplicitFlow-InitOpaque-Split
# 311: EncodeLiterals-Split-Flatten-RandomFuns
# 312: InitImplicitFlow-Split-EncodeLiterals-Flatten
# 313: EncodeLiterals-RandomFuns-Split-InitImplicitFlow
# 314: Flatten-InitImplicitFlow-EncodeLiterals-Split
# 315: EncodeLiterals-RandomFuns-InitEntropy-Split
# 316: InitImplicitFlow-InitOpaque-Split-EncodeLiterals
# 317: EncodeArithmetic-Split-InitEntropy-InitImplicitFlow
# 318: RandomFuns-EncodeArithmetic-EncodeLiterals-Split
# 319: InitImplicitFlow-Flatten-EncodeLiterals-Split
# 320: EncodeArithmetic-EncodeLiterals-Split-InitImplicitFlow
# 321: Split-InitEntropy-EncodeLiterals-InitOpaque
# 322: EncodeLiterals-InitEntropy-Split-InitOpaque
# 323: EncodeArithmetic-Split-InitImplicitFlow-InitEntropy
# 324: EncodeArithmetic-Split-EncodeLiterals-InitEntropy
# 325: EncodeLiterals-InitImplicitFlow-EncodeArithmetic-Split
# 326: EncodeLiterals-Flatten-InitImplicitFlow-Split
# 327: Split-EncodeLiterals-InitOpaque-RandomFuns
# 328: Flatten-EncodeArithmetic-Split-EncodeLiterals
# 329: Split-EncodeLiterals-Flatten-InitOpaque
# 330: Split-EncodeArithmetic-InitOpaque-EncodeLiterals
# 331: Split-InitImplicitFlow-EncodeLiterals-InitOpaque
# 332: Split-InitImplicitFlow-InitEntropy-EncodeLiterals
# 333: EncodeLiterals-Split-InitImplicitFlow-RandomFuns
# 334: InitEntropy-Split-EncodeArithmetic-InitImplicitFlow
# 335: Split-Flatten-EncodeArithmetic-EncodeLiterals
# 336: EncodeLiterals-Split-InitEntropy-InitImplicitFlow
# 337: RandomFuns-Flatten-Split-EncodeLiterals
# 338: Split-EncodeLiterals-EncodeArithmetic-RandomFuns
# 339: Split-InitEntropy-InitImplicitFlow-EncodeLiterals
# 340: EncodeLiterals-InitImplicitFlow-Split-InitEntropy
# 341: Split-EncodeLiterals-RandomFuns-Flatten
# 342: InitEntropy-Split-InitImplicitFlow-EncodeArithmetic
# 343: EncodeArithmetic-InitImplicitFlow-InitEntropy-Split
# 344: Split-EncodeArithmetic-RandomFuns-EncodeLiterals
# 345: Split-Flatten-InitImplicitFlow-EncodeLiterals
# 346: Split-RandomFuns-InitEntropy-EncodeLiterals
# 347: Split-InitEntropy-EncodeLiterals-InitImplicitFlow
# 348: InitImplicitFlow-Split-EncodeLiterals-RandomFuns
# 349: EncodeLiterals-InitImplicitFlow-Flatten-Split
# 350: Split-Flatten-RandomFuns-EncodeLiterals
# 351: Flatten-Split-EncodeLiterals-InitEntropy
# 352: RandomFuns-Split-EncodeLiterals-InitImplicitFlow
# 353: EncodeArithmetic-Split-EncodeLiterals-InitImplicitFlow
# 354: Split-InitImplicitFlow-InitOpaque-EncodeLiterals
# 355: Split-EncodeArithmetic-EncodeLiterals-InitOpaque
# 356: Split-RandomFuns-EncodeArithmetic-InitEntropy
# 357: Split-InitOpaque-RandomFuns-EncodeLiterals
# 358: RandomFuns-Split-Flatten-EncodeLiterals
# 359: InitOpaque-Flatten-Split-EncodeLiterals
# 360: RandomFuns-EncodeLiterals-InitOpaque-Split
# 361: Split-EncodeLiterals-InitImplicitFlow-Flatten
# 362: InitEntropy-Flatten-EncodeLiterals-Split
# 363: EncodeLiterals-Split-InitEntropy-EncodeArithmetic
# 364: RandomFuns-EncodeLiterals-InitImplicitFlow-Split
# 365: InitOpaque-EncodeLiterals-Split-RandomFuns
# 366: InitImplicitFlow-EncodeLiterals-Flatten-Split
# 367: Split-EncodeLiterals-InitOpaque-InitImplicitFlow
# 368: Split-InitImplicitFlow-InitEntropy-EncodeArithmetic
# 369: RandomFuns-Split-EncodeLiterals-EncodeArithmetic
# 370: RandomFuns-EncodeArithmetic-Split-EncodeLiterals
# 371: Split-InitImplicitFlow-EncodeArithmetic-EncodeLiterals
# 372: EncodeArithmetic-EncodeLiterals-InitEntropy-Split
# 373: InitEntropy-InitImplicitFlow-EncodeLiterals-Split
# 374: Split-EncodeLiterals-Flatten-InitImplicitFlow
# 375: RandomFuns-Split-InitEntropy-EncodeLiterals
# 376: EncodeLiterals-Flatten-Split-InitImplicitFlow
# 377: Split-InitImplicitFlow-RandomFuns-EncodeLiterals
# 378: Flatten-Split-EncodeLiterals-RandomFuns
# 379: Split-RandomFuns-EncodeLiterals-InitEntropy
# 380: InitOpaque-InitImplicitFlow-Split-EncodeLiterals
# 381: Split-InitOpaque-InitImplicitFlow-EncodeLiterals
# 382: InitImplicitFlow-EncodeLiterals-Split-EncodeArithmetic
# 383: RandomFuns-Split-EncodeLiterals-InitOpaque
# 384: EncodeLiterals-InitOpaque-RandomFuns-Split
# 385: InitOpaque-Split-EncodeLiterals-InitImplicitFlow
# 386: InitOpaque-EncodeLiterals-Split-InitImplicitFlow
# 387: InitImplicitFlow-InitEntropy-Split-EncodeLiterals
# 388: EncodeLiterals-Split-RandomFuns-InitEntropy
# 389: InitOpaque-Split-EncodeLiterals-RandomFuns
# 390: InitOpaque-EncodeArithmetic-Split-EncodeLiterals
# 391: RandomFuns-InitImplicitFlow-EncodeLiterals-Split
# 392: Split-InitImplicitFlow-EncodeLiterals-RandomFuns
# 393: InitImplicitFlow-EncodeLiterals-Split-RandomFuns
# 394: EncodeLiterals-InitImplicitFlow-Split-InitOpaque
# 395: Split-EncodeLiterals-RandomFuns-InitImplicitFlow
# 396: InitEntropy-Split-EncodeLiterals-InitImplicitFlow
# 397: Flatten-EncodeLiterals-Split-EncodeArithmetic
# 398: Split-InitEntropy-EncodeLiterals-Flatten
# 399: Split-RandomFuns-EncodeLiterals-Flatten
# 400: InitEntropy-EncodeLiterals-Split-RandomFuns
# Analizzo la classe: remove_char
# 1: Split-EncodeLiterals-Flatten-RandomFuns
# 2: EncodeArithmetic-RandomFuns-Split-InitEntropy
# 3: Flatten-EncodeArithmetic-EncodeLiterals-Split
# 4: EncodeLiterals-Split-InitOpaque-Flatten
# 5: EncodeArithmetic-RandomFuns-Split-EncodeLiterals
# 6: EncodeLiterals-InitEntropy-Split-Flatten
# 7: Split-EncodeArithmetic-InitEntropy-InitImplicitFlow
# 8: EncodeLiterals-RandomFuns-EncodeArithmetic-Split
# 9: EncodeArithmetic-InitOpaque-Split-EncodeLiterals
# 10: EncodeLiterals-EncodeArithmetic-InitOpaque-Split
# 11: EncodeLiterals-InitImplicitFlow-InitEntropy-Split
# 12: Split-EncodeLiterals-InitImplicitFlow-RandomFuns
# 13: Split-InitOpaque-Flatten-EncodeLiterals
# 14: Flatten-InitOpaque-EncodeLiterals-Split
# 15: Split-EncodeLiterals-EncodeArithmetic-InitEntropy
# 16: EncodeArithmetic-InitOpaque-EncodeLiterals-Split
# 17: InitOpaque-Flatten-InitImplicitFlow
# 18: EncodeArithmetic-Split-RandomFuns-EncodeLiterals
# 19: Flatten-Split-EncodeLiterals-InitOpaque
# 20: Split-InitImplicitFlow-Flatten-EncodeLiterals
# 21: Split-RandomFuns-InitEntropy-EncodeArithmetic
# 22: EncodeLiterals-InitEntropy-Split-RandomFuns
# 23: Split-EncodeLiterals-RandomFuns-InitEntropy
# 24: EncodeArithmetic-Split-EncodeLiterals-RandomFuns
# 25: Split-Flatten-EncodeLiterals-InitEntropy
# 26: Split-InitEntropy-EncodeArithmetic-EncodeLiterals
# 27: Flatten-EncodeLiterals-EncodeArithmetic-Split
# 28: EncodeArithmetic-InitImplicitFlow-Split-InitEntropy
# 29: Flatten-RandomFuns-Split-EncodeLiterals
# 30: EncodeArithmetic-Split-Flatten-EncodeLiterals
# 31: InitImplicitFlow-Split-EncodeLiterals-EncodeArithmetic
# 32: InitEntropy-EncodeLiterals-Split-InitImplicitFlow
# 33: EncodeArithmetic-InitEntropy-Split-EncodeLiterals
# 34: EncodeArithmetic-Split-RandomFuns-InitEntropy
# 35: EncodeLiterals-EncodeArithmetic-Split-InitEntropy
# 36: EncodeLiterals-Split-InitEntropy-InitOpaque
# 37: RandomFuns-EncodeLiterals-Split-InitOpaque
# 38: EncodeArithmetic-InitEntropy-RandomFuns-Split
# 39: Split-RandomFuns-EncodeLiterals-InitImplicitFlow
# 40: EncodeLiterals-EncodeArithmetic-Split-RandomFuns
# 41: Split-EncodeLiterals-EncodeArithmetic-Flatten
# 42: InitOpaque-InitEntropy-EncodeLiterals-Split
# 43: EncodeLiterals-Split-RandomFuns-InitOpaque
# 44: InitEntropy-InitOpaque-EncodeLiterals-Split
# 45: EncodeArithmetic-Split-InitImplicitFlow-EncodeLiterals
# 46: Split-EncodeLiterals-RandomFuns-EncodeArithmetic
# 47: Split-EncodeArithmetic-InitImplicitFlow-EncodeLiterals
# 48: InitImplicitFlow-RandomFuns-EncodeLiterals-Split
# 49: InitImplicitFlow-Split-EncodeLiterals-InitEntropy
# 50: Flatten-Split-EncodeArithmetic-EncodeLiterals
# 51: RandomFuns-InitEntropy-Split-EncodeArithmetic
# 52: EncodeArithmetic-InitEntropy-Split-InitImplicitFlow
# 53: EncodeLiterals-Flatten-RandomFuns-Split
# 54: EncodeLiterals-InitEntropy-RandomFuns-Split
# 55: EncodeArithmetic-Split-EncodeLiterals-InitOpaque
# 56: Split-RandomFuns-EncodeArithmetic-EncodeLiterals
# 57: Split-InitEntropy-EncodeLiterals-RandomFuns
# 58: EncodeLiterals-Split-EncodeArithmetic-RandomFuns
# 59: EncodeArithmetic-InitImplicitFlow-Split-EncodeLiterals
# 60: InitImplicitFlow-Split-EncodeLiterals-InitOpaque
# 61: Split-EncodeLiterals-InitOpaque-InitEntropy
# 62: EncodeLiterals-Split-InitImplicitFlow-InitEntropy
# 63: InitEntropy-InitOpaque-Split-EncodeLiterals
# 64: InitOpaque-Split-EncodeArithmetic-EncodeLiterals
# 65: InitEntropy-Split-EncodeLiterals-EncodeArithmetic
# 66: Split-Flatten-InitOpaque-EncodeLiterals
# 67: Split-Flatten-EncodeLiterals-EncodeArithmetic
# 68: Flatten-Split-InitEntropy-EncodeLiterals
# 69: RandomFuns-Flatten-EncodeLiterals-Split
# 70: Split-InitOpaque-EncodeLiterals-InitEntropy
# 71: Flatten-EncodeLiterals-InitEntropy-Split
# 72: EncodeLiterals-InitOpaque-Split-Flatten
# 73: InitImplicitFlow-EncodeLiterals-RandomFuns-Split
# 74: InitImplicitFlow-EncodeArithmetic-Split-EncodeLiterals
# 75: EncodeLiterals-Split-InitOpaque-EncodeArithmetic
# 76: Split-Flatten-InitEntropy-EncodeLiterals
# 77: RandomFuns-Split-EncodeLiterals-Flatten
# 78: Split-InitEntropy-EncodeArithmetic-RandomFuns
# 79: RandomFuns-EncodeArithmetic-Split-InitEntropy
# 80: EncodeArithmetic-EncodeLiterals-RandomFuns-Split
# 81: RandomFuns-EncodeLiterals-Flatten-Split
# 82: EncodeArithmetic-InitImplicitFlow-EncodeLiterals-Split
# 83: InitOpaque-InitEntropy-Split-EncodeLiterals
# 84: Split-InitEntropy-EncodeLiterals-EncodeArithmetic
# 85: EncodeArithmetic-Split-InitEntropy-EncodeLiterals
# 86: InitOpaque-EncodeLiterals-InitEntropy-Split
# 87: EncodeLiterals-RandomFuns-Split-InitEntropy
# 88: InitOpaque-Split-InitEntropy-EncodeLiterals
# 89: EncodeLiterals-Split-Flatten-InitEntropy
# 90: EncodeLiterals-Split-EncodeArithmetic-InitImplicitFlow
# 91: EncodeLiterals-Flatten-InitEntropy-Split
# 92: InitOpaque-Split-Flatten-EncodeLiterals
# 93: Split-RandomFuns-EncodeLiterals-EncodeArithmetic
# 94: EncodeLiterals-Split-InitOpaque-RandomFuns
# 95: EncodeLiterals-InitOpaque-Flatten-Split
# 96: InitOpaque-Split-RandomFuns-EncodeLiterals
# 97: InitImplicitFlow-Split-InitOpaque-EncodeLiterals
# 98: Flatten-Split-InitOpaque-EncodeLiterals
# 99: Split-InitEntropy-RandomFuns-EncodeArithmetic
# 100: InitImplicitFlow-Split-RandomFuns-EncodeLiterals
# 101: EncodeLiterals-EncodeArithmetic-Flatten-Split
# 102: InitOpaque-EncodeLiterals-InitImplicitFlow-Split
# 103: EncodeArithmetic-EncodeLiterals-Split-Flatten
# 104: EncodeLiterals-Split-InitEntropy-Flatten
# 105: Flatten-InitOpaque-Split-EncodeLiterals
# 106: Split-EncodeArithmetic-InitEntropy-RandomFuns
# 107: RandomFuns-EncodeLiterals-EncodeArithmetic-Split
# 108: EncodeLiterals-Split-InitOpaque-InitEntropy
# 109: EncodeLiterals-Split-InitEntropy-RandomFuns
# 110: Split-InitOpaque-EncodeArithmetic-EncodeLiterals
# 111: InitEntropy-Split-RandomFuns-EncodeLiterals
# 112: InitOpaque-EncodeArithmetic-EncodeLiterals-Split
# 113: Flatten-EncodeLiterals-Split-InitImplicitFlow
# 114: Split-EncodeLiterals-RandomFuns-InitOpaque
# 115: Flatten-InitImplicitFlow-Split-EncodeLiterals
# 116: Flatten-InitEntropy-Split-EncodeLiterals
# 117: EncodeLiterals-InitEntropy-InitImplicitFlow-Split
# 118: InitEntropy-EncodeArithmetic-Split-InitImplicitFlow
# 119: InitEntropy-EncodeLiterals-InitOpaque-Split
# 120: InitImplicitFlow-InitOpaque-EncodeLiterals-Split
# 121: Flatten-Split-EncodeLiterals-EncodeArithmetic
# 122: EncodeArithmetic-InitEntropy-EncodeLiterals-Split
# 123: EncodeLiterals-InitEntropy-EncodeArithmetic-Split
# 124: Split-InitOpaque-EncodeLiterals-EncodeArithmetic
# 125: Split-EncodeLiterals-InitImplicitFlow-EncodeArithmetic
# 126: InitEntropy-Split-EncodeLiterals-InitOpaque
# 127: InitImplicitFlow-InitEntropy-EncodeLiterals-Split
# 128: EncodeLiterals-Split-EncodeArithmetic-InitEntropy
# 129: EncodeLiterals-EncodeArithmetic-RandomFuns-Split
# 130: InitOpaque-EncodeLiterals-EncodeArithmetic-Split
# 131: InitImplicitFlow-EncodeLiterals-Split-Flatten
# 132: Split-RandomFuns-InitImplicitFlow-EncodeLiterals
# 133: EncodeLiterals-RandomFuns-Flatten-Split
# 134: EncodeLiterals-RandomFuns-Split-InitOpaque
# 135: EncodeLiterals-Split-InitImplicitFlow-Flatten
# 136: InitImplicitFlow-EncodeLiterals-InitEntropy-Split
# 137: RandomFuns-Split-EncodeArithmetic-EncodeLiterals
# 138: InitEntropy-RandomFuns-EncodeLiterals-Split
# 139: RandomFuns-EncodeLiterals-Split-EncodeArithmetic
# 140: Split-EncodeArithmetic-RandomFuns-InitEntropy
# 141: InitEntropy-Split-InitOpaque-EncodeLiterals
# 142: RandomFuns-Split-InitImplicitFlow-EncodeLiterals
# 143: Split-EncodeLiterals-EncodeArithmetic-InitImplicitFlow
# 144: EncodeArithmetic-EncodeLiterals-InitImplicitFlow-Split
# 145: InitEntropy-EncodeLiterals-EncodeArithmetic-Split
# 146: EncodeLiterals-InitEntropy-Split-InitImplicitFlow
# 147: Split-InitEntropy-EncodeArithmetic-InitImplicitFlow
# 148: EncodeLiterals-InitImplicitFlow-Split-Flatten
# 149: Split-EncodeArithmetic-Flatten-EncodeLiterals
# 150: InitImplicitFlow-Split-EncodeArithmetic-EncodeLiterals
# 151: RandomFuns-InitEntropy-Split-EncodeLiterals
# 152: InitEntropy-Split-EncodeArithmetic-RandomFuns
# 153: InitImplicitFlow-Split-Flatten-EncodeLiterals
# 154: EncodeLiterals-EncodeArithmetic-InitEntropy-Split
# 155: InitEntropy-EncodeArithmetic-Split-EncodeLiterals
# 156: InitImplicitFlow-Flatten-Split-EncodeLiterals
# 157: EncodeLiterals-RandomFuns-InitOpaque-Split
# 158: RandomFuns-InitEntropy-EncodeArithmetic-Split
# 159: Split-EncodeLiterals-InitEntropy-InitImplicitFlow
# 160: EncodeArithmetic-RandomFuns-EncodeLiterals-Split
# 161: InitEntropy-EncodeLiterals-Split-Flatten
# 162: RandomFuns-EncodeLiterals-InitEntropy-Split
# 163: Flatten-EncodeLiterals-Split-InitEntropy
# 164: Flatten-Split-InitImplicitFlow-EncodeLiterals
# 165: InitOpaque-EncodeLiterals-Split-EncodeArithmetic
# 166: InitEntropy-EncodeArithmetic-RandomFuns-Split
# 167: Split-EncodeLiterals-EncodeArithmetic-InitOpaque
# 168: InitImplicitFlow-EncodeLiterals-InitOpaque-Split
# 169: InitEntropy-RandomFuns-Split-EncodeArithmetic
# 170: Split-EncodeArithmetic-EncodeLiterals-RandomFuns
# 171: EncodeLiterals-Split-EncodeArithmetic-Flatten
# 172: EncodeLiterals-Flatten-Split-InitOpaque
# 173: EncodeLiterals-InitEntropy-Flatten-Split
# 174: EncodeLiterals-Flatten-Split-EncodeArithmetic
# 175: InitOpaque-Split-InitImplicitFlow-EncodeLiterals
# 176: InitEntropy-EncodeLiterals-Split-InitOpaque
# 177: RandomFuns-Split-InitEntropy-EncodeArithmetic
# 178: EncodeLiterals-EncodeArithmetic-Split-InitImplicitFlow
# 179: Split-InitEntropy-RandomFuns-EncodeLiterals
# 180: RandomFuns-InitOpaque-Split-EncodeLiterals
# 181: EncodeLiterals-Flatten-InitOpaque-Split
# 182: Split-EncodeLiterals-InitImplicitFlow-InitOpaque
# 183: Flatten-InitEntropy-EncodeLiterals-Split
# 184: Flatten-Split-RandomFuns-EncodeLiterals
# 185: Split-EncodeLiterals-InitEntropy-EncodeArithmetic
# 186: Split-EncodeLiterals-Flatten-EncodeArithmetic
# 187: Split-EncodeLiterals-Flatten-InitEntropy
# 188: EncodeLiterals-InitOpaque-EncodeArithmetic-Split
# 189: EncodeLiterals-RandomFuns-Split-EncodeArithmetic
# 190: InitOpaque-EncodeLiterals-Flatten-Split
# 191: EncodeLiterals-EncodeArithmetic-Split-Flatten
# 192: EncodeLiterals-InitImplicitFlow-Split-EncodeArithmetic
# 193: EncodeArithmetic-EncodeLiterals-InitOpaque-Split
# 194: EncodeLiterals-InitImplicitFlow-RandomFuns-Split
# 195: InitEntropy-RandomFuns-Split-EncodeLiterals
# 196: InitEntropy-Split-InitImplicitFlow-EncodeLiterals
# 197: Split-InitOpaque-EncodeLiterals-Flatten
# 198: InitEntropy-EncodeLiterals-Flatten-Split
# 199: RandomFuns-EncodeArithmetic-InitEntropy-Split
# 200: InitEntropy-InitImplicitFlow-Split-EncodeLiterals
# 201: EncodeLiterals-InitEntropy-Split-EncodeArithmetic
# 202: InitEntropy-EncodeLiterals-InitImplicitFlow-Split
# 203: InitImplicitFlow-Split-InitEntropy-EncodeLiterals
# 204: InitEntropy-Split-Flatten-EncodeLiterals
# 205: Split-RandomFuns-Flatten-EncodeLiterals
# 206: Split-RandomFuns-InitOpaque-EncodeLiterals
# 207: EncodeArithmetic-Split-InitEntropy-RandomFuns
# 208: InitOpaque-Split-EncodeLiterals-InitEntropy
# 209: InitOpaque-RandomFuns-Split-EncodeLiterals
# 210: EncodeLiterals-Split-Flatten-InitImplicitFlow
# 211: Split-InitImplicitFlow-EncodeLiterals-InitEntropy
# 212: EncodeLiterals-Split-RandomFuns-InitImplicitFlow
# 213: Split-EncodeArithmetic-InitEntropy-EncodeLiterals
# 214: EncodeArithmetic-InitEntropy-InitImplicitFlow-Split
# 215: EncodeLiterals-InitImplicitFlow-Split-RandomFuns
# 216: EncodeArithmetic-Flatten-EncodeLiterals-Split
# 217: RandomFuns-InitEntropy-EncodeLiterals-Split
# 218: Split-InitOpaque-EncodeLiterals-RandomFuns
# 219: RandomFuns-EncodeLiterals-Split-Flatten
# 220: EncodeArithmetic-EncodeLiterals-Split-InitEntropy
# 221: InitImplicitFlow-EncodeLiterals-EncodeArithmetic-Split
# 222: EncodeLiterals-EncodeArithmetic-Split-InitOpaque
# 223: EncodeArithmetic-EncodeLiterals-Split-InitOpaque
# 224: Split-EncodeArithmetic-EncodeLiterals-Flatten
# 225: EncodeLiterals-Split-RandomFuns-Flatten
# 226: RandomFuns-InitImplicitFlow-Split-EncodeLiterals
# 227: Split-InitImplicitFlow-EncodeLiterals-EncodeArithmetic
# 228: InitOpaque-Split-EncodeLiterals-EncodeArithmetic
# 229: InitEntropy-EncodeLiterals-Split-EncodeArithmetic
# 230: Flatten-EncodeLiterals-RandomFuns-Split
# 231: InitEntropy-Split-EncodeLiterals-Flatten
# 232: EncodeArithmetic-EncodeLiterals-Flatten-Split
# 233: Split-Flatten-EncodeLiterals-InitOpaque
# 234: InitOpaque-EncodeLiterals-Split-Flatten
# 235: RandomFuns-Split-EncodeLiterals-InitEntropy
# 236: Split-EncodeLiterals-InitEntropy-Flatten
# 237: Flatten-RandomFuns-EncodeLiterals-Split
# 238: Flatten-Split-EncodeLiterals-InitImplicitFlow
# 239: EncodeArithmetic-Split-InitOpaque-EncodeLiterals
# 240: RandomFuns-EncodeLiterals-Split-InitEntropy
# 241: InitOpaque-InitImplicitFlow-EncodeLiterals-Split
# 242: EncodeLiterals-Split-Flatten-InitOpaque
# 243: Flatten-EncodeLiterals-Split-InitOpaque
# 244: Split-EncodeArithmetic-EncodeLiterals-InitEntropy
# 245: RandomFuns-InitOpaque-EncodeLiterals-Split
# 246: RandomFuns-Split-InitOpaque-EncodeLiterals
# 247: InitEntropy-RandomFuns-EncodeArithmetic-Split
# 248: InitImplicitFlow-RandomFuns-Split-EncodeLiterals
# 249: InitEntropy-Split-RandomFuns-EncodeArithmetic
# 250: EncodeLiterals-InitOpaque-Split-EncodeArithmetic
# 251: Split-InitEntropy-Flatten-EncodeLiterals
# 252: EncodeArithmetic-Flatten-Split-EncodeLiterals
# 253: Split-Flatten-EncodeLiterals-RandomFuns
# 254: EncodeLiterals-Flatten-EncodeArithmetic-Split
# 255: Split-EncodeLiterals-InitEntropy-RandomFuns
# 256: InitOpaque-Split-EncodeLiterals-Flatten
# 257: Split-InitOpaque-EncodeLiterals-InitImplicitFlow
# 258: Split-InitOpaque-InitEntropy-EncodeLiterals
# 259: InitOpaque-RandomFuns-EncodeLiterals-Split
# 260: Split-Flatten-EncodeLiterals-InitImplicitFlow
# 261: Split-InitEntropy-InitImplicitFlow-EncodeArithmetic
# 262: EncodeLiterals-Flatten-Split-RandomFuns
# 263: InitImplicitFlow-EncodeArithmetic-EncodeLiterals-Split
# 264: EncodeLiterals-RandomFuns-InitImplicitFlow-Split
# 265: EncodeArithmetic-InitEntropy-Split-RandomFuns
# 266: Split-InitImplicitFlow-EncodeLiterals-Flatten
# 267: Split-EncodeLiterals-InitOpaque-Flatten
# 268: InitOpaque-Flatten-EncodeLiterals-Split
# 269: EncodeLiterals-Split-InitImplicitFlow-InitOpaque
# 270: Split-InitEntropy-InitOpaque-EncodeLiterals
# 271: Split-EncodeLiterals-InitOpaque-EncodeArithmetic
# 272: EncodeLiterals-InitOpaque-Split-RandomFuns
# 273: EncodeLiterals-Split-InitOpaque-InitImplicitFlow
# 274: InitEntropy-EncodeArithmetic-EncodeLiterals-Split
# 275: InitOpaque-EncodeLiterals-RandomFuns-Split
# 276: EncodeLiterals-Split-EncodeArithmetic-InitOpaque
# 277: InitEntropy-EncodeLiterals-RandomFuns-Split
# 278: EncodeArithmetic-EncodeLiterals-Split-RandomFuns
# 279: Split-EncodeLiterals-InitImplicitFlow-InitEntropy
# 280: InitEntropy-Flatten-Split-EncodeLiterals
# 281: Flatten-EncodeLiterals-InitOpaque-Split
# 282: RandomFuns-EncodeLiterals-Split-InitImplicitFlow
# 283: EncodeLiterals-InitOpaque-InitImplicitFlow-Split
# 284: Flatten-EncodeLiterals-InitImplicitFlow-Split
# 285: EncodeLiterals-Flatten-Split-InitEntropy
# 286: InitImplicitFlow-EncodeLiterals-Split-InitEntropy
# 287: EncodeLiterals-InitOpaque-InitEntropy-Split
# 288: Flatten-EncodeLiterals-Split-RandomFuns
# 289: InitEntropy-Split-EncodeArithmetic-EncodeLiterals
# 290: EncodeLiterals-RandomFuns-Split-Flatten
# 291: Split-EncodeArithmetic-InitImplicitFlow-InitEntropy
# 292: EncodeLiterals-EncodeArithmetic-InitImplicitFlow-Split
# 293: InitEntropy-Split-EncodeLiterals-RandomFuns
# 294: Split-RandomFuns-EncodeLiterals-InitOpaque
# 295: RandomFuns-Split-EncodeArithmetic-InitEntropy
# 296: EncodeLiterals-InitEntropy-InitOpaque-Split
# 297: EncodeArithmetic-RandomFuns-InitEntropy-Split
# 298: Split-EncodeLiterals-InitEntropy-InitOpaque
# 299: EncodeLiterals-Split-InitImplicitFlow-EncodeArithmetic
# 300: EncodeLiterals-Split-Flatten-EncodeArithmetic
# 301: EncodeLiterals-Split-RandomFuns-EncodeArithmetic
# 302: Split-EncodeArithmetic-EncodeLiterals-InitImplicitFlow
# 303: Split-InitImplicitFlow-EncodeArithmetic-InitEntropy
# 304: EncodeLiterals-InitOpaque-Split-InitEntropy
# 305: InitOpaque-EncodeLiterals-Split-InitEntropy
# 306: InitEntropy-EncodeArithmetic-Split-RandomFuns
# 307: InitImplicitFlow-EncodeLiterals-Split-InitOpaque
# 308: EncodeLiterals-InitOpaque-Split-InitImplicitFlow
# 309: EncodeArithmetic-Split-EncodeLiterals-Flatten
# 310: EncodeLiterals-InitImplicitFlow-InitOpaque-Split
# 311: EncodeLiterals-Split-Flatten-RandomFuns
# 312: InitImplicitFlow-Split-EncodeLiterals-Flatten
# 313: EncodeLiterals-RandomFuns-Split-InitImplicitFlow
# 314: Flatten-InitImplicitFlow-EncodeLiterals-Split
# 315: EncodeLiterals-RandomFuns-InitEntropy-Split
# 316: InitImplicitFlow-InitOpaque-Split-EncodeLiterals
# 317: EncodeArithmetic-Split-InitEntropy-InitImplicitFlow
# 318: RandomFuns-EncodeArithmetic-EncodeLiterals-Split
# 319: InitImplicitFlow-Flatten-EncodeLiterals-Split
# 320: EncodeArithmetic-EncodeLiterals-Split-InitImplicitFlow
# 321: Split-InitEntropy-EncodeLiterals-InitOpaque
# 322: EncodeLiterals-InitEntropy-Split-InitOpaque
# 323: EncodeArithmetic-Split-InitImplicitFlow-InitEntropy
# 324: EncodeArithmetic-Split-EncodeLiterals-InitEntropy
# 325: EncodeLiterals-InitImplicitFlow-EncodeArithmetic-Split
# 326: EncodeLiterals-Flatten-InitImplicitFlow-Split
# 327: Split-EncodeLiterals-InitOpaque-RandomFuns
# 328: Flatten-EncodeArithmetic-Split-EncodeLiterals
# 329: Split-EncodeLiterals-Flatten-InitOpaque
# 330: Split-EncodeArithmetic-InitOpaque-EncodeLiterals
# 331: Split-InitImplicitFlow-EncodeLiterals-InitOpaque
# 332: Split-InitImplicitFlow-InitEntropy-EncodeLiterals
# 333: EncodeLiterals-Split-InitImplicitFlow-RandomFuns
# 334: InitEntropy-Split-EncodeArithmetic-InitImplicitFlow
# 335: Split-Flatten-EncodeArithmetic-EncodeLiterals
# 336: EncodeLiterals-Split-InitEntropy-InitImplicitFlow
# 337: RandomFuns-Flatten-Split-EncodeLiterals
# 338: Split-EncodeLiterals-EncodeArithmetic-RandomFuns
# 339: Split-InitEntropy-InitImplicitFlow-EncodeLiterals
# 340: EncodeLiterals-InitImplicitFlow-Split-InitEntropy
# 341: Split-EncodeLiterals-RandomFuns-Flatten
# 342: InitEntropy-Split-InitImplicitFlow-EncodeArithmetic
# 343: EncodeArithmetic-InitImplicitFlow-InitEntropy-Split
# 344: Split-EncodeArithmetic-RandomFuns-EncodeLiterals
# 345: Split-Flatten-InitImplicitFlow-EncodeLiterals
# 346: Split-RandomFuns-InitEntropy-EncodeLiterals
# 347: Split-InitEntropy-EncodeLiterals-InitImplicitFlow
# 348: InitImplicitFlow-Split-EncodeLiterals-RandomFuns
# 349: EncodeLiterals-InitImplicitFlow-Flatten-Split
# 350: Split-Flatten-RandomFuns-EncodeLiterals
# 351: Flatten-Split-EncodeLiterals-InitEntropy
# 352: RandomFuns-Split-EncodeLiterals-InitImplicitFlow
# 353: EncodeArithmetic-Split-EncodeLiterals-InitImplicitFlow
# 354: Split-InitImplicitFlow-InitOpaque-EncodeLiterals
# 355: Split-EncodeArithmetic-EncodeLiterals-InitOpaque
# 356: Split-RandomFuns-EncodeArithmetic-InitEntropy
# 357: Split-InitOpaque-RandomFuns-EncodeLiterals
# 358: RandomFuns-Split-Flatten-EncodeLiterals
# 359: InitOpaque-Flatten-Split-EncodeLiterals
# 360: RandomFuns-EncodeLiterals-InitOpaque-Split
# 361: Split-EncodeLiterals-InitImplicitFlow-Flatten
# 362: InitEntropy-Flatten-EncodeLiterals-Split
# 363: EncodeLiterals-Split-InitEntropy-EncodeArithmetic
# 364: RandomFuns-EncodeLiterals-InitImplicitFlow-Split
# 365: InitOpaque-EncodeLiterals-Split-RandomFuns
# 366: InitImplicitFlow-EncodeLiterals-Flatten-Split
# 367: Split-EncodeLiterals-InitOpaque-InitImplicitFlow
# 368: Split-InitImplicitFlow-InitEntropy-EncodeArithmetic
# 369: RandomFuns-Split-EncodeLiterals-EncodeArithmetic
# 370: RandomFuns-EncodeArithmetic-Split-EncodeLiterals
# 371: Split-InitImplicitFlow-EncodeArithmetic-EncodeLiterals
# 372: EncodeArithmetic-EncodeLiterals-InitEntropy-Split
# 373: InitEntropy-InitImplicitFlow-EncodeLiterals-Split
# 374: Split-EncodeLiterals-Flatten-InitImplicitFlow
# 375: RandomFuns-Split-InitEntropy-EncodeLiterals
# 376: EncodeLiterals-Flatten-Split-InitImplicitFlow
# 377: Split-InitImplicitFlow-RandomFuns-EncodeLiterals
# 378: Flatten-Split-EncodeLiterals-RandomFuns
# 379: Split-RandomFuns-EncodeLiterals-InitEntropy
# 380: InitOpaque-InitImplicitFlow-Split-EncodeLiterals
# 381: Split-InitOpaque-InitImplicitFlow-EncodeLiterals
# 382: InitImplicitFlow-EncodeLiterals-Split-EncodeArithmetic
# 383: RandomFuns-Split-EncodeLiterals-InitOpaque
# 384: EncodeLiterals-InitOpaque-RandomFuns-Split
# 385: InitOpaque-Split-EncodeLiterals-InitImplicitFlow
# 386: InitOpaque-EncodeLiterals-Split-InitImplicitFlow
# 387: InitImplicitFlow-InitEntropy-Split-EncodeLiterals
# 388: EncodeLiterals-Split-RandomFuns-InitEntropy
# 389: InitOpaque-Split-EncodeLiterals-RandomFuns
# 390: InitOpaque-EncodeArithmetic-Split-EncodeLiterals
# 391: RandomFuns-InitImplicitFlow-EncodeLiterals-Split
# 392: Split-InitImplicitFlow-EncodeLiterals-RandomFuns
# 393: InitImplicitFlow-EncodeLiterals-Split-RandomFuns
# 394: EncodeLiterals-InitImplicitFlow-Split-InitOpaque
# 395: Split-EncodeLiterals-RandomFuns-InitImplicitFlow
# 396: InitEntropy-Split-EncodeLiterals-InitImplicitFlow
# 397: Flatten-EncodeLiterals-Split-EncodeArithmetic
# 398: Split-InitEntropy-EncodeLiterals-Flatten
# 399: Split-RandomFuns-EncodeLiterals-Flatten
# 400: InitEntropy-EncodeLiterals-Split-RandomFuns
# Analizzo la classe: n_is_sum_of_primes
# APPOSTO
# Analizzo la classe: hello_world
# APPOSTO
# Analizzo la classe: magicka
# APPOSTO
# Analizzo la classe: fly_swatter
# APPOSTO
# Analizzo la classe: lcm
# APPOSTO
# Analizzo la classe: train_time_table
# APPOSTO
# Analizzo la classe: factorial_rec
# APPOSTO
# Analizzo la classe: calculator
# 1: Split-EncodeLiterals-Flatten-RandomFuns
# 2: EncodeArithmetic-RandomFuns-Split-InitEntropy
# 3: Flatten-EncodeArithmetic-EncodeLiterals-Split
# 4: EncodeLiterals-Split-InitOpaque-Flatten
# 5: EncodeArithmetic-RandomFuns-Split-EncodeLiterals
# 6: EncodeLiterals-InitEntropy-Split-Flatten
# 7: Split-EncodeArithmetic-InitEntropy-InitImplicitFlow
# 8: EncodeLiterals-RandomFuns-EncodeArithmetic-Split
# 9: EncodeArithmetic-InitOpaque-Split-EncodeLiterals
# 10: EncodeLiterals-EncodeArithmetic-InitOpaque-Split
# 11: EncodeLiterals-InitImplicitFlow-InitEntropy-Split
# 12: Split-EncodeLiterals-InitImplicitFlow-RandomFuns
# 13: Split-InitOpaque-Flatten-EncodeLiterals
# 14: Flatten-InitOpaque-EncodeLiterals-Split
# 15: Split-EncodeLiterals-EncodeArithmetic-InitEntropy
# 16: EncodeArithmetic-InitOpaque-EncodeLiterals-Split
# 17: InitOpaque-Flatten-InitImplicitFlow
# 18: EncodeArithmetic-Split-RandomFuns-EncodeLiterals
# 19: Flatten-Split-EncodeLiterals-InitOpaque
# 20: Split-InitImplicitFlow-Flatten-EncodeLiterals
# 21: Split-RandomFuns-InitEntropy-EncodeArithmetic
# 22: EncodeLiterals-InitEntropy-Split-RandomFuns
# 23: Split-EncodeLiterals-RandomFuns-InitEntropy
# 24: EncodeArithmetic-Split-EncodeLiterals-RandomFuns
# 25: Split-Flatten-EncodeLiterals-InitEntropy
# 26: Split-InitEntropy-EncodeArithmetic-EncodeLiterals
# 27: Flatten-EncodeLiterals-EncodeArithmetic-Split
# 28: EncodeArithmetic-InitImplicitFlow-Split-InitEntropy
# 29: Flatten-RandomFuns-Split-EncodeLiterals
# 30: EncodeArithmetic-Split-Flatten-EncodeLiterals
# 31: InitImplicitFlow-Split-EncodeLiterals-EncodeArithmetic
# 32: InitEntropy-EncodeLiterals-Split-InitImplicitFlow
# 33: EncodeArithmetic-InitEntropy-Split-EncodeLiterals
# 34: EncodeArithmetic-Split-RandomFuns-InitEntropy
# 35: EncodeLiterals-EncodeArithmetic-Split-InitEntropy
# 36: EncodeLiterals-Split-InitEntropy-InitOpaque
# 37: RandomFuns-EncodeLiterals-Split-InitOpaque
# 38: EncodeArithmetic-InitEntropy-RandomFuns-Split
# 39: Split-RandomFuns-EncodeLiterals-InitImplicitFlow
# 40: EncodeLiterals-EncodeArithmetic-Split-RandomFuns
# 41: Split-EncodeLiterals-EncodeArithmetic-Flatten
# 42: InitOpaque-InitEntropy-EncodeLiterals-Split
# 43: EncodeLiterals-Split-RandomFuns-InitOpaque
# 44: InitEntropy-InitOpaque-EncodeLiterals-Split
# 45: EncodeArithmetic-Split-InitImplicitFlow-EncodeLiterals
# 46: Split-EncodeLiterals-RandomFuns-EncodeArithmetic
# 47: Split-EncodeArithmetic-InitImplicitFlow-EncodeLiterals
# 48: InitImplicitFlow-RandomFuns-EncodeLiterals-Split
# 49: InitImplicitFlow-Split-EncodeLiterals-InitEntropy
# 50: Flatten-Split-EncodeArithmetic-EncodeLiterals
# 51: RandomFuns-InitEntropy-Split-EncodeArithmetic
# 52: EncodeArithmetic-InitEntropy-Split-InitImplicitFlow
# 53: EncodeLiterals-Flatten-RandomFuns-Split
# 54: EncodeLiterals-InitEntropy-RandomFuns-Split
# 55: EncodeArithmetic-Split-EncodeLiterals-InitOpaque
# 56: Split-RandomFuns-EncodeArithmetic-EncodeLiterals
# 57: Split-InitEntropy-EncodeLiterals-RandomFuns
# 58: EncodeLiterals-Split-EncodeArithmetic-RandomFuns
# 59: EncodeArithmetic-InitImplicitFlow-Split-EncodeLiterals
# 60: InitImplicitFlow-Split-EncodeLiterals-InitOpaque
# 61: Split-EncodeLiterals-InitOpaque-InitEntropy
# 62: EncodeLiterals-Split-InitImplicitFlow-InitEntropy
# 63: InitEntropy-InitOpaque-Split-EncodeLiterals
# 64: InitOpaque-Split-EncodeArithmetic-EncodeLiterals
# 65: InitEntropy-Split-EncodeLiterals-EncodeArithmetic
# 66: Split-Flatten-InitOpaque-EncodeLiterals
# 67: Split-Flatten-EncodeLiterals-EncodeArithmetic
# 68: Flatten-Split-InitEntropy-EncodeLiterals
# 69: RandomFuns-Flatten-EncodeLiterals-Split
# 70: Split-InitOpaque-EncodeLiterals-InitEntropy
# 71: Flatten-EncodeLiterals-InitEntropy-Split
# 72: EncodeLiterals-InitOpaque-Split-Flatten
# 73: InitImplicitFlow-EncodeLiterals-RandomFuns-Split
# 74: InitImplicitFlow-EncodeArithmetic-Split-EncodeLiterals
# 75: EncodeLiterals-Split-InitOpaque-EncodeArithmetic
# 76: Split-Flatten-InitEntropy-EncodeLiterals
# 77: RandomFuns-Split-EncodeLiterals-Flatten
# 78: Split-InitEntropy-EncodeArithmetic-RandomFuns
# 79: RandomFuns-EncodeArithmetic-Split-InitEntropy
# 80: EncodeArithmetic-EncodeLiterals-RandomFuns-Split
# 81: RandomFuns-EncodeLiterals-Flatten-Split
# 82: EncodeArithmetic-InitImplicitFlow-EncodeLiterals-Split
# 83: InitOpaque-InitEntropy-Split-EncodeLiterals
# 84: Split-InitEntropy-EncodeLiterals-EncodeArithmetic
# 85: EncodeArithmetic-Split-InitEntropy-EncodeLiterals
# 86: InitOpaque-EncodeLiterals-InitEntropy-Split
# 87: EncodeLiterals-RandomFuns-Split-InitEntropy
# 88: InitOpaque-Split-InitEntropy-EncodeLiterals
# 89: EncodeLiterals-Split-Flatten-InitEntropy
# 90: EncodeLiterals-Split-EncodeArithmetic-InitImplicitFlow
# 91: EncodeLiterals-Flatten-InitEntropy-Split
# 92: InitOpaque-Split-Flatten-EncodeLiterals
# 93: Split-RandomFuns-EncodeLiterals-EncodeArithmetic
# 94: EncodeLiterals-Split-InitOpaque-RandomFuns
# 95: EncodeLiterals-InitOpaque-Flatten-Split
# 96: InitOpaque-Split-RandomFuns-EncodeLiterals
# 97: InitImplicitFlow-Split-InitOpaque-EncodeLiterals
# 98: Flatten-Split-InitOpaque-EncodeLiterals
# 99: Split-InitEntropy-RandomFuns-EncodeArithmetic
# 100: InitImplicitFlow-Split-RandomFuns-EncodeLiterals
# 101: EncodeLiterals-EncodeArithmetic-Flatten-Split
# 102: InitOpaque-EncodeLiterals-InitImplicitFlow-Split
# 103: EncodeArithmetic-EncodeLiterals-Split-Flatten
# 104: EncodeLiterals-Split-InitEntropy-Flatten
# 105: Flatten-InitOpaque-Split-EncodeLiterals
# 106: Split-EncodeArithmetic-InitEntropy-RandomFuns
# 107: RandomFuns-EncodeLiterals-EncodeArithmetic-Split
# ...
# 99: Split-InitEntropy-RandomFuns-EncodeArithmetic
# 100: InitImplicitFlow-Split-RandomFuns-EncodeLiterals
# 101: EncodeLiterals-EncodeArithmetic-Flatten-Split
# 102: InitOpaque-EncodeLiterals-InitImplicitFlow-Split
# 103: EncodeArithmetic-EncodeLiterals-Split-Flatten
# 104: EncodeLiterals-Split-InitEntropy-Flatten
# 105: Flatten-InitOpaque-Split-EncodeLiterals
# 106: Split-EncodeArithmetic-InitEntropy-RandomFuns
# 107: RandomFuns-EncodeLiterals-EncodeArithmetic-Split
# 108: EncodeLiterals-Split-InitOpaque-InitEntropy
# 109: EncodeLiterals-Split-InitEntropy-RandomFuns
# 110: Split-InitOpaque-EncodeArithmetic-EncodeLiterals
# 111: InitEntropy-Split-RandomFuns-EncodeLiterals
# 112: InitOpaque-EncodeArithmetic-EncodeLiterals-Split
# 113: Flatten-EncodeLiterals-Split-InitImplicitFlow
# 114: Split-EncodeLiterals-RandomFuns-InitOpaque
# 115: Flatten-InitImplicitFlow-Split-EncodeLiterals
# 116: Flatten-InitEntropy-Split-EncodeLiterals
# 117: EncodeLiterals-InitEntropy-InitImplicitFlow-Split
# 118: InitEntropy-EncodeArithmetic-Split-InitImplicitFlow
# 119: InitEntropy-EncodeLiterals-InitOpaque-Split
# 120: InitImplicitFlow-InitOpaque-EncodeLiterals-Split
# 121: Flatten-Split-EncodeLiterals-EncodeArithmetic
# 122: EncodeArithmetic-InitEntropy-EncodeLiterals-Split
# 123: EncodeLiterals-InitEntropy-EncodeArithmetic-Split
# 124: Split-InitOpaque-EncodeLiterals-EncodeArithmetic
# 125: Split-EncodeLiterals-InitImplicitFlow-EncodeArithmetic
# 126: InitEntropy-Split-EncodeLiterals-InitOpaque
# 127: InitImplicitFlow-InitEntropy-EncodeLiterals-Split
# 128: EncodeLiterals-Split-EncodeArithmetic-InitEntropy
# 129: EncodeLiterals-EncodeArithmetic-RandomFuns-Split
# 130: InitOpaque-EncodeLiterals-EncodeArithmetic-Split
# 131: InitImplicitFlow-EncodeLiterals-Split-Flatten
# 132: Split-RandomFuns-InitImplicitFlow-EncodeLiterals
# 133: EncodeLiterals-RandomFuns-Flatten-Split
# 134: EncodeLiterals-RandomFuns-Split-InitOpaque
# 135: EncodeLiterals-Split-InitImplicitFlow-Flatten
# 136: InitImplicitFlow-EncodeLiterals-InitEntropy-Split
# 137: RandomFuns-Split-EncodeArithmetic-EncodeLiterals
# 138: InitEntropy-RandomFuns-EncodeLiterals-Split
# 139: RandomFuns-EncodeLiterals-Split-EncodeArithmetic
# 140: Split-EncodeArithmetic-RandomFuns-InitEntropy
# 141: InitEntropy-Split-InitOpaque-EncodeLiterals
# 142: RandomFuns-Split-InitImplicitFlow-EncodeLiterals
# 143: Split-EncodeLiterals-EncodeArithmetic-InitImplicitFlow
# 144: EncodeArithmetic-EncodeLiterals-InitImplicitFlow-Split
# 145: InitEntropy-EncodeLiterals-EncodeArithmetic-Split
# 146: EncodeLiterals-InitEntropy-Split-InitImplicitFlow
# 147: Split-InitEntropy-EncodeArithmetic-InitImplicitFlow
# 148: EncodeLiterals-InitImplicitFlow-Split-Flatten
# 149: Split-EncodeArithmetic-Flatten-EncodeLiterals
# 150: InitImplicitFlow-Split-EncodeArithmetic-EncodeLiterals
# 151: RandomFuns-InitEntropy-Split-EncodeLiterals
# 152: InitEntropy-Split-EncodeArithmetic-RandomFuns
# 153: InitImplicitFlow-Split-Flatten-EncodeLiterals
# 154: EncodeLiterals-EncodeArithmetic-InitEntropy-Split
# 155: InitEntropy-EncodeArithmetic-Split-EncodeLiterals
# 156: InitImplicitFlow-Flatten-Split-EncodeLiterals
# 157: EncodeLiterals-RandomFuns-InitOpaque-Split
# 158: RandomFuns-InitEntropy-EncodeArithmetic-Split
# 159: Split-EncodeLiterals-InitEntropy-InitImplicitFlow
# 160: EncodeArithmetic-RandomFuns-EncodeLiterals-Split
# 161: InitEntropy-EncodeLiterals-Split-Flatten
# 162: RandomFuns-EncodeLiterals-InitEntropy-Split
# 163: Flatten-EncodeLiterals-Split-InitEntropy
# 164: Flatten-Split-InitImplicitFlow-EncodeLiterals
# 165: InitOpaque-EncodeLiterals-Split-EncodeArithmetic
# 166: InitEntropy-EncodeArithmetic-RandomFuns-Split
# 167: Split-EncodeLiterals-EncodeArithmetic-InitOpaque
# 168: InitImplicitFlow-EncodeLiterals-InitOpaque-Split
# 169: InitEntropy-RandomFuns-Split-EncodeArithmetic
# 170: Split-EncodeArithmetic-EncodeLiterals-RandomFuns
# 171: EncodeLiterals-Split-EncodeArithmetic-Flatten
# 172: EncodeLiterals-Flatten-Split-InitOpaque
# 173: EncodeLiterals-InitEntropy-Flatten-Split
# 174: EncodeLiterals-Flatten-Split-EncodeArithmetic
# 175: InitOpaque-Split-InitImplicitFlow-EncodeLiterals
# 176: InitEntropy-EncodeLiterals-Split-InitOpaque
# 177: RandomFuns-Split-InitEntropy-EncodeArithmetic
# 178: EncodeLiterals-EncodeArithmetic-Split-InitImplicitFlow
# 179: Split-InitEntropy-RandomFuns-EncodeLiterals
# 180: RandomFuns-InitOpaque-Split-EncodeLiterals
# 181: EncodeLiterals-Flatten-InitOpaque-Split
# 182: Split-EncodeLiterals-InitImplicitFlow-InitOpaque
# 183: Flatten-InitEntropy-EncodeLiterals-Split
# 184: Flatten-Split-RandomFuns-EncodeLiterals
# 185: Split-EncodeLiterals-InitEntropy-EncodeArithmetic
# 186: Split-EncodeLiterals-Flatten-EncodeArithmetic
# 187: Split-EncodeLiterals-Flatten-InitEntropy
# 188: EncodeLiterals-InitOpaque-EncodeArithmetic-Split
# 189: EncodeLiterals-RandomFuns-Split-EncodeArithmetic
# 190: InitOpaque-EncodeLiterals-Flatten-Split
# 191: EncodeLiterals-EncodeArithmetic-Split-Flatten
# 192: EncodeLiterals-InitImplicitFlow-Split-EncodeArithmetic
# 193: EncodeArithmetic-EncodeLiterals-InitOpaque-Split
# 194: EncodeLiterals-InitImplicitFlow-RandomFuns-Split
# 195: InitEntropy-RandomFuns-Split-EncodeLiterals
# 196: InitEntropy-Split-InitImplicitFlow-EncodeLiterals
# 197: Split-InitOpaque-EncodeLiterals-Flatten
# 198: InitEntropy-EncodeLiterals-Flatten-Split
# 199: RandomFuns-EncodeArithmetic-InitEntropy-Split
# 200: InitEntropy-InitImplicitFlow-Split-EncodeLiterals
# 201: EncodeLiterals-InitEntropy-Split-EncodeArithmetic
# 202: InitEntropy-EncodeLiterals-InitImplicitFlow-Split
# 203: InitImplicitFlow-Split-InitEntropy-EncodeLiterals
# 204: InitEntropy-Split-Flatten-EncodeLiterals
# 205: Split-RandomFuns-Flatten-EncodeLiterals
# 206: Split-RandomFuns-InitOpaque-EncodeLiterals
# 207: EncodeArithmetic-Split-InitEntropy-RandomFuns
# 208: InitOpaque-Split-EncodeLiterals-InitEntropy
# 209: InitOpaque-RandomFuns-Split-EncodeLiterals
# 210: EncodeLiterals-Split-Flatten-InitImplicitFlow
# 211: Split-InitImplicitFlow-EncodeLiterals-InitEntropy
# 212: EncodeLiterals-Split-RandomFuns-InitImplicitFlow
# 213: Split-EncodeArithmetic-InitEntropy-EncodeLiterals
# 214: EncodeArithmetic-InitEntropy-InitImplicitFlow-Split
# 215: EncodeLiterals-InitImplicitFlow-Split-RandomFuns
# 216: EncodeArithmetic-Flatten-EncodeLiterals-Split
# 217: RandomFuns-InitEntropy-EncodeLiterals-Split
# 218: Split-InitOpaque-EncodeLiterals-RandomFuns
# 219: RandomFuns-EncodeLiterals-Split-Flatten
# 220: EncodeArithmetic-EncodeLiterals-Split-InitEntropy
# 221: InitImplicitFlow-EncodeLiterals-EncodeArithmetic-Split
# 222: EncodeLiterals-EncodeArithmetic-Split-InitOpaque
# 223: EncodeArithmetic-EncodeLiterals-Split-InitOpaque
# 224: Split-EncodeArithmetic-EncodeLiterals-Flatten
# 225: EncodeLiterals-Split-RandomFuns-Flatten
# 226: RandomFuns-InitImplicitFlow-Split-EncodeLiterals
# 227: Split-InitImplicitFlow-EncodeLiterals-EncodeArithmetic
# 228: InitOpaque-Split-EncodeLiterals-EncodeArithmetic
# 229: InitEntropy-EncodeLiterals-Split-EncodeArithmetic
# 230: Flatten-EncodeLiterals-RandomFuns-Split
# 231: InitEntropy-Split-EncodeLiterals-Flatten
# 232: EncodeArithmetic-EncodeLiterals-Flatten-Split
# 233: Split-Flatten-EncodeLiterals-InitOpaque
# 234: InitOpaque-EncodeLiterals-Split-Flatten
# 235: RandomFuns-Split-EncodeLiterals-InitEntropy
# 236: Split-EncodeLiterals-InitEntropy-Flatten
# 237: Flatten-RandomFuns-EncodeLiterals-Split
# 238: Flatten-Split-EncodeLiterals-InitImplicitFlow
# 239: EncodeArithmetic-Split-InitOpaque-EncodeLiterals
# 240: RandomFuns-EncodeLiterals-Split-InitEntropy
# 241: InitOpaque-InitImplicitFlow-EncodeLiterals-Split
# 242: EncodeLiterals-Split-Flatten-InitOpaque
# 243: Flatten-EncodeLiterals-Split-InitOpaque
# 244: Split-EncodeArithmetic-EncodeLiterals-InitEntropy
# 245: RandomFuns-InitOpaque-EncodeLiterals-Split
# 246: RandomFuns-Split-InitOpaque-EncodeLiterals
# 247: InitEntropy-RandomFuns-EncodeArithmetic-Split
# 248: InitImplicitFlow-RandomFuns-Split-EncodeLiterals
# 249: InitEntropy-Split-RandomFuns-EncodeArithmetic
# 250: EncodeLiterals-InitOpaque-Split-EncodeArithmetic
# 251: Split-InitEntropy-Flatten-EncodeLiterals
# 252: EncodeArithmetic-Flatten-Split-EncodeLiterals
# 253: Split-Flatten-EncodeLiterals-RandomFuns
# 254: EncodeLiterals-Flatten-EncodeArithmetic-Split
# 255: Split-EncodeLiterals-InitEntropy-RandomFuns
# 256: InitOpaque-Split-EncodeLiterals-Flatten
# 257: Split-InitOpaque-EncodeLiterals-InitImplicitFlow
# 258: Split-InitOpaque-InitEntropy-EncodeLiterals
# 259: InitOpaque-RandomFuns-EncodeLiterals-Split
# 260: Split-Flatten-EncodeLiterals-InitImplicitFlow
# 261: Split-InitEntropy-InitImplicitFlow-EncodeArithmetic
# 262: EncodeLiterals-Flatten-Split-RandomFuns
# 263: InitImplicitFlow-EncodeArithmetic-EncodeLiterals-Split
# 264: EncodeLiterals-RandomFuns-InitImplicitFlow-Split
# 265: EncodeArithmetic-InitEntropy-Split-RandomFuns
# 266: Split-InitImplicitFlow-EncodeLiterals-Flatten
# 267: Split-EncodeLiterals-InitOpaque-Flatten
# 268: InitOpaque-Flatten-EncodeLiterals-Split
# 269: EncodeLiterals-Split-InitImplicitFlow-InitOpaque
# 270: Split-InitEntropy-InitOpaque-EncodeLiterals
# 271: Split-EncodeLiterals-InitOpaque-EncodeArithmetic
# 272: EncodeLiterals-InitOpaque-Split-RandomFuns
# 273: EncodeLiterals-Split-InitOpaque-InitImplicitFlow
# 274: InitEntropy-EncodeArithmetic-EncodeLiterals-Split
# 275: InitOpaque-EncodeLiterals-RandomFuns-Split
# 276: EncodeLiterals-Split-EncodeArithmetic-InitOpaque
# 277: InitEntropy-EncodeLiterals-RandomFuns-Split
# 278: EncodeArithmetic-EncodeLiterals-Split-RandomFuns
# 279: Split-EncodeLiterals-InitImplicitFlow-InitEntropy
# 280: InitEntropy-Flatten-Split-EncodeLiterals
# 281: Flatten-EncodeLiterals-InitOpaque-Split
# 282: RandomFuns-EncodeLiterals-Split-InitImplicitFlow
# 283: EncodeLiterals-InitOpaque-InitImplicitFlow-Split
# 284: Flatten-EncodeLiterals-InitImplicitFlow-Split
# 285: EncodeLiterals-Flatten-Split-InitEntropy
# 286: InitImplicitFlow-EncodeLiterals-Split-InitEntropy
# 287: EncodeLiterals-InitOpaque-InitEntropy-Split
# 288: Flatten-EncodeLiterals-Split-RandomFuns
# 289: InitEntropy-Split-EncodeArithmetic-EncodeLiterals
# 290: EncodeLiterals-RandomFuns-Split-Flatten
# 291: Split-EncodeArithmetic-InitImplicitFlow-InitEntropy
# 292: EncodeLiterals-EncodeArithmetic-InitImplicitFlow-Split
# 293: InitEntropy-Split-EncodeLiterals-RandomFuns
# 294: Split-RandomFuns-EncodeLiterals-InitOpaque
# 295: RandomFuns-Split-EncodeArithmetic-InitEntropy
# 296: EncodeLiterals-InitEntropy-InitOpaque-Split
# 297: EncodeArithmetic-RandomFuns-InitEntropy-Split
# 298: Split-EncodeLiterals-InitEntropy-InitOpaque
# 299: EncodeLiterals-Split-InitImplicitFlow-EncodeArithmetic
# 300: EncodeLiterals-Split-Flatten-EncodeArithmetic
# 301: EncodeLiterals-Split-RandomFuns-EncodeArithmetic
# 302: Split-EncodeArithmetic-EncodeLiterals-InitImplicitFlow
# 303: Split-InitImplicitFlow-EncodeArithmetic-InitEntropy
# 304: EncodeLiterals-InitOpaque-Split-InitEntropy
# 305: InitOpaque-EncodeLiterals-Split-InitEntropy
# 306: InitEntropy-EncodeArithmetic-Split-RandomFuns
# 307: InitImplicitFlow-EncodeLiterals-Split-InitOpaque
# 308: EncodeLiterals-InitOpaque-Split-InitImplicitFlow
# 309: EncodeArithmetic-Split-EncodeLiterals-Flatten
# 310: EncodeLiterals-InitImplicitFlow-InitOpaque-Split
# 311: EncodeLiterals-Split-Flatten-RandomFuns
# 312: InitImplicitFlow-Split-EncodeLiterals-Flatten
# 313: EncodeLiterals-RandomFuns-Split-InitImplicitFlow
# 314: Flatten-InitImplicitFlow-EncodeLiterals-Split
# 315: EncodeLiterals-RandomFuns-InitEntropy-Split
# 316: InitImplicitFlow-InitOpaque-Split-EncodeLiterals
# 317: EncodeArithmetic-Split-InitEntropy-InitImplicitFlow
# 318: RandomFuns-EncodeArithmetic-EncodeLiterals-Split
# 319: InitImplicitFlow-Flatten-EncodeLiterals-Split
# 320: EncodeArithmetic-EncodeLiterals-Split-InitImplicitFlow
# 321: Split-InitEntropy-EncodeLiterals-InitOpaque
# 322: EncodeLiterals-InitEntropy-Split-InitOpaque
# 323: EncodeArithmetic-Split-InitImplicitFlow-InitEntropy
# 324: EncodeArithmetic-Split-EncodeLiterals-InitEntropy
# 325: EncodeLiterals-InitImplicitFlow-EncodeArithmetic-Split
# 326: EncodeLiterals-Flatten-InitImplicitFlow-Split
# 327: Split-EncodeLiterals-InitOpaque-RandomFuns
# 328: Flatten-EncodeArithmetic-Split-EncodeLiterals
# 329: Split-EncodeLiterals-Flatten-InitOpaque
# 330: Split-EncodeArithmetic-InitOpaque-EncodeLiterals
# 331: Split-InitImplicitFlow-EncodeLiterals-InitOpaque
# 332: Split-InitImplicitFlow-InitEntropy-EncodeLiterals
# 333: EncodeLiterals-Split-InitImplicitFlow-RandomFuns
# 334: InitEntropy-Split-EncodeArithmetic-InitImplicitFlow
# 335: Split-Flatten-EncodeArithmetic-EncodeLiterals
# 336: EncodeLiterals-Split-InitEntropy-InitImplicitFlow
# 337: RandomFuns-Flatten-Split-EncodeLiterals
# 338: Split-EncodeLiterals-EncodeArithmetic-RandomFuns
# 339: Split-InitEntropy-InitImplicitFlow-EncodeLiterals
# 340: EncodeLiterals-InitImplicitFlow-Split-InitEntropy
# 341: Split-EncodeLiterals-RandomFuns-Flatten
# 342: InitEntropy-Split-InitImplicitFlow-EncodeArithmetic
# 343: EncodeArithmetic-InitImplicitFlow-InitEntropy-Split
# 344: Split-EncodeArithmetic-RandomFuns-EncodeLiterals
# 345: Split-Flatten-InitImplicitFlow-EncodeLiterals
# 346: Split-RandomFuns-InitEntropy-EncodeLiterals
# 347: Split-InitEntropy-EncodeLiterals-InitImplicitFlow
# 348: InitImplicitFlow-Split-EncodeLiterals-RandomFuns
# 349: EncodeLiterals-InitImplicitFlow-Flatten-Split
# 350: Split-Flatten-RandomFuns-EncodeLiterals
# 351: Flatten-Split-EncodeLiterals-InitEntropy
# 352: RandomFuns-Split-EncodeLiterals-InitImplicitFlow
# 353: EncodeArithmetic-Split-EncodeLiterals-InitImplicitFlow
# 354: Split-InitImplicitFlow-InitOpaque-EncodeLiterals
# 355: Split-EncodeArithmetic-EncodeLiterals-InitOpaque
# 356: Split-RandomFuns-EncodeArithmetic-InitEntropy
# 357: Split-InitOpaque-RandomFuns-EncodeLiterals
# 358: RandomFuns-Split-Flatten-EncodeLiterals
# 359: InitOpaque-Flatten-Split-EncodeLiterals
# 360: RandomFuns-EncodeLiterals-InitOpaque-Split
# 361: Split-EncodeLiterals-InitImplicitFlow-Flatten
# 362: InitEntropy-Flatten-EncodeLiterals-Split
# 363: EncodeLiterals-Split-InitEntropy-EncodeArithmetic
# 364: RandomFuns-EncodeLiterals-InitImplicitFlow-Split
# 365: InitOpaque-EncodeLiterals-Split-RandomFuns
# 366: InitImplicitFlow-EncodeLiterals-Flatten-Split
# 367: Split-EncodeLiterals-InitOpaque-InitImplicitFlow
# 368: Split-InitImplicitFlow-InitEntropy-EncodeArithmetic
# 369: RandomFuns-Split-EncodeLiterals-EncodeArithmetic
# 370: RandomFuns-EncodeArithmetic-Split-EncodeLiterals
# 371: Split-InitImplicitFlow-EncodeArithmetic-EncodeLiterals
# 372: EncodeArithmetic-EncodeLiterals-InitEntropy-Split
# 373: InitEntropy-InitImplicitFlow-EncodeLiterals-Split
# 374: Split-EncodeLiterals-Flatten-InitImplicitFlow
# 375: RandomFuns-Split-InitEntropy-EncodeLiterals
# 376: EncodeLiterals-Flatten-Split-InitImplicitFlow
# 377: Split-InitImplicitFlow-RandomFuns-EncodeLiterals
# 378: Flatten-Split-EncodeLiterals-RandomFuns
# 379: Split-RandomFuns-EncodeLiterals-InitEntropy
# 380: InitOpaque-InitImplicitFlow-Split-EncodeLiterals
# 381: Split-InitOpaque-InitImplicitFlow-EncodeLiterals
# 382: InitImplicitFlow-EncodeLiterals-Split-EncodeArithmetic
# 383: RandomFuns-Split-EncodeLiterals-InitOpaque
# 384: EncodeLiterals-InitOpaque-RandomFuns-Split
# 385: InitOpaque-Split-EncodeLiterals-InitImplicitFlow
# 386: InitOpaque-EncodeLiterals-Split-InitImplicitFlow
# 387: InitImplicitFlow-InitEntropy-Split-EncodeLiterals
# 388: EncodeLiterals-Split-RandomFuns-InitEntropy
# 389: InitOpaque-Split-EncodeLiterals-RandomFuns
# 390: InitOpaque-EncodeArithmetic-Split-EncodeLiterals
# 391: RandomFuns-InitImplicitFlow-EncodeLiterals-Split
# 392: Split-InitImplicitFlow-EncodeLiterals-RandomFuns
# 393: InitImplicitFlow-EncodeLiterals-Split-RandomFuns
# 394: EncodeLiterals-InitImplicitFlow-Split-InitOpaque
# 395: Split-EncodeLiterals-RandomFuns-InitImplicitFlow
# 396: InitEntropy-Split-EncodeLiterals-InitImplicitFlow
# 397: Flatten-EncodeLiterals-Split-EncodeArithmetic
# 398: Split-InitEntropy-EncodeLiterals-Flatten
# 399: Split-RandomFuns-EncodeLiterals-Flatten
# 400: InitEntropy-EncodeLiterals-Split-RandomFuns
# Analizzo la classe: leap_year
# APPOSTO
# Analizzo la classe: theme_park
# APPOSTO
# Analizzo la classe: factorial
# APPOSTO
# Analizzo la classe: n_is_palindrome
# APPOSTO
# Analizzo la classe: strcpy
# APPOSTO
# Analizzo la classe: candy_splitting
# APPOSTO
# Analizzo la classe: strcat
# APPOSTO
# Analizzo la classe: fib_2
# APPOSTO
# Numero di classi senza problemi: 43
# Numero di classi CON problemi: 4

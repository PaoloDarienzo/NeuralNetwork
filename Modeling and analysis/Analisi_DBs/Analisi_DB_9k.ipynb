# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from tensorflow import keras as ks

import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from skimage.transform import resize
from sklearn.metrics import confusion_matrix

import cv2

#Per data visualization
import seaborn as sns

from matplotlib import pyplot as plt

import glob
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import os, os.path

#Per modello NN
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Softmax

import time
import math

import operator

print(tf.__version__)
# Out:
# 1.15.2
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Extract the full file name
def extract_name(from_string):
  to_pos = from_string.index('.')
  substring = from_string[0:to_pos]
  return substring

#Extract the class from the file name, if the class is the string before che -
def extract_label(from_string):
  position = from_string.index('-') # gets position of the - in the filename
  substring = from_string[0:position]
  return substring

#Extract the list of obfuscations applied to label
def extract_obf(from_string):
  start_pos = from_string.index('-')
  end_pos = from_string.index('.')
  substring = from_string[(start_pos + 1):end_pos]
  return substring

def mapping_labels_encoded(label_encoder):
  for index in range(len(list(label_encoder.classes_))):
    #print(index, end = ": ")
    print(index, end = "-> ")
    print(list(label_encoder.inverse_transform([index]))) 

class TimeHistory(ks.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

print("Done")
# Out:
# Done

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

downloaded = drive.CreateFile({'id':"1nderD97u_2d1I6TE3ey8wBtEWqLAosk4"})   # replace the id with id of file you want to access
downloaded.GetContentFile('data_9400_88.zip')        # replace the file name with your file

# !unzip -q data_9400_88.zip -d DB_Repo/

print("Done")
# Out:
# Done

# %%
path, dirs, files = next(os.walk("/content/DB_Repo/data"))
file_count = len(files)
#Should be 14100
print(file_count)
# Out:
# 9400

# %%
# %cd /content/DB_Repo/data
# !pwd
# Out:
# /content/DB_Repo/data
# /content/DB_Repo/data

# %%
#COSTANTI E DICHIARAZIONI

database_list = list()
filename_list = list()
labels_list = list()
obf_list = list()
class_names = set()

#LETTURA E RESIZE IMMAGINI

#Aggiungo i valori alle liste leggendo i vari files
for filename in glob.glob('*.npy'):
  temp_img = np.load(filename)
  database_list.append(temp_img)
  #Salvo il file name
  filename_list.append(extract_name(filename))
  #Salvo la label, ossia la classe
  labels_list.append(extract_label(filename))
  #Creo un set di tutte le classi così trovate
  class_names.add(extract_label(filename))
  #Salvo la lista di offuscatori di ogni file
  obf_list.append(extract_obf(filename))

# %%
'''

#SHUFFLE

#Ho i valori e le etichette in due liste (+ obf); 
#le mescolo mantenendo l'ordine tra valore-label
temp = list(zip(database_list, labels_list, obf_list))
np.random.shuffle(temp)
database_list, labels_list, obf_list = zip(*temp)


'''
# Out:
# "\n\n#SHUFFLE\n\n#Ho i valori e le etichette in due liste (+ obf); \n#le mescolo mantenendo l'ordine tra valore-label\ntemp = list(zip(database_list, labels_list, obf_list))\nnp.random.shuffle(temp)\ndatabase_list, labels_list, obf_list = zip(*temp)\n\n\n"

# %%
assert len(database_list) == len(labels_list) == len(obf_list)

#Trasformo i valori in numpy.ndarray
images = np.array(database_list)

labels = np.array(labels_list)

obf = np.array(obf_list)

numero_file = images.size

# %% [markdown]
# #ANALISI DATABASE

# %%
print("Numero immagini:", images.size)
print("Numero labels:", labels.size)
print("Numero obf:", obf.size)
# Out:
# Numero immagini: 9400
# Numero labels: 9400
# Numero obf: 9400

# %%
dim1, dim2 = images[0].shape
print(dim1, dim2)
# Out:
# 21 64

# %%
np.amax(images[0])
# Out:
# 65535

# %%
dim1_min = 999999
dim2_min = 999999
dim1_max = 0
dim2_max = 0
max_val = 0
min_val = 999999

index_of_maxlen = -1

dim2diff = 999999

count_0_1024 = 0
count_1024_2048 = 0
count_2048_4096 = 0
count_over_4096 = 0
count_err = 0

valore_medio_sotto_1024 = 0
#NB se non è esattamente 65535.0, qualche immagine non ha tale valore come massimo
valore_max_medio = 0

lista_obf_dim = list()
dizionario_dim_obf = dict()

for index in range(images.size):
  dim1_t, dim2_t = images[index].shape

  valore_max_medio += np.amax(images[index])

  dizionario_dim_obf[index] = dim1_t

  if max_val < np.amax(images[index]):
    max_val = np.amax(images[index])
  if min_val > np.amax(images[index]):
    min_val = np.amin(images[index])
  if dim1_t > dim1_max:
    dim1_max = dim1_t
    index_of_maxlen = index
  if dim2_t > dim2_max:
    dim2_max = dim2_t
  if dim1_t < dim1_min:
    dim1_min = dim1_t
  if dim2_t < dim2_min:
    dim2_min = dim2_t
  if dim2_t != 64:
    dim2diff = dim2_t

  if dim1_t <= 1024:
    count_0_1024+=1
    valore_medio_sotto_1024 += dim1_t
  elif dim1_t > 1024 and dim1_t <= 2048:
    count_1024_2048+=1
  elif dim1_t > 2048 and dim1_t <= 4096:
    count_2048_4096+=1
  elif dim1_t > 4096:
    count_over_4096+=1
  else:
    count_err+=1

# %%
valore_medio_sotto_1024 /= count_0_1024
valore_max_medio /= numero_file

sorted_diz = dict(sorted(dizionario_dim_obf.items(), key=operator.itemgetter(1),reverse=True))

# %%
print("Valore più alto:", max_val)
print("Valore più basso:", min_val)
print("Dim1_min:", dim1_min)
print("Dim1_max:", dim1_max)
print("File più lungo:", labels[index_of_maxlen], ",", obf[index_of_maxlen])
print("Dim2_min:", dim2_min)
print("Dim2_max:", dim2_max)
print("Se esiste un valore di dim2 diverso da 64:", dim2diff)
print()
print("Numero dimensioni1 tra 0 e 1024:", count_0_1024)
print("Valore medio dimensioni1 sotto 1024:", valore_medio_sotto_1024)
print("Numero dimensioni1 tra 1024 e 2048:", count_1024_2048)
print("Numero dimensioni1 tra 2048 e 4096:", count_2048_4096)
print("Numero dimensioni1 oltre il 4096:", count_over_4096)
print("Errori nel contare:", count_err)
print()
print("Controllo che il massimo di ogni immagine sia uguale per tutte (ossia 65535):", valore_max_medio)
# Out:
# Valore più alto: 65535
# Valore più basso: 0
# Dim1_min: 7
# Dim1_max: 7889
# File più lungo: fair_warning , InitOpaque-EncodeLiterals-Split
# Dim2_min: 64
# Dim2_max: 64
# Se esiste un valore di dim2 diverso da 64: 999999
#
# Numero dimensioni1 tra 0 e 1024: 8754
# Valore medio dimensioni1 sotto 1024: 70.56339958875942
# Numero dimensioni1 tra 1024 e 2048: 49
# Numero dimensioni1 tra 2048 e 4096: 199
# Numero dimensioni1 oltre il 4096: 398
# Errori nel contare: 0
#
# Controllo che il massimo di ogni immagine sia uguale per tutte (ossia 65535): 65535.0

# %%
counter = 25
for key in sorted_diz:
  print("Lunghezza:", sorted_diz[key], end=", ")
  print(obf[key], end="\t ---> \t\t")
  print(labels[key])
  counter-=1
  if counter == 0:
    break
# Out:
# Lunghezza: 7889, InitOpaque-EncodeLiterals-Split	 ---> 		fair_warning
# Lunghezza: 7886, RandomFuns-Split-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7886, Split-RandomFuns-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7886, InitOpaque-Split-RandomFuns	 ---> 		fair_warning
# Lunghezza: 7886, InitOpaque-RandomFuns-Split	 ---> 		fair_warning
# Lunghezza: 7886, RandomFuns-InitOpaque-Split	 ---> 		fair_warning
# Lunghezza: 7886, Split-InitOpaque-RandomFuns	 ---> 		fair_warning
# Lunghezza: 7885, InitOpaque-EncodeLiterals	 ---> 		fair_warning
# Lunghezza: 7883, EncodeLiterals-InitOpaque-Split	 ---> 		fair_warning
# Lunghezza: 7883, EncodeLiterals-Split-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7882, RandomFuns-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7882, EncodeLiterals-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7882, InitOpaque-RandomFuns	 ---> 		fair_warning
# Lunghezza: 7880, EncodeArithmetic-Split-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7880, InitOpaque-EncodeArithmetic-Split	 ---> 		fair_warning
# Lunghezza: 7880, EncodeArithmetic-InitOpaque-Split	 ---> 		fair_warning
# Lunghezza: 7879, EncodeArithmetic-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7879, InitOpaque-Flatten	 ---> 		fair_warning
# Lunghezza: 7879, Flatten-Split-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7879, Flatten-InitOpaque	 ---> 		fair_warning
# Lunghezza: 7879, InitOpaque-Flatten-Split	 ---> 		fair_warning
# Lunghezza: 7879, Flatten-InitOpaque-Split	 ---> 		fair_warning
# Lunghezza: 7879, InitOpaque-EncodeArithmetic	 ---> 		fair_warning
# Lunghezza: 7877, Split-InitOpaque-EncodeLiterals	 ---> 		fair_warning
# Lunghezza: 7877, InitOpaque-Split-EncodeLiterals	 ---> 		fair_warning

# %%
classi_e_val = list()

for indice in range(images.size):
  dimensione_classe = images[indice].shape[0]
  classe = labels[indice]
  classi_e_val.append((classe, dimensione_classe))

# %%
from itertools import groupby
from operator import itemgetter
from statistics import mean


#s = [('A', 1), ('B', 2), ('C', 3), ('A', 9), ('B', 8)]
s = classi_e_val
s2 = sorted(s, key=itemgetter(0))   # sorting the tuple based on 0th index

dimension_list = [(k, int(mean(list(zip(*g))[1]))) for k, g in groupby(s2, itemgetter(0))]

# %%
sorted_by_second = sorted(dimension_list, key=lambda tup: tup[1])

# %%
for elem in sorted_by_second:
  print(elem)
# Out:
# ('hello_world', 37)
# ('count_digits', 40)
# ('factors', 40)
# ('pyramid', 40)
# ('reverse_integer', 40)
# ('sum', 40)
# ('times_table', 40)
# ('factorial_rec', 41)
# ('fib_1', 41)
# ('fib_2', 41)
# ('gcd', 41)
# ('power_n', 41)
# ('strcpy', 41)
# ('strlen', 41)
# ('gcd_rec', 42)
# ('lcm', 42)
# ('n_is_palindrome', 42)
# ('n_is_prime', 42)
# ('positive_or_negative', 42)
# ('remove_char', 42)
# ('factorial', 43)
# ('leap_year', 43)
# ('prime_n_between_intervals', 43)
# ('strcat', 43)
# ('armstrong_n', 44)
# ('char_frequency', 44)
# ('n_is_sum_of_primes', 44)
# ('quotient_remainder', 44)
# ('minimum_scalar_product', 45)
# ('snapper_chain', 46)
# ('stringsort', 46)
# ('candy_splitting', 47)
# ('calculator', 48)
# ('store_struct', 50)
# ('count_vowels', 51)
# ('fly_swatter', 53)
# ('saving_the_universe', 54)
# ('train_time_table', 61)
# ('rotate', 76)
# ('bot_trust', 79)
# ('welcome_to_codejam', 118)
# ('multibase_happiness', 148)
# ('theme_park', 252)
# ('watersheds', 992)
# ('magicka', 3566)
# ('alien_language', 4537)
# ('fair_warning', 7762)

# %%
obf_set = set()

for index in range(obf.size):
  for elem in obf[index].split('-'):
    obf_set.add(elem)

print("Trasformazioni applicate:")
print(sorted(obf_set))

sorted_obf_set = sorted(obf_set)
counter = 1
for elem in (sorted_obf_set):
  print("{}: {}".format(counter, elem))
  counter += 1
# Out:
# Trasformazioni applicate:
# ['EncodeArithmetic', 'EncodeLiterals', 'Flatten', 'InitEntropy', 'InitImplicitFlow', 'InitOpaque', 'RandomFuns', 'Split', 'base']
# 1: EncodeArithmetic
# 2: EncodeLiterals
# 3: Flatten
# 4: InitEntropy
# 5: InitImplicitFlow
# 6: InitOpaque
# 7: RandomFuns
# 8: Split
# 9: base

# %%
labels_set = set()

for index in range(obf.size):
  for elem in labels[index].split('-'):
    labels_set.add(elem)

print("Programmi (labels) analizzati:")

sorted_labels_set = sorted(labels_set)
counter = 1
for elem in (sorted_labels_set):
  print("{}: {}".format(counter, elem))
  counter += 1
# Out:
# Programmi (labels) analizzati:
# 1: alien_language
# 2: armstrong_n
# 3: bot_trust
# 4: calculator
# 5: candy_splitting
# 6: char_frequency
# 7: count_digits
# 8: count_vowels
# 9: factorial
# 10: factorial_rec
# 11: factors
# 12: fair_warning
# 13: fib_1
# 14: fib_2
# 15: fly_swatter
# 16: gcd
# 17: gcd_rec
# 18: hello_world
# 19: lcm
# 20: leap_year
# 21: magicka
# 22: minimum_scalar_product
# 23: multibase_happiness
# 24: n_is_palindrome
# 25: n_is_prime
# 26: n_is_sum_of_primes
# 27: positive_or_negative
# 28: power_n
# 29: prime_n_between_intervals
# 30: pyramid
# 31: quotient_remainder
# 32: remove_char
# 33: reverse_integer
# 34: rotate
# 35: saving_the_universe
# 36: snapper_chain
# 37: store_struct
# 38: strcat
# 39: strcpy
# 40: stringsort
# 41: strlen
# 42: sum
# 43: theme_park
# 44: times_table
# 45: train_time_table
# 46: watersheds
# 47: welcome_to_codejam

# %%
set_transformations = set()

for elem in obf:
  set_transformations.add(elem)

number_of_unique_trans = len(set_transformations)
print(number_of_unique_trans)

set_transformations_sorted = sorted(set_transformations)
# Out:
# 200

# %%
print("Trasformazioni applicate: ")
counter = 1
for elem in set_transformations_sorted:
  print("{}: {}".format(counter, elem))
  counter += 1
# Out:
# Trasformazioni applicate:
# 1: EncodeArithmetic
# 2: EncodeArithmetic-EncodeLiterals
# 3: EncodeArithmetic-EncodeLiterals-InitEntropy
# 4: EncodeArithmetic-EncodeLiterals-RandomFuns
# 5: EncodeArithmetic-EncodeLiterals-Split
# 6: EncodeArithmetic-Flatten
# 7: EncodeArithmetic-Flatten-Split
# 8: EncodeArithmetic-InitEntropy
# 9: EncodeArithmetic-InitEntropy-EncodeLiterals
# 10: EncodeArithmetic-InitEntropy-Split
# 11: EncodeArithmetic-InitImplicitFlow
# 12: EncodeArithmetic-InitImplicitFlow-Split
# 13: EncodeArithmetic-InitOpaque
# 14: EncodeArithmetic-InitOpaque-Split
# 15: EncodeArithmetic-RandomFuns
# 16: EncodeArithmetic-RandomFuns-Split
# 17: EncodeArithmetic-Split
# 18: EncodeArithmetic-Split-EncodeLiterals
# 19: EncodeArithmetic-Split-Flatten
# 20: EncodeArithmetic-Split-InitEntropy
# 21: EncodeArithmetic-Split-InitImplicitFlow
# 22: EncodeArithmetic-Split-InitOpaque
# 23: EncodeArithmetic-Split-RandomFuns
# 24: EncodeLiterals
# 25: EncodeLiterals-EncodeArithmetic
# 26: EncodeLiterals-EncodeArithmetic-InitEntropy
# 27: EncodeLiterals-EncodeArithmetic-RandomFuns
# 28: EncodeLiterals-EncodeArithmetic-Split
# 29: EncodeLiterals-Flatten
# 30: EncodeLiterals-Flatten-Split
# 31: EncodeLiterals-InitEntropy
# 32: EncodeLiterals-InitEntropy-EncodeArithmetic
# 33: EncodeLiterals-InitEntropy-Split
# 34: EncodeLiterals-InitImplicitFlow
# 35: EncodeLiterals-InitImplicitFlow-Split
# 36: EncodeLiterals-InitOpaque
# 37: EncodeLiterals-InitOpaque-Split
# 38: EncodeLiterals-RandomFuns
# 39: EncodeLiterals-RandomFuns-EncodeArithmetic
# 40: EncodeLiterals-RandomFuns-Split
# 41: EncodeLiterals-Split
# 42: EncodeLiterals-Split-EncodeArithmetic
# 43: EncodeLiterals-Split-Flatten
# 44: EncodeLiterals-Split-InitEntropy
# 45: EncodeLiterals-Split-InitImplicitFlow
# 46: EncodeLiterals-Split-InitOpaque
# 47: EncodeLiterals-Split-RandomFuns
# 48: Flatten
# 49: Flatten-EncodeArithmetic
# 50: Flatten-EncodeArithmetic-Split
# 51: Flatten-EncodeLiterals
# 52: Flatten-EncodeLiterals-Split
# 53: Flatten-InitEntropy
# 54: Flatten-InitEntropy-Split
# 55: Flatten-InitImplicitFlow
# 56: Flatten-InitImplicitFlow-Split
# 57: Flatten-InitOpaque
# 58: Flatten-InitOpaque-Split
# 59: Flatten-RandomFuns
# 60: Flatten-RandomFuns-Split
# 61: Flatten-Split
# 62: Flatten-Split-EncodeArithmetic
# 63: Flatten-Split-EncodeLiterals
# 64: Flatten-Split-InitEntropy
# 65: Flatten-Split-InitImplicitFlow
# 66: Flatten-Split-InitOpaque
# 67: Flatten-Split-RandomFuns
# 68: InitEntropy
# 69: InitEntropy-EncodeArithmetic
# 70: InitEntropy-EncodeArithmetic-EncodeLiterals
# 71: InitEntropy-EncodeArithmetic-Split
# 72: InitEntropy-EncodeLiterals
# 73: InitEntropy-EncodeLiterals-EncodeArithmetic
# 74: InitEntropy-EncodeLiterals-Split
# 75: InitEntropy-Flatten
# 76: InitEntropy-Flatten-Split
# 77: InitEntropy-InitImplicitFlow
# 78: InitEntropy-InitImplicitFlow-Split
# 79: InitEntropy-InitOpaque
# 80: InitEntropy-InitOpaque-Split
# 81: InitEntropy-RandomFuns
# 82: InitEntropy-RandomFuns-Split
# 83: InitEntropy-Split
# 84: InitEntropy-Split-EncodeArithmetic
# 85: InitEntropy-Split-EncodeLiterals
# 86: InitEntropy-Split-Flatten
# 87: InitEntropy-Split-InitImplicitFlow
# 88: InitEntropy-Split-InitOpaque
# 89: InitEntropy-Split-RandomFuns
# 90: InitImplicitFlow
# 91: InitImplicitFlow-EncodeArithmetic
# 92: InitImplicitFlow-EncodeArithmetic-Split
# 93: InitImplicitFlow-EncodeLiterals
# 94: InitImplicitFlow-EncodeLiterals-Split
# 95: InitImplicitFlow-Flatten
# 96: InitImplicitFlow-Flatten-Split
# 97: InitImplicitFlow-InitEntropy
# 98: InitImplicitFlow-InitEntropy-Split
# 99: InitImplicitFlow-InitOpaque
# 100: InitImplicitFlow-InitOpaque-Split
# 101: InitImplicitFlow-RandomFuns
# 102: InitImplicitFlow-RandomFuns-Split
# 103: InitImplicitFlow-Split
# 104: InitImplicitFlow-Split-EncodeArithmetic
# 105: InitImplicitFlow-Split-EncodeLiterals
# 106: InitImplicitFlow-Split-Flatten
# 107: InitImplicitFlow-Split-InitEntropy
# 108: InitImplicitFlow-Split-InitOpaque
# 109: InitImplicitFlow-Split-RandomFuns
# 110: InitOpaque
# 111: InitOpaque-EncodeArithmetic
# 112: InitOpaque-EncodeArithmetic-Split
# 113: InitOpaque-EncodeLiterals
# 114: InitOpaque-EncodeLiterals-Split
# 115: InitOpaque-Flatten
# 116: InitOpaque-Flatten-Split
# 117: InitOpaque-InitEntropy
# 118: InitOpaque-InitEntropy-Split
# 119: InitOpaque-InitImplicitFlow
# 120: InitOpaque-InitImplicitFlow-Split
# 121: InitOpaque-RandomFuns
# 122: InitOpaque-RandomFuns-Split
# 123: InitOpaque-Split
# 124: InitOpaque-Split-EncodeArithmetic
# 125: InitOpaque-Split-EncodeLiterals
# 126: InitOpaque-Split-Flatten
# 127: InitOpaque-Split-InitEntropy
# 128: InitOpaque-Split-InitImplicitFlow
# 129: InitOpaque-Split-RandomFuns
# 130: RandomFuns
# 131: RandomFuns-EncodeArithmetic
# 132: RandomFuns-EncodeArithmetic-Split
# 133: RandomFuns-EncodeLiterals
# 134: RandomFuns-EncodeLiterals-Split
# 135: RandomFuns-Flatten
# 136: RandomFuns-Flatten-Split
# 137: RandomFuns-InitEntropy
# 138: RandomFuns-InitEntropy-Split
# 139: RandomFuns-InitImplicitFlow
# 140: RandomFuns-InitImplicitFlow-Split
# 141: RandomFuns-InitOpaque
# 142: RandomFuns-InitOpaque-Split
# 143: RandomFuns-Split
# 144: RandomFuns-Split-EncodeArithmetic
# 145: RandomFuns-Split-EncodeLiterals
# 146: RandomFuns-Split-Flatten
# 147: RandomFuns-Split-InitEntropy
# 148: RandomFuns-Split-InitImplicitFlow
# 149: RandomFuns-Split-InitOpaque
# 150: Split
# 151: Split-EncodeArithmetic
# 152: Split-EncodeArithmetic-EncodeLiterals
# 153: Split-EncodeArithmetic-Flatten
# 154: Split-EncodeArithmetic-InitEntropy
# 155: Split-EncodeArithmetic-InitImplicitFlow
# 156: Split-EncodeArithmetic-InitOpaque
# 157: Split-EncodeArithmetic-RandomFuns
# 158: Split-EncodeLiterals
# 159: Split-EncodeLiterals-EncodeArithmetic
# 160: Split-EncodeLiterals-Flatten
# 161: Split-EncodeLiterals-InitEntropy
# 162: Split-EncodeLiterals-InitImplicitFlow
# 163: Split-EncodeLiterals-InitOpaque
# 164: Split-EncodeLiterals-RandomFuns
# 165: Split-Flatten
# 166: Split-Flatten-EncodeArithmetic
# 167: Split-Flatten-EncodeLiterals
# 168: Split-Flatten-InitEntropy
# 169: Split-Flatten-InitImplicitFlow
# 170: Split-Flatten-InitOpaque
# 171: Split-Flatten-RandomFuns
# 172: Split-InitEntropy
# 173: Split-InitEntropy-EncodeArithmetic
# 174: Split-InitEntropy-EncodeLiterals
# 175: Split-InitEntropy-Flatten
# 176: Split-InitEntropy-InitImplicitFlow
# 177: Split-InitEntropy-InitOpaque
# 178: Split-InitEntropy-RandomFuns
# 179: Split-InitImplicitFlow
# 180: Split-InitImplicitFlow-EncodeArithmetic
# 181: Split-InitImplicitFlow-EncodeLiterals
# 182: Split-InitImplicitFlow-Flatten
# 183: Split-InitImplicitFlow-InitEntropy
# 184: Split-InitImplicitFlow-InitOpaque
# 185: Split-InitImplicitFlow-RandomFuns
# 186: Split-InitOpaque
# 187: Split-InitOpaque-EncodeArithmetic
# 188: Split-InitOpaque-EncodeLiterals
# 189: Split-InitOpaque-Flatten
# 190: Split-InitOpaque-InitEntropy
# 191: Split-InitOpaque-InitImplicitFlow
# 192: Split-InitOpaque-RandomFuns
# 193: Split-RandomFuns
# 194: Split-RandomFuns-EncodeArithmetic
# 195: Split-RandomFuns-EncodeLiterals
# 196: Split-RandomFuns-Flatten
# 197: Split-RandomFuns-InitEntropy
# 198: Split-RandomFuns-InitImplicitFlow
# 199: Split-RandomFuns-InitOpaque
# 200: base

# %%
def indices(lst, element):
    result = []
    offset = -1
    while True:
        try:
            offset = lst.index(element, offset+1)
        except ValueError:
            return result
        result.append(offset)

# %%
print("Programmi che non hanno tutte le trasformazioni, e trasformazioni da loro saltate:")

counterOk = 0
counterWrong = 0

for class_name in class_names:
  print("Analizzo la classe: " + class_name)

  set_of_obf_per_class = set()
  #setDiff = set()

  indici = indices(labels_list, class_name)

  for elem in indici:
    set_of_obf_per_class.add(obf_list[elem])


  setDiff = set_transformations - set_of_obf_per_class

  if len(setDiff) == 0:
    print("APPOSTO")
    counterOk += 1
  else:
    counterWrong += 1
    counterDiff = 1
    for elem in setDiff:
      print("{}: {}".format(counterDiff, elem))
      counterDiff += 1

print("{}: {}".format("Numero di classi senza problemi", counterOk))
print("{}: {}".format("Numero di classi CON problemi", counterWrong))
# Out:
# Programmi che non hanno tutte le trasformazioni, e trasformazioni da loro saltate:
# Analizzo la classe: train_time_table
# APPOSTO
# Analizzo la classe: quotient_remainder
# APPOSTO
# Analizzo la classe: snapper_chain
# APPOSTO
# Analizzo la classe: candy_splitting
# APPOSTO
# Analizzo la classe: stringsort
# APPOSTO
# Analizzo la classe: sum
# APPOSTO
# Analizzo la classe: hello_world
# APPOSTO
# Analizzo la classe: factors
# APPOSTO
# Analizzo la classe: store_struct
# APPOSTO
# Analizzo la classe: char_frequency
# APPOSTO
# Analizzo la classe: fib_2
# APPOSTO
# Analizzo la classe: positive_or_negative
# APPOSTO
# Analizzo la classe: magicka
# APPOSTO
# Analizzo la classe: power_n
# APPOSTO
# Analizzo la classe: fair_warning
# APPOSTO
# Analizzo la classe: factorial_rec
# APPOSTO
# Analizzo la classe: welcome_to_codejam
# APPOSTO
# Analizzo la classe: strcat
# APPOSTO
# Analizzo la classe: n_is_palindrome
# APPOSTO
# Analizzo la classe: calculator
# APPOSTO
# Analizzo la classe: gcd_rec
# APPOSTO
# Analizzo la classe: armstrong_n
# APPOSTO
# Analizzo la classe: leap_year
# APPOSTO
# Analizzo la classe: bot_trust
# APPOSTO
# Analizzo la classe: reverse_integer
# APPOSTO
# Analizzo la classe: factorial
# APPOSTO
# Analizzo la classe: strcpy
# APPOSTO
# Analizzo la classe: n_is_prime
# APPOSTO
# Analizzo la classe: prime_n_between_intervals
# APPOSTO
# Analizzo la classe: n_is_sum_of_primes
# APPOSTO
# Analizzo la classe: strlen
# APPOSTO
# Analizzo la classe: alien_language
# APPOSTO
# Analizzo la classe: count_vowels
# APPOSTO
# Analizzo la classe: remove_char
# APPOSTO
# Analizzo la classe: watersheds
# APPOSTO
# Analizzo la classe: fly_swatter
# APPOSTO
# Analizzo la classe: count_digits
# APPOSTO
# Analizzo la classe: minimum_scalar_product
# APPOSTO
# Analizzo la classe: fib_1
# APPOSTO
# Analizzo la classe: multibase_happiness
# APPOSTO
# Analizzo la classe: lcm
# APPOSTO
# Analizzo la classe: pyramid
# APPOSTO
# Analizzo la classe: saving_the_universe
# APPOSTO
# Analizzo la classe: times_table
# APPOSTO
# Analizzo la classe: gcd
# APPOSTO
# Analizzo la classe: rotate
# APPOSTO
# Analizzo la classe: theme_park
# APPOSTO
# Numero di classi senza problemi: 47
# Numero di classi CON problemi: 0

# %% [markdown]
# #Descrizione
#
# Modello su database da 36k; rete bidirezionale LSTM (CuDNN).
#
# Eseguito codice 4:
#
# 1.   2 layer da 141 nodi, 94 nodi;
# 2.   Immagini 256x64;
# 3.   256 batch size;
# 4.   Accuratezza finale: 95%.
#
# (Patience = 10).

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install PyDrive
# Out:
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.7.12)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.17.4)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.8)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (4.0)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (1.12.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.8)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.7.2)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.0.3)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->PyDrive) (3.1.1)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->PyDrive) (47.1.1)

# %% [markdown]
# #Import

# %%
import tensorflow as tf
from tensorflow import keras as ks

import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from skimage.transform import resize

import cv2

#Data visualization
import seaborn as sns

from matplotlib import pyplot as plt

import glob
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import os, os.path

#Per modello NN
from tensorflow.keras import layers
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import CuDNNLSTM
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import ConvLSTM2D
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Softmax
from tensorflow.keras.layers import Dropout

import time
import math

print(tf.__version__)
# Out:
# 1.15.2
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ##Defining methods

# %%
class Stats:

  def __init__( self, img_dim, perc_used, batch_size_used, 
                val_acc, val_loss, total_epochs,
                early_stopping_epochs, total_time, modello, history, _for_conf_matr, model_name):
    
    self.model = modello
    self.history = history

    self._for_conf_matr = _for_conf_matr

    self.img_dim = img_dim           
    self.perc = str(perc_used)
    self.batch_size = str(batch_size_used)
    
    self.val_acc = str(round(val_acc, 5))
    self.val_loss = str(round(val_loss, 5))

    self.total_epochs = str(total_epochs)
    self.early_stopping_epochs = str(early_stopping_epochs)
    self.training_time = str(round(total_time, 5))
    self.model_name = model_name

  def myStats(self):
    print("Dimensione immagini: ", self.img_dim)
    print("Percentuale test set: " + self.perc + "%")
    print("Dimensione batch size: " + self.batch_size)

    print("Val accuracy: " + self.val_acc)
    print("Val loss: " + self.val_loss)

    print("Epoche di addestramento utilizzate: " + self.early_stopping_epochs + "/" + self.total_epochs)
    print("Tempo di addestramento: " + self.training_time + " sec")
    print("Model: " + self.model_name)

# %%
#Extract the class from the file name, if the class is the string before che -
def extract_label(from_string):
  position = from_string.index('-') # gets position of the - in the filename
  substring = from_string[0:position]
  return substring

def extract_obf(from_string):
  start_pos = from_string.index('-')
  end_pos = from_string.index('.')
  substring = from_string[(start_pos + 1):end_pos]
  return substring

def mapping_labels_encoded(label_encoder):
  for index in range(len(list(label_encoder.classes_))):
    print(index, end = "-> ")
    print(list(label_encoder.inverse_transform([index]))) 

class TimeHistory(ks.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')


print("Done")
# Out:
# Done

# %% [markdown]
# #Import database

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
downloaded = drive.CreateFile({'id':"1iDz4FJROi7aW45Y0ZQjkNRsE9NLxIXmG"})   # replace the id with id of file you want to access
downloaded.GetContentFile('data_36k.zip')        # replace the file name with your file

# %%
# !unzip -qq data_36k.zip -d DB_Repo/

print("Done")
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: DB_Repo/data/strlen-RandomFuns-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitEntropy-Flatten.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitEntropy-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitEntropy-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitEntropy-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitEntropy-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitEntropy-Split.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitImplicitFlow-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitImplicitFlow-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitImplicitFlow-Flatten.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitImplicitFlow-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitImplicitFlow-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitImplicitFlow-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitImplicitFlow-Split.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitOpaque-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitOpaque-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitOpaque-Flatten.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitOpaque-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitOpaque-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitOpaque-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitOpaque-Split.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-EncodeArithmetic-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-Flatten.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-InitEntropy-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-RandomFuns-Split.npy
#   inflating: DB_Repo/data/strlen-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-InitEntropy-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-InitEntropy-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-InitImplicitFlow-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-RandomFuns-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-EncodeArithmetic-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-EncodeArithmetic-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-EncodeArithmetic-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-EncodeArithmetic-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-EncodeArithmetic-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-Flatten-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-Flatten-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-Flatten-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-Flatten-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-Flatten-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitEntropy-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitEntropy-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitEntropy-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitEntropy-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitEntropy-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitImplicitFlow-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitImplicitFlow-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitImplicitFlow-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitImplicitFlow-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitImplicitFlow-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitOpaque-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitOpaque-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitOpaque-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitOpaque-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitOpaque-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-RandomFuns-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-RandomFuns-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-RandomFuns-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-RandomFuns-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-RandomFuns-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-EncodeArithmetic-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-EncodeArithmetic-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-InitImplicitFlow-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-RandomFuns-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-EncodeArithmetic-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-InitEntropy-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-EncodeArithmetic-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-Flatten.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-InitEntropy-EncodeArithmetic.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-InitEntropy.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-InitImplicitFlow.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns-InitOpaque.npy
#   inflating: DB_Repo/data/strlen-Split-RandomFuns.npy
#   inflating: DB_Repo/data/strlen-Split.npy
#   inflating: DB_Repo/data/strlen-base.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-Flatten-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-InitEntropy-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-InitImplicitFlow-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-InitOpaque-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-RandomFuns-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-Split-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-Split-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-Split-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-Split-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Flatten-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Flatten-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Flatten-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Flatten-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Flatten-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Flatten-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Flatten-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitEntropy-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitEntropy-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitEntropy-InitImplicitFlow-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitEntropy-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitEntropy-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitEntropy-RandomFuns-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitEntropy-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitEntropy-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitEntropy-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitEntropy-Split-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitEntropy-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitImplicitFlow-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitImplicitFlow-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitImplicitFlow-InitEntropy-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitImplicitFlow-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitImplicitFlow-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitImplicitFlow-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitImplicitFlow-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitImplicitFlow-Split-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitImplicitFlow-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitOpaque-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitOpaque-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitOpaque-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitOpaque-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitOpaque-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitOpaque-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitOpaque-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-RandomFuns-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-RandomFuns-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-RandomFuns-InitEntropy-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-RandomFuns-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-RandomFuns-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-RandomFuns-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-RandomFuns-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-RandomFuns-Split-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-RandomFuns-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-InitEntropy-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-InitEntropy-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-InitImplicitFlow-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-RandomFuns-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic-Split.npy
#   inflating: DB_Repo/data/sum-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-Flatten-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-InitEntropy-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-InitImplicitFlow-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-InitOpaque-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-RandomFuns-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-Split-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-Split-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-Split-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-Split-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-EncodeArithmetic-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-InitEntropy-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-InitImplicitFlow-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-InitOpaque-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-RandomFuns-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-Split-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-Split-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-Split-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-EncodeArithmetic-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-Flatten-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-InitImplicitFlow-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-InitOpaque-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-RandomFuns-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-Split-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-Split-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-Split-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-EncodeArithmetic-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-Flatten-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-InitEntropy-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-InitOpaque-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-RandomFuns-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-Split-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-Split-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-Split-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-Split-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-EncodeArithmetic-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-Flatten-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-InitEntropy-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-InitImplicitFlow-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-RandomFuns-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-Split-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-Split-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-Split-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-EncodeArithmetic-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-Flatten-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-InitEntropy-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-InitImplicitFlow-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-InitOpaque-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-Split-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-Split-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-Split-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-EncodeArithmetic-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-EncodeArithmetic-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-EncodeArithmetic-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-EncodeArithmetic-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-EncodeArithmetic-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-Flatten-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-Flatten-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-Flatten-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-Flatten-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-Flatten-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitEntropy-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitEntropy-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitEntropy-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitEntropy-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitEntropy-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitImplicitFlow-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitImplicitFlow-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitImplicitFlow-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitImplicitFlow-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitImplicitFlow-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitOpaque-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitOpaque-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitOpaque-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitOpaque-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitOpaque-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-RandomFuns-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-RandomFuns-Flatten.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-RandomFuns-InitEntropy.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-RandomFuns-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-RandomFuns-InitOpaque.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split-RandomFuns.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeArithmetic-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeArithmetic-InitEntropy.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeArithmetic-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeArithmetic-InitOpaque.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeArithmetic-RandomFuns.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeArithmetic-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeArithmetic-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-EncodeArithmetic-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-InitEntropy-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-InitImplicitFlow-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-InitOpaque-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-RandomFuns-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-Split-InitEntropy.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-Split-InitOpaque.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-Split-RandomFuns.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-InitEntropy-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-Flatten-InitEntropy-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-InitEntropy-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-Flatten-InitEntropy-InitOpaque.npy
#   inflating: DB_Repo/data/sum-Flatten-InitEntropy-RandomFuns.npy
#   inflating: DB_Repo/data/sum-Flatten-InitEntropy-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-InitEntropy-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-InitEntropy.npy
#   inflating: DB_Repo/data/sum-Flatten-InitImplicitFlow-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-Flatten-InitImplicitFlow-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-InitImplicitFlow-InitEntropy.npy
#   inflating: DB_Repo/data/sum-Flatten-InitImplicitFlow-InitOpaque.npy
#   inflating: DB_Repo/data/sum-Flatten-InitImplicitFlow-RandomFuns.npy
#   inflating: DB_Repo/data/sum-Flatten-InitImplicitFlow-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-InitImplicitFlow-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-Flatten-InitOpaque-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-Flatten-InitOpaque-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-InitOpaque-InitEntropy.npy
#   inflating: DB_Repo/data/sum-Flatten-InitOpaque-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-Flatten-InitOpaque-RandomFuns.npy
#   inflating: DB_Repo/data/sum-Flatten-InitOpaque-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-InitOpaque-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-InitOpaque.npy
#   inflating: DB_Repo/data/sum-Flatten-RandomFuns-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-Flatten-RandomFuns-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-RandomFuns-InitEntropy.npy
#   inflating: DB_Repo/data/sum-Flatten-RandomFuns-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-Flatten-RandomFuns-InitOpaque.npy
#   inflating: DB_Repo/data/sum-Flatten-RandomFuns-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-RandomFuns-Split.npy
#   inflating: DB_Repo/data/sum-Flatten-RandomFuns.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-InitEntropy.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-InitOpaque.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-Flatten-Split-RandomFuns.npy
#   inflating: DB_Repo/data/sum-Flatten-Split.npy
#   inflating: DB_Repo/data/sum-Flatten.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeArithmetic-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeArithmetic-Flatten.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeArithmetic-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeArithmetic-InitOpaque.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeArithmetic-RandomFuns-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeArithmetic-RandomFuns.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeArithmetic-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeArithmetic-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeArithmetic-Split-RandomFuns.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeArithmetic-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-EncodeArithmetic-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-Flatten-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-InitImplicitFlow-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-InitOpaque-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-RandomFuns-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-Split-Flatten.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-Split-InitOpaque.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-Split-RandomFuns.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Flatten-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Flatten-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Flatten-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Flatten-InitOpaque.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Flatten-RandomFuns.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Flatten-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Flatten-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Flatten.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitImplicitFlow-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitImplicitFlow-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitImplicitFlow-Flatten.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitImplicitFlow-InitOpaque.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitImplicitFlow-RandomFuns.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitImplicitFlow-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitImplicitFlow-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitOpaque-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitOpaque-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitOpaque-Flatten.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitOpaque-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitOpaque-RandomFuns.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitOpaque-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitOpaque-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-InitOpaque.npy
#   inflating: DB_Repo/data/sum-InitEntropy-RandomFuns-EncodeArithmetic-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-RandomFuns-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-InitEntropy-RandomFuns-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-RandomFuns-Flatten.npy
#   inflating: DB_Repo/data/sum-InitEntropy-RandomFuns-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-InitEntropy-RandomFuns-InitOpaque.npy
#   inflating: DB_Repo/data/sum-InitEntropy-RandomFuns-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-InitEntropy-RandomFuns-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-RandomFuns-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy-RandomFuns.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-EncodeArithmetic-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-EncodeArithmetic-RandomFuns.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-Flatten.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-InitImplicitFlow-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-InitOpaque.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-RandomFuns-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split-RandomFuns.npy
#   inflating: DB_Repo/data/sum-InitEntropy-Split.npy
#   inflating: DB_Repo/data/sum-InitEntropy.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeArithmetic-EncodeLiterals-Split.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeArithmetic-Flatten.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeArithmetic-InitEntropy.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeArithmetic-InitOpaque.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeArithmetic-RandomFuns.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeArithmetic-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeArithmetic-Split.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeLiterals-EncodeArithmetic-Split.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeLiterals-Flatten-Split.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeLiterals-InitEntropy-Split.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeLiterals-InitOpaque-Split.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/sum-InitImplicitFlow-EncodeLiterals-RandomFuns-Split.npy
# ...
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-InitOpaque-Split.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-EncodeArithmetic-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-InitEntropy-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns-Split.npy
#   inflating: DB_Repo/data/welcome_to_codejam-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-InitEntropy-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-InitEntropy-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-InitImplicitFlow-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-RandomFuns-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-EncodeArithmetic-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-EncodeArithmetic-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-EncodeArithmetic-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-EncodeArithmetic-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-EncodeArithmetic-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-Flatten-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-Flatten-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-Flatten-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-Flatten-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-Flatten-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitEntropy-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitEntropy-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitEntropy-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitEntropy-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitEntropy-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitImplicitFlow-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitImplicitFlow-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitImplicitFlow-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitImplicitFlow-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitImplicitFlow-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitOpaque-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitOpaque-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitOpaque-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitOpaque-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitOpaque-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-RandomFuns-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-RandomFuns-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-RandomFuns-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-RandomFuns-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-RandomFuns-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-EncodeArithmetic-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-EncodeArithmetic-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-InitImplicitFlow-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-RandomFuns-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-EncodeArithmetic-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-InitEntropy-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-EncodeLiterals-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-EncodeArithmetic-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-EncodeArithmetic-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-EncodeLiterals-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-EncodeLiterals-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-EncodeLiterals-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-EncodeLiterals-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-EncodeLiterals-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-Flatten-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-Flatten.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-InitEntropy-EncodeArithmetic.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-InitEntropy-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-InitEntropy.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-InitImplicitFlow-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-InitImplicitFlow.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-InitOpaque-EncodeLiterals.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns-InitOpaque.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split-RandomFuns.npy
#   inflating: DB_Repo/data/welcome_to_codejam-Split.npy
#   inflating: DB_Repo/data/welcome_to_codejam-base.npy

# %%
path, dirs, files = next(os.walk("/content/DB_Repo/data"))
file_count = len(files)
#Should be 36000
print(file_count)
# Out:
# 36000

# %%
# %cd /content/DB_Repo/data
# !pwd
# Out:
# /content/DB_Repo/data
# /content/DB_Repo/data

# %% [markdown]
# #Lettura database, resize immagini e modello

# %%
def codice_4():

  batch_size = 256

  time_steps = 256
  n_features = 64
  #size_ts_blocks = 8

  #Unit in first layer
  num_units1 = 141
  num_units2 = 94

  new_dim = 256
  MAX_LEN = 64 #fisso
  channels = 1

  n_epochs = 100

  #Considero il primo 20% della lista di dati come test set
  percentage_required = 20 #%

  #COSTANTI E DICHIARAZIONI

  database_list = list()
  labels_list = list()
  obf_list = list()

  #LETTURA E RESIZE IMMAGINI

  print("START IMAGE INPUT")
  #Aggiungo i valori alle liste leggendo i vari files
  for filename in glob.glob('*.npy'):
    temp_img = np.load(filename)
    temp_img = temp_img.reshape((-1, MAX_LEN)).astype('float32') 
    temp_img = cv2.resize(temp_img, (MAX_LEN, new_dim), interpolation=cv2.INTER_CUBIC)
    database_list.append(temp_img)
    #Salvo la label, ossia la classe
    labels_list.append(extract_label(filename))
    #Salvo la lista di offuscatori di ogni file
    obf_list.append(extract_obf(filename))
  print("END IMAGE INPUT")


  #SHUFFLE

  #Ho i valori e le etichette in due liste (+ obf); 
  #le mescolo mantenendo l'ordine tra valore-label
  temp = list(zip(database_list, labels_list, obf_list))
  np.random.shuffle(temp)
  database_list, labels_list, obf_list = zip(*temp)


  #SUDDIVISIONE DATI

  #Suddivido in training set e test set
  assert len(database_list) == len(labels_list) == len(obf_list)

  index_to_split = math.ceil((len(database_list) * percentage_required) / 100)
  indices = [(0, index_to_split - 1), (index_to_split, len(database_list) - 1)]

  test_list, training_list = [database_list[s:e+1] for s,e in indices]
  labels_test_list, labels_training_list = [labels_list[s:e+1] for s,e in indices]
  obf_test_list, obf_training_list = [obf_list[s:e+1] for s,e in indices]

  #Trasformo i valori in numpy.ndarray
  train_images = np.array(training_list)
  test_images = np.array(test_list)

  train_labels = np.array(labels_training_list)
  test_labels = np.array(labels_test_list)

  train_obf = np.array(obf_training_list)
  test_obf = np.array(obf_test_list)

  label_encoder = LabelEncoder()
  label_encoder.fit(train_labels)
  train_labels_encoded = label_encoder.transform(train_labels)
  test_labels_encoded = label_encoder.transform(test_labels)


  #Normalizzazione valori in range 0-1
  train_images = train_images / 65535.0
  test_images = test_images / 65535.0


  #Dichiarazione parametri

  n_classes = len(list(label_encoder.classes_))

  modelLSTM = ks.Sequential()

  #no activation selection

  modelLSTM.add(Bidirectional(CuDNNLSTM(num_units1, unit_forget_bias='true', return_sequences='true'),
                              input_shape=(time_steps, n_features)))
  modelLSTM.add(Bidirectional(CuDNNLSTM(num_units2, unit_forget_bias='true')))
  modelLSTM.add(Dense(n_classes, activation='softmax'))

  modelLSTM.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

  #Validation_data è usato al termine di ogni epoch;
  #Batch size should be (at most) the same number of hidden cells
  es = ks.callbacks.EarlyStopping(monitor='val_loss', patience=10,
                                  mode='auto', restore_best_weights=True, verbose=1)
  time_callback = TimeHistory()

  hist = modelLSTM.fit(train_images, train_labels_encoded, 
                      batch_size = batch_size,
                      validation_data=(test_images, test_labels_encoded), 
                      epochs=n_epochs, shuffle='true',
                      callbacks=[time_callback, es], verbose=1)

  number_of_epochs_it_ran = len(hist.history['loss'])

  time_per_epoch = time_callback.times
  total_time = sum(time_per_epoch)

  test_accuracy = modelLSTM.evaluate(test_images, test_labels_encoded)

  _for_conf_matr = (label_encoder.classes_, test_images, test_labels_encoded)
  statistiche_modello = Stats(train_images[0].shape, percentage_required, batch_size, test_accuracy[1], test_accuracy[0], n_epochs, number_of_epochs_it_ran, total_time, modelLSTM, hist, _for_conf_matr, "model1_bi")

  return statistiche_modello

# %%
results = list()

results.append(codice_4())
# Out:
# START IMAGE INPUT
# END IMAGE INPUT
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Train on 28800 samples, validate on 7200 samples
# Epoch 1/100
# 28800/28800 [==============================] - 48s 2ms/sample - loss: 2.8426 - acc: 0.2729 - val_loss: 2.1668 - val_acc: 0.4196
# Epoch 2/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 1.8826 - acc: 0.4887 - val_loss: 1.7394 - val_acc: 0.5331
# Epoch 3/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 1.5580 - acc: 0.5841 - val_loss: 1.5495 - val_acc: 0.5986
# Epoch 4/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 1.2238 - acc: 0.6813 - val_loss: 1.1830 - val_acc: 0.6985
# Epoch 5/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 1.0014 - acc: 0.7417 - val_loss: 1.0615 - val_acc: 0.7193
# Epoch 6/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.8452 - acc: 0.7846 - val_loss: 0.9155 - val_acc: 0.7619
# Epoch 7/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.7716 - acc: 0.8020 - val_loss: 0.8969 - val_acc: 0.7657
# Epoch 8/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.6808 - acc: 0.8275 - val_loss: 0.7763 - val_acc: 0.8025
# Epoch 9/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.5763 - acc: 0.8571 - val_loss: 0.6951 - val_acc: 0.8261
# Epoch 10/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.4921 - acc: 0.8790 - val_loss: 0.6473 - val_acc: 0.8454
# Epoch 11/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.4126 - acc: 0.8983 - val_loss: 0.6024 - val_acc: 0.8594
# Epoch 12/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.3818 - acc: 0.9068 - val_loss: 0.5626 - val_acc: 0.8733
# Epoch 13/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.3312 - acc: 0.9200 - val_loss: 0.5157 - val_acc: 0.8819
# Epoch 14/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.3175 - acc: 0.9209 - val_loss: 0.5130 - val_acc: 0.8797
# Epoch 15/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.2776 - acc: 0.9334 - val_loss: 0.4658 - val_acc: 0.8935
# Epoch 16/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.2257 - acc: 0.9459 - val_loss: 0.4300 - val_acc: 0.9054
# Epoch 17/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.2059 - acc: 0.9496 - val_loss: 0.4199 - val_acc: 0.9092
# Epoch 18/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.1968 - acc: 0.9526 - val_loss: 0.4370 - val_acc: 0.9075
# Epoch 19/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.1721 - acc: 0.9592 - val_loss: 0.3916 - val_acc: 0.9169
# Epoch 20/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.1594 - acc: 0.9620 - val_loss: 0.3729 - val_acc: 0.9221
# Epoch 21/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.1326 - acc: 0.9691 - val_loss: 0.3890 - val_acc: 0.9204
# Epoch 22/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.1240 - acc: 0.9709 - val_loss: 0.3929 - val_acc: 0.9183
# Epoch 23/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.1311 - acc: 0.9680 - val_loss: 0.3448 - val_acc: 0.9326
# Epoch 24/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0768 - acc: 0.9833 - val_loss: 0.3177 - val_acc: 0.9428
# Epoch 25/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0491 - acc: 0.9914 - val_loss: 0.2994 - val_acc: 0.9489
# Epoch 26/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0387 - acc: 0.9942 - val_loss: 0.3007 - val_acc: 0.9482
# Epoch 27/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0253 - acc: 0.9968 - val_loss: 0.2950 - val_acc: 0.9497
# Epoch 28/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0438 - acc: 0.9923 - val_loss: 0.3138 - val_acc: 0.9483
# Epoch 29/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.1369 - acc: 0.9634 - val_loss: 0.4749 - val_acc: 0.9010
# Epoch 30/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.2218 - acc: 0.9381 - val_loss: 0.4793 - val_acc: 0.8964
# Epoch 31/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.1468 - acc: 0.9613 - val_loss: 0.3469 - val_acc: 0.9350
# Epoch 32/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0587 - acc: 0.9879 - val_loss: 0.3198 - val_acc: 0.9474
# Epoch 33/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0440 - acc: 0.9919 - val_loss: 0.3016 - val_acc: 0.9496
# Epoch 34/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0322 - acc: 0.9946 - val_loss: 0.3105 - val_acc: 0.9483
# Epoch 35/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0292 - acc: 0.9951 - val_loss: 0.2931 - val_acc: 0.9542
# Epoch 36/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0212 - acc: 0.9970 - val_loss: 0.2960 - val_acc: 0.9535
# Epoch 37/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0133 - acc: 0.9987 - val_loss: 0.2959 - val_acc: 0.9550
# Epoch 38/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0073 - acc: 0.9996 - val_loss: 0.2863 - val_acc: 0.9549
# Epoch 39/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0033 - acc: 1.0000 - val_loss: 0.2923 - val_acc: 0.9549
# Epoch 40/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0025 - acc: 1.0000 - val_loss: 0.2953 - val_acc: 0.9549
# Epoch 41/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0021 - acc: 1.0000 - val_loss: 0.2977 - val_acc: 0.9554
# Epoch 42/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0018 - acc: 1.0000 - val_loss: 0.3000 - val_acc: 0.9551
# Epoch 43/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0016 - acc: 1.0000 - val_loss: 0.3015 - val_acc: 0.9557
# Epoch 44/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0014 - acc: 1.0000 - val_loss: 0.3029 - val_acc: 0.9554
# Epoch 45/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0013 - acc: 1.0000 - val_loss: 0.3036 - val_acc: 0.9554
# Epoch 46/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0012 - acc: 1.0000 - val_loss: 0.3056 - val_acc: 0.9557
# Epoch 47/100
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 0.0011 - acc: 1.0000 - val_loss: 0.3074 - val_acc: 0.9560
# Epoch 48/100
# 28672/28800 [============================>.] - ETA: 0s - loss: 9.9689e-04 - acc: 1.0000Restoring model weights from the end of the best epoch.
# 28800/28800 [==============================] - 42s 1ms/sample - loss: 9.9656e-04 - acc: 1.0000 - val_loss: 0.3083 - val_acc: 0.9558
# Epoch 00048: early stopping
# 7200/7200 [==============================] - 18s 3ms/sample - loss: 0.2863 - acc: 0.9549

# %% [markdown]
# #Risultati

# %%
for elem in results:
  elem.myStats()
  #Plot training & validation accuracy values
  hist = elem.history
  plt.plot(hist.history['acc'])
  plt.plot(hist.history['val_acc'])
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()

  # Plot training & validation loss values
  plt.plot(hist.history['loss'])
  plt.plot(hist.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()

  #Necessito di un array con tutte le labels

  modello = elem.model
  classi, test_images, test_labels_encoded = elem._for_conf_matr
  test_predictions = modello.predict_classes(test_images)

  conf_matr = confusion_matrix(y_true = test_labels_encoded, y_pred = test_predictions)
  #print(conf_matr)

  con_mat_norm = np.around(conf_matr.astype('float') / conf_matr.sum(axis=1)[:, np.newaxis], decimals=2)

  con_mat_df = pd.DataFrame(con_mat_norm,
                          index = list(classi), 
                          columns = list(classi))
  
  figure = plt.figure(figsize=(len(list(classi)), len(list(classi))), dpi=50)
  sns.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues)
  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()
# Out:
# Dimensione immagini:  (256, 64)
# Percentuale test set: 20%
# Dimensione batch size: 256
# Val accuracy: 0.95486
# Val loss: 0.28627
# Epoche di addestramento utilizzate: 48/100
# Tempo di addestramento: 2005.79873 sec
# Model: model1_bi
